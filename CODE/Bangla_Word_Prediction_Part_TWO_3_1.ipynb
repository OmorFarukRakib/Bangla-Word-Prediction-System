# %%
from numpy import array
from keras.callbacks import CSVLogger
import numpy as np
from pickle import dump
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Embedding
import io

# %%
# load doc into memory
def load_doc(filename):
    with io.open(filename, 'r', encoding='utf8') as f:
        text = f.read()
    return text

# load
in_filename = r'updated_data_3_1.txt'
doc = load_doc(in_filename)
lines = doc.split('\n')

# %%
lines
# Out:
# ['\ufeffকর্পোরেশনের দোষ তো আছে',
#  'দোষ তো আছে ।',
#  'তো আছে । কিন্তু',
#  'আছে । কিন্তু আমরা',
#  '। কিন্তু আমরা যে',
#  'কিন্তু আমরা যে সুযোগ',
#  'আমরা যে সুযোগ বুঝে',
#  'যে সুযোগ বুঝে হাজার',
#  'সুযোগ বুঝে হাজার হাজার',
#  'বুঝে হাজার হাজার কোটি',
#  'হাজার হাজার কোটি টাকার',
#  'হাজার কোটি টাকার ট্যাক্স',
#  'কোটি টাকার ট্যাক্স ফাকি',
#  'টাকার ট্যাক্স ফাকি দিয়ে',
#  'ট্যাক্স ফাকি দিয়ে আসছি',
#  'ফাকি দিয়ে আসছি সেটাও',
#  'দিয়ে আসছি সেটাও আমরা',
#  'আসছি সেটাও আমরা জানি',
#  'সেটাও আমরা জানি ।',
#  'আমরা জানি । এই',
#  'জানি । এই ভয়ে',
#  '। এই ভয়ে সবাই',
#  'এই ভয়ে সবাই স্যু',
#  'ভয়ে সবাই স্যু করার',
#  'সবাই স্যু করার সাহস',
#  'স্যু করার সাহস পাবেনা',
#  'করার সাহস পাবেনা ।',
#  'সাহস পাবেনা । কারণ',
#  'পাবেনা । কারণ উলটা',
#  '। কারণ উলটা স্যু',
#  'কারণ উলটা স্যু সে',
#  'উলটা স্যু সে নিজে',
#  'স্যু সে নিজে খেয়ে',
#  'সে নিজে খেয়ে যাবে',
#  'নিজে খেয়ে যাবে ।',
#  'খেয়ে যাবে । আপনি',
#  'যাবে । আপনি স্যু',
#  '। আপনি স্যু করে',
#  'আপনি স্যু করে দৃষ্টান্ত',
#  'স্যু করে দৃষ্টান্ত শুরু',
#  'করে দৃষ্টান্ত শুরু করে',
#  'দৃষ্টান্ত শুরু করে দিলেই',
#  'শুরু করে দিলেই পারেন',
#  'করে দিলেই পারেন ।',
#  'দিলেই পারেন । অন্যরাও',
#  'পারেন । অন্যরাও ধীরে',
#  '। অন্যরাও ধীরে ধীরে',
#  'অন্যরাও ধীরে ধীরে উৎসাহিত',
#  'ধীরে ধীরে উৎসাহিত হবে',
#  'ধীরে উৎসাহিত হবে ।',
#  'উৎসাহিত হবে । পরিবর্তন',
#  'হবে । পরিবর্তন আসবে',
#  '। পরিবর্তন আসবে ।',
#  'পরিবর্তন আসবে । আমাদের',
#  'আসবে । আমাদের সবার',
#  '। আমাদের সবার মনেই',
#  'আমাদের সবার মনেই বিদেশে',
#  'সবার মনেই বিদেশে পড়তে',
#  'মনেই বিদেশে পড়তে যাওয়ার',
#  'বিদেশে পড়তে যাওয়ার সুপ্ত',
#  'পড়তে যাওয়ার সুপ্ত কিন্তু',
#  'যাওয়ার সুপ্ত কিন্তু তীব্র',
#  'সুপ্ত কিন্তু তীব্র আকাঙ্ক্ষা',
#  'কিন্তু তীব্র আকাঙ্ক্ষা কাজ',
#  'তীব্র আকাঙ্ক্ষা কাজ করে',
#  'আকাঙ্ক্ষা কাজ করে ।',
#  'কাজ করে । বিদেশে',
#  'করে । বিদেশে পড়ার',
#  '। বিদেশে পড়ার ক্ষেত্রে',
#  'বিদেশে পড়ার ক্ষেত্রে খরচের',
#  'পড়ার ক্ষেত্রে খরচের ব্যাপারটা',
#  'ক্ষেত্রে খরচের ব্যাপারটা মাথায়',
#  'খরচের ব্যাপারটা মাথায় আসে',
#  'ব্যাপারটা মাথায় আসে বলেই',
#  'মাথায় আসে বলেই আমরা',
#  'আসে বলেই আমরা অনেকেই',
#  'বলেই আমরা অনেকেই চাই',
#  'আমরা অনেকেই চাই বৃত্তি',
#  'অনেকেই চাই বৃত্তি বা',
#  'চাই বৃত্তি বা স্কলারশিপ',
#  'বৃত্তি বা স্কলারশিপ এর',
#  'বা স্কলারশিপ এর ব্যাপারে',
#  'স্কলারশিপ এর ব্যাপারে খোঁজ',
#  'এর ব্যাপারে খোঁজ নিতে',
#  'ব্যাপারে খোঁজ নিতে ।',
#  'খোঁজ নিতে । পুরো',
#  'নিতে । পুরো প্রক্রিয়াটি',
#  '। পুরো প্রক্রিয়াটি অনেক',
#  'পুরো প্রক্রিয়াটি অনেক বিশদ',
#  'প্রক্রিয়াটি অনেক বিশদ হওয়ায়',
#  'অনেক বিশদ হওয়ায় আমার',
#  'বিশদ হওয়ায় আমার ক্ষুদ্র',
#  'হওয়ায় আমার ক্ষুদ্র অভিজ্ঞতা',
#  'আমার ক্ষুদ্র অভিজ্ঞতা থেকে',
#  'ক্ষুদ্র অভিজ্ঞতা থেকে আমি',
#  'অভিজ্ঞতা থেকে আমি চেষ্টা',
#  'থেকে আমি চেষ্টা করবো',
#  'আমি চেষ্টা করবো আমার',
#  'চেষ্টা করবো আমার শিক্ষার্থীদের',
#  'করবো আমার শিক্ষার্থীদের কিছুটা',
#  'আমার শিক্ষার্থীদের কিছুটা জানানোর',
#  'শিক্ষার্থীদের কিছুটা জানানোর ।',
#  'কিছুটা জানানোর । আমার',
#  'জানানোর । আমার লেখাটা',
#  '। আমার লেখাটা টি',
#  'আমার লেখাটা টি পর্বে',
#  'লেখাটা টি পর্বে থাকবে',
#  'টি পর্বে থাকবে ।',
#  'পর্বে থাকবে । আজ',
#  'থাকবে । আজ প্রথম',
#  '। আজ প্রথম পর্ব',
#  'আজ প্রথম পর্ব ।',
#  'প্রথম পর্ব । আজকে',
#  'পর্ব । আজকে আমি',
#  '। আজকে আমি আলোচনা',
#  'আজকে আমি আলোচনা করবো',
#  'আমি আলোচনা করবো বাংলাদেশি',
#  'আলোচনা করবো বাংলাদেশি শিক্ষার্থীদের',
#  'করবো বাংলাদেশি শিক্ষার্থীদের জন্য',
#  'বাংলাদেশি শিক্ষার্থীদের জন্য বিদেশে',
#  'শিক্ষার্থীদের জন্য বিদেশে পড়তে',
#  'জন্য বিদেশে পড়তে যাওয়ার',
#  'বিদেশে পড়তে যাওয়ার স্কলারশিপ',
#  'পড়তে যাওয়ার স্কলারশিপ নিয়ে',
#  'যাওয়ার স্কলারশিপ নিয়ে ।',
#  'স্কলারশিপ নিয়ে । পরবর্তীতে',
#  'নিয়ে । পরবর্তীতে বিভিন্ন',
#  '। পরবর্তীতে বিভিন্ন দেশে',
#  'পরবর্তীতে বিভিন্ন দেশে এপ্লাই',
#  'বিভিন্ন দেশে এপ্লাই করার',
#  'দেশে এপ্লাই করার প্রক্রিয়া',
#  'এপ্লাই করার প্রক্রিয়া ক্রেডিট',
#  'করার প্রক্রিয়া ক্রেডিট ট্রান্সফার',
#  'প্রক্রিয়া ক্রেডিট ট্রান্সফার বিশ্ববিদ্যালয়ের',
#  'ক্রেডিট ট্রান্সফার বিশ্ববিদ্যালয়ের ইন',
#  'ট্রান্সফার বিশ্ববিদ্যালয়ের ইন হাউস',
#  'বিশ্ববিদ্যালয়ের ইন হাউস স্কলারশিপ',
#  'ইন হাউস স্কলারশিপ ইত্যাদি',
#  'হাউস স্কলারশিপ ইত্যাদি বিষয়ে',
#  'স্কলারশিপ ইত্যাদি বিষয়ে আলোচনা',
#  'ইত্যাদি বিষয়ে আলোচনা করবো',
#  'বিষয়ে আলোচনা করবো ।',
#  'আলোচনা করবো । যুক্তরাজ্যে',
#  'করবো । যুক্তরাজ্যে পড়তে',
#  '। যুক্তরাজ্যে পড়তে যাওয়ার',
#  'যুক্তরাজ্যে পড়তে যাওয়ার জন্য',
#  'পড়তে যাওয়ার জন্য ব্রিটিশ',
#  'যাওয়ার জন্য ব্রিটিশ সরকারের',
#  'জন্য ব্রিটিশ সরকারের বৃত্তি',
#  'ব্রিটিশ সরকারের বৃত্তি এটি',
#  'সরকারের বৃত্তি এটি ।',
#  'বৃত্তি এটি । অত্যন্ত',
#  'এটি । অত্যন্ত সম্মানজনক',
#  '। অত্যন্ত সম্মানজনক এবং',
#  'অত্যন্ত সম্মানজনক এবং সেইসাথে',
#  'সম্মানজনক এবং সেইসাথে খুবই',
#  'এবং সেইসাথে খুবই প্রতিযোগিতামূলক',
#  'সেইসাথে খুবই প্রতিযোগিতামূলক ।',
#  'খুবই প্রতিযোগিতামূলক । সাধারণত',
#  'প্রতিযোগিতামূলক । সাধারণত যারা',
#  '। সাধারণত যারা শিক্ষকতা',
#  'সাধারণত যারা শিক্ষকতা পেশায়',
#  'যারা শিক্ষকতা পেশায় নিয়োজিত',
#  'শিক্ষকতা পেশায় নিয়োজিত থাকেন',
#  'পেশায় নিয়োজিত থাকেন তারা',
#  'নিয়োজিত থাকেন তারা এটা',
#  'থাকেন তারা এটা পেয়ে',
#  'তারা এটা পেয়ে থাকেন',
#  'এটা পেয়ে থাকেন তবে',
#  'পেয়ে থাকেন তবে শিক্ষকই',
#  'থাকেন তবে শিক্ষকই হতে',
#  'তবে শিক্ষকই হতে হবে',
#  'শিক্ষকই হতে হবে এমন',
#  'হতে হবে এমন কোনো',
#  'হবে এমন কোনো বাধ্যবাধকতা',
#  'এমন কোনো বাধ্যবাধকতা নেই',
#  'কোনো বাধ্যবাধকতা নেই ।',
#  'বাধ্যবাধকতা নেই । আপনার',
#  'নেই । আপনার বয়স',
#  '। আপনার বয়স কম',
#  'আপনার বয়স কম হলে',
#  'বয়স কম হলে এবং',
#  'কম হলে এবং আপনার',
#  'হলে এবং আপনার ব্যাচেলর',
#  'এবং আপনার ব্যাচেলর ডিগ্রিতে',
#  'আপনার ব্যাচেলর ডিগ্রিতে নম্বর',
#  'ব্যাচেলর ডিগ্রিতে নম্বর থাকলেই',
#  'ডিগ্রিতে নম্বর থাকলেই আপনি',
#  'নম্বর থাকলেই আপনি এই',
#  'থাকলেই আপনি এই স্কলারশিপের',
#  'আপনি এই স্কলারশিপের জন্য',
#  'এই স্কলারশিপের জন্য এপ্লাই',
#  'স্কলারশিপের জন্য এপ্লাই করতে',
#  'জন্য এপ্লাই করতে পারবেন',
#  'এপ্লাই করতে পারবেন ।',
#  'করতে পারবেন । এক্ষেত্রে',
#  'পারবেন । এক্ষেত্রে যেটা',
#  '। এক্ষেত্রে যেটা লাগবে',
#  'এক্ষেত্রে যেটা লাগবে সেটা',
#  'যেটা লাগবে সেটা হলো',
#  'লাগবে সেটা হলো যুক্তরাজ্যের',
#  'সেটা হলো যুক্তরাজ্যের কোনো',
#  'হলো যুক্তরাজ্যের কোনো একটি',
#  'যুক্তরাজ্যের কোনো একটি বিশ্ববিদ্যালয়ে',
#  'কোনো একটি বিশ্ববিদ্যালয়ে ভর্তির',
#  'একটি বিশ্ববিদ্যালয়ে ভর্তির আনকন্ডিশনাল',
#  'বিশ্ববিদ্যালয়ে ভর্তির আনকন্ডিশনাল অফার',
#  'ভর্তির আনকন্ডিশনাল অফার লেটার',
#  'আনকন্ডিশনাল অফার লেটার ।',
#  'অফার লেটার । গুগল',
#  'লেটার । গুগল করলেই',
#  '। গুগল করলেই লিস্ট',
#  'গুগল করলেই লিস্ট পাবেন',
#  'করলেই লিস্ট পাবেন ব্রিটেনের',
#  'লিস্ট পাবেন ব্রিটেনের কোন',
#  'পাবেন ব্রিটেনের কোন কোন',
#  'ব্রিটেনের কোন কোন বিশ্ববিদ্যালয়',
#  'কোন কোন বিশ্ববিদ্যালয় কমনওয়েলথের',
#  'কোন বিশ্ববিদ্যালয় কমনওয়েলথের আওতায়',
#  'বিশ্ববিদ্যালয় কমনওয়েলথের আওতায় আছে',
#  'কমনওয়েলথের আওতায় আছে ।',
#  'আওতায় আছে । তারমানে',
#  'আছে । তারমানে আপনার',
#  '। তারমানে আপনার আগে',
#  'তারমানে আপনার আগে বিশ্ববিদ্যালয়ে',
#  'আপনার আগে বিশ্ববিদ্যালয়ে ওদের',
#  'আগে বিশ্ববিদ্যালয়ে ওদের নিজস্ব',
#  'বিশ্ববিদ্যালয়ে ওদের নিজস্ব সিস্টেমে',
#  'ওদের নিজস্ব সিস্টেমে এপ্লাই',
#  'নিজস্ব সিস্টেমে এপ্লাই করতে',
#  'সিস্টেমে এপ্লাই করতে হবে',
#  'এপ্লাই করতে হবে আর',
#  'করতে হবে আর অফার',
#  'হবে আর অফার লেটার',
#  'আর অফার লেটার পেলেই',
#  'অফার লেটার পেলেই আপনি',
#  'লেটার পেলেই আপনি কমনওয়েলথের',
#  'পেলেই আপনি কমনওয়েলথের জন্য',
#  'আপনি কমনওয়েলথের জন্য এপ্লাই',
#  'কমনওয়েলথের জন্য এপ্লাই করতে',
#  'জন্য এপ্লাই করতে পারবেন',
#  'এপ্লাই করতে পারবেন ।',
#  'করতে পারবেন । দুটোর',
#  'পারবেন । দুটোর ক্ষেত্রেই',
#  '। দুটোর ক্ষেত্রেই এপ্লিকেশন',
#  'দুটোর ক্ষেত্রেই এপ্লিকেশন প্রোসেস',
#  'ক্ষেত্রেই এপ্লিকেশন প্রোসেস ভিন্ন',
#  'এপ্লিকেশন প্রোসেস ভিন্ন ।',
#  'প্রোসেস ভিন্ন । এছাড়া',
#  'ভিন্ন । এছাড়া স্কলারশিপের',
#  '। এছাড়া স্কলারশিপের ক্ষেত্রেও',
#  'এছাড়া স্কলারশিপের ক্ষেত্রেও আইল্টসের',
#  'স্কলারশিপের ক্ষেত্রেও আইল্টসের স্কোর',
#  'ক্ষেত্রেও আইল্টসের স্কোর আপনার',
#  'আইল্টসের স্কোর আপনার জন্য',
#  'স্কোর আপনার জন্য একটা',
#  'আপনার জন্য একটা ফ্যাক্টর',
#  'জন্য একটা ফ্যাক্টর হবে',
#  'একটা ফ্যাক্টর হবে ।',
#  'ফ্যাক্টর হবে । কমনওয়েলথ',
#  'হবে । কমনওয়েলথ সাধারণত',
#  '। কমনওয়েলথ সাধারণত ওপেন',
#  'কমনওয়েলথ সাধারণত ওপেন হয়',
#  'সাধারণত ওপেন হয় নভেম্বরের',
#  'ওপেন হয় নভেম্বরের দিকে',
#  'হয় নভেম্বরের দিকে ।',
#  'নভেম্বরের দিকে । সময়',
#  'দিকে । সময় থাকে',
#  '। সময় থাকে ২',
#  'সময় থাকে ২ মাসের',
#  'থাকে ২ মাসের মতো',
#  '২ মাসের মতো ।',
#  'মাসের মতো । এটাও',
#  'মতো । এটাও কমনওয়েলথের',
#  '। এটাও কমনওয়েলথের মতই',
#  'এটাও কমনওয়েলথের মতই কিন্তু',
#  'কমনওয়েলথের মতই কিন্তু এটার',
#  'মতই কিন্তু এটার ফাণ্ডিং',
#  'কিন্তু এটার ফাণ্ডিং অর্ধেক',
#  'এটার ফাণ্ডিং অর্ধেক যেই',
#  'ফাণ্ডিং অর্ধেক যেই বিশ্ববিদ্যালয়',
#  'অর্ধেক যেই বিশ্ববিদ্যালয় এফিলিয়েটেড',
#  'যেই বিশ্ববিদ্যালয় এফিলিয়েটেড সেটা',
#  'বিশ্ববিদ্যালয় এফিলিয়েটেড সেটা দিবে',
#  'এফিলিয়েটেড সেটা দিবে আর',
#  'সেটা দিবে আর বাকি',
#  'দিবে আর বাকি অর্ধেক',
#  'আর বাকি অর্ধেক দিবে',
#  'বাকি অর্ধেক দিবে কমনওয়েলথ',
#  'অর্ধেক দিবে কমনওয়েলথ স্কলারশিপ',
#  'দিবে কমনওয়েলথ স্কলারশিপ কমিটি',
#  'কমনওয়েলথ স্কলারশিপ কমিটি ।',
#  'স্কলারশিপ কমিটি । বাকিসব',
#  'কমিটি । বাকিসব ক্রাইটেরিয়া',
#  '। বাকিসব ক্রাইটেরিয়া একই',
#  'বাকিসব ক্রাইটেরিয়া একই ।',
#  'ক্রাইটেরিয়া একই । তবে',
#  'একই । তবে বিশ্ববিদ্যালয়ের',
#  '। তবে বিশ্ববিদ্যালয়ের একটা',
#  'তবে বিশ্ববিদ্যালয়ের একটা তালিকা',
#  'বিশ্ববিদ্যালয়ের একটা তালিকা থাকে',
#  'একটা তালিকা থাকে যে',
#  'তালিকা থাকে যে কোন',
#  'থাকে যে কোন কোন',
#  'যে কোন কোন বিশ্ববিদ্যালয়',
#  'কোন কোন বিশ্ববিদ্যালয় এই',
#  'কোন বিশ্ববিদ্যালয় এই শেয়ারড',
#  'বিশ্ববিদ্যালয় এই শেয়ারড প্রোগ্রামের',
#  'এই শেয়ারড প্রোগ্রামের আওতায়',
#  'শেয়ারড প্রোগ্রামের আওতায় ।',
#  'প্রোগ্রামের আওতায় । যুক্তরাজ্যে',
#  'আওতায় । যুক্তরাজ্যে পড়তে',
#  '। যুক্তরাজ্যে পড়তে যাওয়ার',
#  'যুক্তরাজ্যে পড়তে যাওয়ার জন্য',
#  'পড়তে যাওয়ার জন্য ব্রিটিশ',
#  'যাওয়ার জন্য ব্রিটিশ সরকারের',
#  'জন্য ব্রিটিশ সরকারের বৃত্তি',
#  'ব্রিটিশ সরকারের বৃত্তি ।',
#  'সরকারের বৃত্তি । সাধারণত',
#  'বৃত্তি । সাধারণত এনজিও',
#  '। সাধারণত এনজিও কর্মী',
#  'সাধারণত এনজিও কর্মী সরকারী',
#  'এনজিও কর্মী সরকারী চাকুরে',
#  'কর্মী সরকারী চাকুরে বাংলাদেশ',
#  'সরকারী চাকুরে বাংলাদেশ ব্যাংকের',
#  'চাকুরে বাংলাদেশ ব্যাংকের কর্মকর্তা',
#  'বাংলাদেশ ব্যাংকের কর্মকর্তা উদ্যোক্তা',
#  'ব্যাংকের কর্মকর্তা উদ্যোক্তা এদের',
#  'কর্মকর্তা উদ্যোক্তা এদের জন্য',
#  'উদ্যোক্তা এদের জন্য এই',
#  'এদের জন্য এই বৃত্তি',
#  'জন্য এই বৃত্তি ।',
#  'এই বৃত্তি । আপনার',
#  'বৃত্তি । আপনার চাকরি',
#  '। আপনার চাকরি যদি',
#  'আপনার চাকরি যদি দুই',
#  'চাকরি যদি দুই বছর',
#  'যদি দুই বছর হয়',
#  'দুই বছর হয় তাহলে',
#  'বছর হয় তাহলে এটার',
#  'হয় তাহলে এটার জন্য',
#  'তাহলে এটার জন্য এপ্লাই',
#  'এটার জন্য এপ্লাই করতে',
#  'জন্য এপ্লাই করতে পারবেন',
#  'এপ্লাই করতে পারবেন ।',
#  'করতে পারবেন । ক্রাইটেরিয়া',
#  'পারবেন । ক্রাইটেরিয়া একই',
#  '। ক্রাইটেরিয়া একই রকম',
#  'ক্রাইটেরিয়া একই রকম ।',
#  'একই রকম । আইল্টসে',
#  'রকম । আইল্টসে ভালো',
#  '। আইল্টসে ভালো স্কোর',
#  'আইল্টসে ভালো স্কোর আর',
#  'ভালো স্কোর আর ইউকের',
#  'স্কোর আর ইউকের বিশ্ববিদ্যালয়',
#  'আর ইউকের বিশ্ববিদ্যালয় থেকে',
#  'ইউকের বিশ্ববিদ্যালয় থেকে আনকন্ডিশনাল',
#  'বিশ্ববিদ্যালয় থেকে আনকন্ডিশনাল অফার',
#  'থেকে আনকন্ডিশনাল অফার লেটার',
#  'আনকন্ডিশনাল অফার লেটার লাগবে',
#  'অফার লেটার লাগবে ।',
#  'লেটার লাগবে । মার্কিন',
#  'লাগবে । মার্কিন সরকারের',
#  '। মার্কিন সরকারের বৃত্তি',
#  'মার্কিন সরকারের বৃত্তি ।',
#  'সরকারের বৃত্তি । দারুণ',
#  'বৃত্তি । দারুণ প্রেস্টিজিয়াস',
#  '। দারুণ প্রেস্টিজিয়াস এবং',
#  'দারুণ প্রেস্টিজিয়াস এবং আর্থিক',
#  'প্রেস্টিজিয়াস এবং আর্থিক দিক',
#  'এবং আর্থিক দিক থেকেও',
#  'আর্থিক দিক থেকেও বেশ',
#  'দিক থেকেও বেশ লাভজনক',
#  'থেকেও বেশ লাভজনক ।',
#  'বেশ লাভজনক । মূল',
#  'লাভজনক । মূল বৃত্তিটির',
#  '। মূল বৃত্তিটির নাম',
#  'মূল বৃত্তিটির নাম হলো',
#  'বৃত্তিটির নাম হলো ফুলব্রাইট',
#  'নাম হলো ফুলব্রাইট ফরেন',
#  'হলো ফুলব্রাইট ফরেন স্টুডেন্ট',
#  'ফুলব্রাইট ফরেন স্টুডেন্ট প্রোগ্রাম',
#  'ফরেন স্টুডেন্ট প্রোগ্রাম ।',
#  'স্টুডেন্ট প্রোগ্রাম । এটার',
#  'প্রোগ্রাম । এটার ক্ষেত্রে',
#  '। এটার ক্ষেত্রে আলাদাভাবে',
#  'এটার ক্ষেত্রে আলাদাভাবে কোনো',
#  'ক্ষেত্রে আলাদাভাবে কোনো বিশ্ববিদ্যালয়ে',
#  'আলাদাভাবে কোনো বিশ্ববিদ্যালয়ে এপ্লাই',
#  'কোনো বিশ্ববিদ্যালয়ে এপ্লাই করতে',
#  'বিশ্ববিদ্যালয়ে এপ্লাই করতে হবেনা',
#  'এপ্লাই করতে হবেনা ।',
#  'করতে হবেনা । ফুলব্রাইটে',
#  'হবেনা । ফুলব্রাইটে এপ্লাই',
#  '। ফুলব্রাইটে এপ্লাই করলেই',
#  'ফুলব্রাইটে এপ্লাই করলেই হবে',
#  'এপ্লাই করলেই হবে ।',
#  'করলেই হবে । যদি',
#  'হবে । যদি আপনি',
#  '। যদি আপনি বৃত্তির',
#  'যদি আপনি বৃত্তির জন্য',
#  'আপনি বৃত্তির জন্য মনোনীত',
#  'বৃত্তির জন্য মনোনীত হোন',
#  'জন্য মনোনীত হোন তাহলে',
#  'মনোনীত হোন তাহলে তারাই',
#  'হোন তাহলে তারাই আপনাকে',
#  'তাহলে তারাই আপনাকে বিশ্ববিদ্যালয়',
#  'তারাই আপনাকে বিশ্ববিদ্যালয় নির্ধারণ',
#  'আপনাকে বিশ্ববিদ্যালয় নির্ধারণ করে',
#  'বিশ্ববিদ্যালয় নির্ধারণ করে দিবে',
#  'নির্ধারণ করে দিবে ।',
#  'করে দিবে । ইয়োরোপ',
#  'দিবে । ইয়োরোপ ঘুরে',
#  '। ইয়োরোপ ঘুরে বেড়ানোর',
#  'ইয়োরোপ ঘুরে বেড়ানোর জন্য',
#  'ঘুরে বেড়ানোর জন্য এর',
#  'বেড়ানোর জন্য এর চাইতে',
#  'জন্য এর চাইতে ভালো',
#  'এর চাইতে ভালো স্কলারশিপ',
#  'চাইতে ভালো স্কলারশিপ আর',
#  'ভালো স্কলারশিপ আর হয়না',
#  'স্কলারশিপ আর হয়না ।',
#  'আর হয়না । বিশেষ',
#  'হয়না । বিশেষ করে',
#  '। বিশেষ করে সায়েন্স',
#  'বিশেষ করে সায়েন্স এন্ড',
#  'করে সায়েন্স এন্ড টেকনোলজিতে',
#  'সায়েন্স এন্ড টেকনোলজিতে যারা',
#  'এন্ড টেকনোলজিতে যারা পড়ছেন',
#  'টেকনোলজিতে যারা পড়ছেন তাদের',
#  'যারা পড়ছেন তাদের জন্য',
#  'পড়ছেন তাদের জন্য এটা',
#  'তাদের জন্য এটা বেশ',
#  'জন্য এটা বেশ লিউক্রেটিভ',
#  'এটা বেশ লিউক্রেটিভ ।',
#  'বেশ লিউক্রেটিভ । সিজিপিএ',
#  'লিউক্রেটিভ । সিজিপিএ ভালো',
#  '। সিজিপিএ ভালো থাকা',
#  'সিজিপিএ ভালো থাকা লাগবে',
#  'ভালো থাকা লাগবে ।',
#  'থাকা লাগবে । এই',
#  'লাগবে । এই স্কলারশিপের',
#  '। এই স্কলারশিপের মজা',
#  'এই স্কলারশিপের মজা হলো',
#  'স্কলারশিপের মজা হলো ওরা',
#  'মজা হলো ওরা আ',
#  'হলো ওরা আ পনাকে',
#  'ওরা আ পনাকে ইয়োরোপের',
#  'আ পনাকে ইয়োরোপের দুটো',
#  'পনাকে ইয়োরোপের দুটো দেশের',
#  'ইয়োরোপের দুটো দেশের দুই',
#  'দুটো দেশের দুই বিশ্ববিদ্যালয়ে',
#  'দেশের দুই বিশ্ববিদ্যালয়ে যৌথভাবে',
#  'দুই বিশ্ববিদ্যালয়ে যৌথভাবে দুই',
#  'বিশ্ববিদ্যালয়ে যৌথভাবে দুই বছরের',
#  'যৌথভাবে দুই বছরের মাস্টার্স',
#  'দুই বছরের মাস্টার্স ডিগ্রি',
#  'বছরের মাস্টার্স ডিগ্রি করাবে',
#  'মাস্টার্স ডিগ্রি করাবে ।',
#  'ডিগ্রি করাবে । বৃত্তির',
#  'করাবে । বৃত্তির পরিমাণ',
#  '। বৃত্তির পরিমাণ বেশ',
#  'বৃত্তির পরিমাণ বেশ ভালো',
#  'পরিমাণ বেশ ভালো ।',
#  'বেশ ভালো । কোনো',
#  'ভালো । কোনো চাকরির',
#  '। কোনো চাকরির অভিজ্ঞতা',
#  'কোনো চাকরির অভিজ্ঞতা লাগবেনা',
#  'চাকরির অভিজ্ঞতা লাগবেনা ।',
#  'অভিজ্ঞতা লাগবেনা । বিশ্বের',
#  'লাগবেনা । বিশ্বের যেকোনো',
#  '। বিশ্বের যেকোনো বিশ্ববিদ্যালয়',
#  'বিশ্বের যেকোনো বিশ্ববিদ্যালয় থেকে',
#  'যেকোনো বিশ্ববিদ্যালয় থেকে আপনি',
#  'বিশ্ববিদ্যালয় থেকে আপনি আনকন্ডিশনাল',
#  'থেকে আপনি আনকন্ডিশনাল অফার',
#  'আপনি আনকন্ডিশনাল অফার লেটার',
#  'আনকন্ডিশনাল অফার লেটার পেলে',
#  'অফার লেটার পেলে আপনি',
#  'লেটার পেলে আপনি এটায়',
#  'পেলে আপনি এটায় এপ্লাই',
#  'আপনি এটায় এপ্লাই করতে',
#  'এটায় এপ্লাই করতে পারবেন',
#  'এপ্লাই করতে পারবেন ।',
#  'করতে পারবেন । আইল্টস',
#  'পারবেন । আইল্টস দেওয়া',
#  '। আইল্টস দেওয়া লাগবে',
#  'আইল্টস দেওয়া লাগবে ।',
#  'দেওয়া লাগবে । বিশ্ববিদ্যালয়',
#  'লাগবে । বিশ্ববিদ্যালয় অফার',
#  '। বিশ্ববিদ্যালয় অফার পাওয়ার',
#  'বিশ্ববিদ্যালয় অফার পাওয়ার পর',
#  'অফার পাওয়ার পর আলদাভাবে',
#  'পাওয়ার পর আলদাভাবে এপ্লাই',
#  'পর আলদাভাবে এপ্লাই করতে',
#  'আলদাভাবে এপ্লাই করতে হবে',
#  'এপ্লাই করতে হবে ।',
#  'করতে হবে । সাধারণত',
#  'হবে । সাধারণত জানুয়ারি',
#  '। সাধারণত জানুয়ারি ফেব্রুয়ারিতে',
#  'সাধারণত জানুয়ারি ফেব্রুয়ারিতে ওপেন',
#  'জানুয়ারি ফেব্রুয়ারিতে ওপেন হয়ে',
#  'ফেব্রুয়ারিতে ওপেন হয়ে এপ্রিল',
#  'ওপেন হয়ে এপ্রিল পর্যন্ত',
#  'হয়ে এপ্রিল পর্যন্ত সময়',
#  'এপ্রিল পর্যন্ত সময় থাকে',
#  'পর্যন্ত সময় থাকে ।',
#  'সময় থাকে । বিশ্বের',
#  'থাকে । বিশ্বের ভালো',
#  '। বিশ্বের ভালো র\u200d্যাংকের',
#  'বিশ্বের ভালো র\u200d্যাংকের বিশ্ববিদ্যালয়ে',
#  'ভালো র\u200d্যাংকের বিশ্ববিদ্যালয়ে ভর্তি',
#  'র\u200d্যাংকের বিশ্ববিদ্যালয়ে ভর্তি হয়ে',
#  'বিশ্ববিদ্যালয়ে ভর্তি হয়ে অফার',
#  'ভর্তি হয়ে অফার লেটার',
#  'হয়ে অফার লেটার নিয়ে',
#  'অফার লেটার নিয়ে এই',
#  'লেটার নিয়ে এই স্কলারশিপে',
#  'নিয়ে এই স্কলারশিপে এপ্লাই',
#  'এই স্কলারশিপে এপ্লাই করতে',
#  'স্কলারশিপে এপ্লাই করতে হয়',
#  'এপ্লাই করতে হয় ।',
#  'করতে হয় । সাধারণত',
#  'হয় । সাধারণত উন্নয়ন',
#  '। সাধারণত উন্নয়ন বিষয়ক',
#  'সাধারণত উন্নয়ন বিষয়ক পড়ালেখার',
#  'উন্নয়ন বিষয়ক পড়ালেখার জন্য',
#  'বিষয়ক পড়ালেখার জন্য এই',
#  'পড়ালেখার জন্য এই বৃত্তি',
#  'জন্য এই বৃত্তি দেওয়া',
#  'এই বৃত্তি দেওয়া হয়',
#  'বৃত্তি দেওয়া হয় ।',
#  'দেওয়া হয় । দারুণ',
#  'হয় । দারুণ একটা',
#  '। দারুণ একটা সিভি',
#  'দারুণ একটা সিভি লাগবে',
#  'একটা সিভি লাগবে ।',
#  'সিভি লাগবে । ফরম্যাট',
#  'লাগবে । ফরম্যাট অনেকেই',
#  '। ফরম্যাট অনেকেই দিয়ে',
#  'ফরম্যাট অনেকেই দিয়ে দেয়',
#  'অনেকেই দিয়ে দেয় যেমন',
#  'দিয়ে দেয় যেমন ইরেসমাসে',
#  'দেয় যেমন ইরেসমাসে আপনাকে',
#  'যেমন ইরেসমাসে আপনাকে সিভি',
#  'ইরেসমাসে আপনাকে সিভি ফরম্যাট',
#  'আপনাকে সিভি ফরম্যাট ওরাই',
#  'সিভি ফরম্যাট ওরাই দিয়ে',
#  'ফরম্যাট ওরাই দিয়ে দিবে',
#  'ওরাই দিয়ে দিবে ।',
#  'দিয়ে দিবে । বাকিগুলোর',
#  'দিবে । বাকিগুলোর ক্ষেত্রে',
#  '। বাকিগুলোর ক্ষেত্রে সিভি',
#  'বাকিগুলোর ক্ষেত্রে সিভি হবে',
#  'ক্ষেত্রে সিভি হবে সিম্পল',
#  'সিভি হবে সিম্পল কিন্তু',
#  'হবে সিম্পল কিন্তু বেশ',
#  'সিম্পল কিন্তু বেশ ঝকঝকে',
#  'কিন্তু বেশ ঝকঝকে ।',
#  'বেশ ঝকঝকে । মিথ্যা',
#  'ঝকঝকে । মিথ্যা কোনো',
#  '। মিথ্যা কোনো ইনফরমেশন',
#  'মিথ্যা কোনো ইনফরমেশন দেওয়া',
#  'কোনো ইনফরমেশন দেওয়া যাবেনা',
#  'ইনফরমেশন দেওয়া যাবেনা ।',
#  'দেওয়া যাবেনা । আপনার',
#  'যাবেনা । আপনার বিশ্ববিদ্যালয়ের',
#  '। আপনার বিশ্ববিদ্যালয়ের থিসিস',
#  'আপনার বিশ্ববিদ্যালয়ের থিসিস সুপারভাইজর',
#  'বিশ্ববিদ্যালয়ের থিসিস সুপারভাইজর বা',
#  'থিসিস সুপারভাইজর বা শিক্ষক',
#  'সুপারভাইজর বা শিক্ষক বা',
#  'বা শিক্ষক বা আপনার',
#  'শিক্ষক বা আপনার কর্মক্ষেত্রের',
#  'বা আপনার কর্মক্ষেত্রের বস',
#  'আপনার কর্মক্ষেত্রের বস থেকে',
#  'কর্মক্ষেত্রের বস থেকে আপনার',
#  'বস থেকে আপনার দুটো',
#  'থেকে আপনার দুটো রেফারেন্স',
#  'আপনার দুটো রেফারেন্স লেটার',
#  'দুটো রেফারেন্স লেটার লাগবে',
#  'রেফারেন্স লেটার লাগবে ।',
#  'লেটার লাগবে । এ',
#  'লাগবে । এ ক্ষেত্রে',
#  '। এ ক্ষেত্রে যে',
#  'এ ক্ষেত্রে যে আপনাকে',
#  'ক্ষেত্রে যে আপনাকে রেফারেন্স',
#  'যে আপনাকে রেফারেন্স দিবে',
#  'আপনাকে রেফারেন্স দিবে অর্থাৎ',
#  'রেফারেন্স দিবে অর্থাৎ রেফারির',
#  'দিবে অর্থাৎ রেফারির যোগ্যতাও',
#  'অর্থাৎ রেফারির যোগ্যতাও সেই',
#  'রেফারির যোগ্যতাও সেই লেভেলের',
#  'যোগ্যতাও সেই লেভেলের হতে',
#  'সেই লেভেলের হতে হবে',
#  'লেভেলের হতে হবে ।',
#  'হতে হবে । সে',
#  'হবে । সে আপনার',
#  '। সে আপনার যোগ্যতা',
#  'সে আপনার যোগ্যতা দুর্বলতা',
#  'আপনার যোগ্যতা দুর্বলতা এবং',
#  'যোগ্যতা দুর্বলতা এবং পোটেনশিয়াল',
#  'দুর্বলতা এবং পোটেনশিয়াল সম্পর্কে',
#  'এবং পোটেনশিয়াল সম্পর্কে জানবে',
#  'পোটেনশিয়াল সম্পর্কে জানবে ।',
#  'সম্পর্কে জানবে । কাজেই',
#  'জানবে । কাজেই রেফারি',
#  '। কাজেই রেফারি নির্বাচনের',
#  'কাজেই রেফারি নির্বাচনের ক্ষেত্রে',
#  'রেফারি নির্বাচনের ক্ষেত্রে সতর্ক',
#  'নির্বাচনের ক্ষেত্রে সতর্ক হোন',
#  'ক্ষেত্রে সতর্ক হোন এবং',
#  'সতর্ক হোন এবং আগে',
#  'হোন এবং আগে থেকেই',
#  'এবং আগে থেকেই সুসম্পর্ক',
#  'আগে থেকেই সুসম্পর্ক বজায়',
#  'থেকেই সুসম্পর্ক বজায় রাখুন',
#  'সুসম্পর্ক বজায় রাখুন ।',
#  'বজায় রাখুন । নিজের',
#  'রাখুন । নিজের যোগ্যতা',
#  '। নিজের যোগ্যতা দিয়ে',
#  'নিজের যোগ্যতা দিয়ে সুসম্পর্ক',
#  'যোগ্যতা দিয়ে সুসম্পর্ক বজায়',
#  'দিয়ে সুসম্পর্ক বজায় রাখবেন',
#  'সুসম্পর্ক বজায় রাখবেন ।',
#  'বজায় রাখবেন । মাথায়',
#  'রাখবেন । মাথায় রাখবেন',
#  '। মাথায় রাখবেন আপনাকে',
#  'মাথায় রাখবেন আপনাকে কেউ',
#  'রাখবেন আপনাকে কেউ কিছু',
#  'আপনাকে কেউ কিছু মুখে',
#  'কেউ কিছু মুখে তুলে',
#  'কিছু মুখে তুলে খাওয়াবে',
#  'মুখে তুলে খাওয়াবে না',
#  'তুলে খাওয়াবে না ।',
#  'খাওয়াবে না । কষ্ট',
#  'না । কষ্ট করতে',
#  '। কষ্ট করতে হবে',
#  'কষ্ট করতে হবে ।',
#  'করতে হবে । নিজের',
#  'হবে । নিজের সাথে',
#  '। নিজের সাথে প্রতিযোগিতা',
#  'নিজের সাথে প্রতিযোগিতা করতে',
#  'সাথে প্রতিযোগিতা করতে হবে',
#  'প্রতিযোগিতা করতে হবে ।',
#  'করতে হবে । জেলা',
#  'হবে । জেলা প্রশাসনের',
#  '। জেলা প্রশাসনের একজন',
#  'জেলা প্রশাসনের একজন এক্সিকিউটিভ',
#  'প্রশাসনের একজন এক্সিকিউটিভ ম্যাজিস্ট্রেটকে',
#  'একজন এক্সিকিউটিভ ম্যাজিস্ট্রেটকে এই',
#  'এক্সিকিউটিভ ম্যাজিস্ট্রেটকে এই দায়িত্ব',
#  'ম্যাজিস্ট্রেটকে এই দায়িত্ব দেওয়া',
#  'এই দায়িত্ব দেওয়া হয়',
#  'দায়িত্ব দেওয়া হয় ।',
#  'দেওয়া হয় । এনডিসির',
#  'হয় । এনডিসির কাজ',
#  '। এনডিসির কাজ হলো',
#  'এনডিসির কাজ হলো মূলত',
#  'কাজ হলো মূলত জেলা',
#  'হলো মূলত জেলা প্রশাসন',
#  'মূলত জেলা প্রশাসন এবং',
#  'জেলা প্রশাসন এবং জেলা',
#  'প্রশাসন এবং জেলা সংশ্লিষ্ট',
#  'এবং জেলা সংশ্লিষ্ট সকল',
#  'জেলা সংশ্লিষ্ট সকল সরকারি',
#  'সংশ্লিষ্ট সকল সরকারি বিষয়ে',
#  'সকল সরকারি বিষয়ে লজিস্টিকস',
#  'সরকারি বিষয়ে লজিস্টিকস সাপোর্ট',
#  'বিষয়ে লজিস্টিকস সাপোর্ট দেওয়া',
#  'লজিস্টিকস সাপোর্ট দেওয়া ।',
#  'সাপোর্ট দেওয়া । যেমন',
#  'দেওয়া । যেমন জেলায়',
#  '। যেমন জেলায় কোনো',
#  'যেমন জেলায় কোনো ভিআইপি',
#  'জেলায় কোনো ভিআইপি আসলে',
#  'কোনো ভিআইপি আসলে যথাযোগ্যভাবে',
#  'ভিআইপি আসলে যথাযোগ্যভাবে তার',
#  'আসলে যথাযোগ্যভাবে তার আবাসন',
#  'যথাযোগ্যভাবে তার আবাসন ও',
#  'তার আবাসন ও পরিবহন',
#  'আবাসন ও পরিবহন নিশ্চিত',
#  'ও পরিবহন নিশ্চিত করা',
#  'পরিবহন নিশ্চিত করা ।',
#  'নিশ্চিত করা । তার',
#  'করা । তার সফরসঙ্গীদের',
#  '। তার সফরসঙ্গীদের আবাসন',
#  'তার সফরসঙ্গীদের আবাসন আহার',
#  'সফরসঙ্গীদের আবাসন আহার ইত্যাদি',
#  'আবাসন আহার ইত্যাদি নিশ্চিত',
#  'আহার ইত্যাদি নিশ্চিত করা',
#  'ইত্যাদি নিশ্চিত করা এবং',
#  'নিশ্চিত করা এবং জেলার',
#  'করা এবং জেলার পরিবহন',
#  'এবং জেলার পরিবহন পুলের',
#  'জেলার পরিবহন পুলের গাড়ি',
#  'পরিবহন পুলের গাড়ি সার্কিট',
#  'পুলের গাড়ি সার্কিট হাউজ',
#  'গাড়ি সার্কিট হাউজ ব্যবস্থাপনা',
#  'সার্কিট হাউজ ব্যবস্থাপনা শ্রদ্ধেয়',
#  'হাউজ ব্যবস্থাপনা শ্রদ্ধেয় ডিসি',
#  'ব্যবস্থাপনা শ্রদ্ধেয় ডিসি স্যারের',
#  'শ্রদ্ধেয় ডিসি স্যারের বাংলোর',
#  'ডিসি স্যারের বাংলোর তদারকি',
#  'স্যারের বাংলোর তদারকি অফিসের',
#  'বাংলোর তদারকি অফিসের কার',
#  'তদারকি অফিসের কার কী',
#  'অফিসের কার কী লাগবে',
#  'কার কী লাগবে এক',
#  'কী লাগবে এক কথায়',
#  'লাগবে এক কথায় সবকিছু',
#  'এক কথায় সবকিছু দেখভাল',
#  'কথায় সবকিছু দেখভাল করতে',
#  'সবকিছু দেখভাল করতে হয়',
#  'দেখভাল করতে হয় এই',
#  'করতে হয় এই এনডিসির',
#  'হয় এই এনডিসির ।',
#  'এই এনডিসির । এনডিসির',
#  'এনডিসির । এনডিসির যেই',
#  '। এনডিসির যেই অফিশিয়াল',
#  'এনডিসির যেই অফিশিয়াল ফোন',
#  'যেই অফিশিয়াল ফোন আছে',
#  'অফিশিয়াল ফোন আছে সেটা',
#  'ফোন আছে সেটা কখনো',
#  'আছে সেটা কখনো বন্ধ',
#  'সেটা কখনো বন্ধ হয়না',
#  'কখনো বন্ধ হয়না ।',
#  'বন্ধ হয়না । রোজ',
#  'হয়না । রোজ কেয়ামতের',
#  '। রোজ কেয়ামতের দিনেও',
#  'রোজ কেয়ামতের দিনেও যদি',
#  'কেয়ামতের দিনেও যদি কেউ',
#  'দিনেও যদি কেউ ফোন',
#  'যদি কেউ ফোন করে',
#  'কেউ ফোন করে বলে',
#  'ফোন করে বলে স্যার',
#  'করে বলে স্যার গাড়ি',
#  'বলে স্যার গাড়ি লাগবে',
#  'স্যার গাড়ি লাগবে ।',
#  'গাড়ি লাগবে । থাকা',
#  'লাগবে । থাকা লাগবে',
#  '। থাকা লাগবে নরসিংদীতে',
#  'থাকা লাগবে নরসিংদীতে ।',
#  'লাগবে নরসিংদীতে । স্যার',
#  'নরসিংদীতে । স্যার এই',
#  '। স্যার এই সমস্যা',
#  'স্যার এই সমস্যা হয়েছে',
#  'এই সমস্যা হয়েছে ।',
#  'সমস্যা হয়েছে । সেটাও',
#  'হয়েছে । সেটাও এনডিসির',
#  '। সেটাও এনডিসির যেভাবেই',
#  'সেটাও এনডিসির যেভাবেই হোক',
#  'এনডিসির যেভাবেই হোক ম্যানেজ',
#  'যেভাবেই হোক ম্যানেজ করা',
#  'হোক ম্যানেজ করা লাগবে',
#  'ম্যানেজ করা লাগবে ।',
#  'করা লাগবে । এর',
#  'লাগবে । এর পাশাপাশি',
#  '। এর পাশাপাশি দাপ্তরিক',
#  'এর পাশাপাশি দাপ্তরিক কাজ',
#  'পাশাপাশি দাপ্তরিক কাজ এবং',
#  'দাপ্তরিক কাজ এবং বিচারিক',
#  'কাজ এবং বিচারিক কাজ',
#  'এবং বিচারিক কাজ তো',
#  'বিচারিক কাজ তো আছেই',
#  'কাজ তো আছেই ।',
#  'তো আছেই । আমি',
#  'আছেই । আমি তখনো',
#  '। আমি তখনো বুঝিনি',
#  'আমি তখনো বুঝিনি কী',
#  'তখনো বুঝিনি কী এক',
#  'বুঝিনি কী এক কর্মযজ্ঞ',
#  'কী এক কর্মযজ্ঞ আমার',
#  'এক কর্মযজ্ঞ আমার জন্য',
#  'কর্মযজ্ঞ আমার জন্য অপেক্ষা',
#  'আমার জন্য অপেক্ষা করছিলো',
#  'জন্য অপেক্ষা করছিলো ।',
#  'অপেক্ষা করছিলো । আমি',
#  'করছিলো । আমি মাননীয়',
#  '। আমি মাননীয় প্রধানমন্ত্রীর',
#  'আমি মাননীয় প্রধানমন্ত্রীর কার্যালয়ের',
#  'মাননীয় প্রধানমন্ত্রীর কার্যালয়ের এটুআই',
#  'প্রধানমন্ত্রীর কার্যালয়ের এটুআই থেকে',
#  'কার্যালয়ের এটুআই থেকে মেইল',
#  'এটুআই থেকে মেইল ফোন',
#  'থেকে মেইল ফোন কল',
#  'মেইল ফোন কল পেতে',
#  'ফোন কল পেতে থাকলাম',
#  'কল পেতে থাকলাম ।',
#  'পেতে থাকলাম । সময়',
#  'থাকলাম । সময় গড়ায়',
#  '। সময় গড়ায় আর',
#  'সময় গড়ায় আর মেইল',
#  'গড়ায় আর মেইল ফোন',
#  'আর মেইল ফোন কলের',
#  'মেইল ফোন কলের গতি',
#  'ফোন কলের গতি বাড়ে',
#  'কলের গতি বাড়ে ।',
#  'গতি বাড়ে । তাদের',
#  'বাড়ে । তাদের কাজ',
#  '। তাদের কাজ ছিলো',
#  'তাদের কাজ ছিলো নরসিংদীর',
#  'কাজ ছিলো নরসিংদীর পুরো',
#  'ছিলো নরসিংদীর পুরো জেলার',
#  'নরসিংদীর পুরো জেলার সিক্যিউরিটি',
#  'পুরো জেলার সিক্যিউরিটি এনশিউর',
#  'জেলার সিক্যিউরিটি এনশিউর করা',
#  'সিক্যিউরিটি এনশিউর করা ।',
#  'এনশিউর করা । তাদের',
#  'করা । তাদের আবাসন',
#  '। তাদের আবাসন গাড়িসহ',
#  'তাদের আবাসন গাড়িসহ সকল',
#  'আবাসন গাড়িসহ সকল ধরণের',
#  'গাড়িসহ সকল ধরণের রিকোয়ারমেন্টের',
#  'সকল ধরণের রিকোয়ারমেন্টের দায়িত্ব',
#  'ধরণের রিকোয়ারমেন্টের দায়িত্ব যথারীতি',
#  'রিকোয়ারমেন্টের দায়িত্ব যথারীতি পড়লো',
#  'দায়িত্ব যথারীতি পড়লো আমার',
#  'যথারীতি পড়লো আমার কাঁধে',
#  'পড়লো আমার কাঁধে ।',
#  'আমার কাঁধে । নিরাপত্তা',
#  'কাঁধে । নিরাপত্তা ইস্যু',
#  '। নিরাপত্তা ইস্যু হিসেবে',
#  'নিরাপত্তা ইস্যু হিসেবে তারিখের',
#  'ইস্যু হিসেবে তারিখের প্রোগ্রামে',
#  'হিসেবে তারিখের প্রোগ্রামে কারা',
#  'তারিখের প্রোগ্রামে কারা কারা',
#  'প্রোগ্রামে কারা কারা থাকবে',
#  'কারা কারা থাকবে তাদের',
#  'কারা থাকবে তাদের সিক্যিউরিটি',
#  'থাকবে তাদের সিক্যিউরিটি ক্লিয়ারেন্সের',
#  'তাদের সিক্যিউরিটি ক্লিয়ারেন্সের জন্য',
#  'সিক্যিউরিটি ক্লিয়ারেন্সের জন্য ডিএসবি',
#  'ক্লিয়ারেন্সের জন্য ডিএসবি পাস',
#  'জন্য ডিএসবি পাস করানো',
#  'ডিএসবি পাস করানো থেকে',
#  'পাস করানো থেকে শুরু',
#  'করানো থেকে শুরু করে',
#  'থেকে শুরু করে সবকিছু',
#  'শুরু করে সবকিছু খেয়াল',
#  'করে সবকিছু খেয়াল রাখতে',
#  'সবকিছু খেয়াল রাখতে হলো',
#  'খেয়াল রাখতে হলো ।',
#  'রাখতে হলো । তারিখ',
#  'হলো । তারিখ আসলো',
#  '। তারিখ আসলো সেনাবাহিনীর',
#  'তারিখ আসলো সেনাবাহিনীর ডগ',
#  'আসলো সেনাবাহিনীর ডগ ।',
#  'সেনাবাহিনীর ডগ । স্কোয়াড',
#  'ডগ । স্কোয়াড ।',
#  '। স্কোয়াড । ফোন',
#  'স্কোয়াড । ফোন দিয়ে',
#  '। ফোন দিয়ে বললো',
#  'ফোন দিয়ে বললো স্যার',
#  'দিয়ে বললো স্যার আমরা',
#  'বললো স্যার আমরা মেম্বার',
#  'স্যার আমরা মেম্বার আর',
#  'আমরা মেম্বার আর ছয়টা',
#  'মেম্বার আর ছয়টা কুকুর',
#  'আর ছয়টা কুকুর থাকার',
#  'ছয়টা কুকুর থাকার ব্যবস্থা',
#  'কুকুর থাকার ব্যবস্থা করেন',
#  'থাকার ব্যবস্থা করেন ।',
#  'ব্যবস্থা করেন । আমার',
#  'করেন । আমার তখন',
#  '। আমার তখন অলরেডি',
#  'আমার তখন অলরেডি সার্কিট',
#  'তখন অলরেডি সার্কিট হাউজ',
#  'অলরেডি সার্কিট হাউজ ফুল',
#  'সার্কিট হাউজ ফুল ।',
#  'হাউজ ফুল । ম্যানেজ',
#  'ফুল । ম্যানেজ করলাম',
#  '। ম্যানেজ করলাম ।',
#  'ম্যানেজ করলাম । নেভির',
#  'করলাম । নেভির ডাইভার',
#  '। নেভির ডাইভার দল',
#  'নেভির ডাইভার দল ফোন',
#  'ডাইভার দল ফোন দিয়ে',
#  'দল ফোন দিয়ে বললো',
#  'ফোন দিয়ে বললো স্যার',
#  'দিয়ে বললো স্যার আমরা',
#  'বললো স্যার আমরা আসতেছি',
#  'স্যার আমরা আসতেছি ।',
#  'আমরা আসতেছি । থাকবো',
#  'আসতেছি । থাকবো ম্যানেজ',
#  '। থাকবো ম্যানেজ করেন',
#  'থাকবো ম্যানেজ করেন ।',
#  'ম্যানেজ করেন । সেনাবাহিনীর',
#  'করেন । সেনাবাহিনীর সিক্যিউরিটি',
#  '। সেনাবাহিনীর সিক্যিউরিটি সুইপিং',
#  'সেনাবাহিনীর সিক্যিউরিটি সুইপিং টিম',
#  'সিক্যিউরিটি সুইপিং টিম আসলো',
#  'সুইপিং টিম আসলো একটা',
#  'টিম আসলো একটা আবাসনের',
#  'আসলো একটা আবাসনের ব্যবস্থা',
#  'একটা আবাসনের ব্যবস্থা করলাম',
#  'আবাসনের ব্যবস্থা করলাম তাদেরও',
#  'ব্যবস্থা করলাম তাদেরও ।',
#  'করলাম তাদেরও । রাণী',
#  'তাদেরও । রাণী আসার',
#  '। রাণী আসার কথা',
#  'রাণী আসার কথা সড়ক',
#  'আসার কথা সড়ক পথে',
#  'কথা সড়ক পথে কিন্তু',
#  'সড়ক পথে কিন্তু হেলিপ্যাড',
#  'পথে কিন্তু হেলিপ্যাড রেডি',
#  'কিন্তু হেলিপ্যাড রেডি করতে',
#  'হেলিপ্যাড রেডি করতে হবে',
#  'রেডি করতে হবে ।',
#  'করতে হবে । গণপূর্তের',
#  'হবে । গণপূর্তের নির্বাহী',
#  '। গণপূর্তের নির্বাহী প্রকৌশলী',
#  'গণপূর্তের নির্বাহী প্রকৌশলী মহোদয়কে',
#  'নির্বাহী প্রকৌশলী মহোদয়কে বললাম',
#  'প্রকৌশলী মহোদয়কে বললাম স্টেডিয়ামে',
#  'মহোদয়কে বললাম স্টেডিয়ামে হেলিপ্যাড',
#  'বললাম স্টেডিয়ামে হেলিপ্যাড বানান',
#  'স্টেডিয়ামে হেলিপ্যাড বানান ।',
#  'হেলিপ্যাড বানান । বানানো',
#  'বানান । বানানো হলো',
#  '। বানানো হলো ।',
#  'বানানো হলো । মোটরকেড',
#  'হলো । মোটরকেড এবং',
#  '। মোটরকেড এবং নিরাপত্তার',
#  'মোটরকেড এবং নিরাপত্তার দায়িত্বে',
#  'এবং নিরাপত্তার দায়িত্বে থাকা',
#  'নিরাপত্তার দায়িত্বে থাকা অফিসারের',
#  'দায়িত্বে থাকা অফিসারের জন্য',
#  'থাকা অফিসারের জন্য প্রচুর',
#  'অফিসারের জন্য প্রচুর গাড়ি',
#  'জন্য প্রচুর গাড়ি লাগবে',
#  'প্রচুর গাড়ি লাগবে ।',
#  'গাড়ি লাগবে । করলাম',
#  'লাগবে । করলাম ম্যানেজ',
#  '। করলাম ম্যানেজ ।',
#  'করলাম ম্যানেজ । এর',
#  'ম্যানেজ । এর মাঝে',
#  '। এর মাঝে হঠাত',
#  'এর মাঝে হঠাত বলা',
#  'মাঝে হঠাত বলা হলো',
#  'হঠাত বলা হলো রাণী',
#  'বলা হলো রাণী যদি',
#  'হলো রাণী যদি লাঞ্চ',
#  'রাণী যদি লাঞ্চ করতে',
#  'যদি লাঞ্চ করতে চায়',
#  'লাঞ্চ করতে চায় তাহলে',
#  'করতে চায় তাহলে মেন্যু',
#  'চায় তাহলে মেন্যু কী',
#  'তাহলে মেন্যু কী হবে',
#  'মেন্যু কী হবে ।',
#  'কী হবে । নেট',
#  'হবে । নেট ঘেঁটে',
#  '। নেট ঘেঁটে ডাচদের',
#  'নেট ঘেঁটে ডাচদের খাবারের',
#  'ঘেঁটে ডাচদের খাবারের আইডিয়া',
#  'ডাচদের খাবারের আইডিয়া নিলাম',
#  'খাবারের আইডিয়া নিলাম ।',
#  'আইডিয়া নিলাম । আমার',
#  'নিলাম । আমার বউকেও',
#  '। আমার বউকেও বললাম',
#  'আমার বউকেও বললাম হেল্প',
#  'বউকেও বললাম হেল্প করতে',
#  'বললাম হেল্প করতে ।',
#  'হেল্প করতে । যদিও',
#  'করতে । যদিও ওটা',
#  '। যদিও ওটা পরে',
#  'যদিও ওটা পরে আর',
#  'ওটা পরে আর প্রয়োজন',
#  'পরে আর প্রয়োজন হয়নি',
#  'আর প্রয়োজন হয়নি ।',
#  'প্রয়োজন হয়নি । রাণীর',
#  'হয়নি । রাণীর জন্য',
#  '। রাণীর জন্য মেডিকেল',
#  'রাণীর জন্য মেডিকেল টিম',
#  'জন্য মেডিকেল টিম ফায়ার',
#  'মেডিকেল টিম ফায়ার সার্ভিস',
#  'টিম ফায়ার সার্ভিস ফুড',
#  'ফায়ার সার্ভিস ফুড এক্সামিনার',
#  'সার্ভিস ফুড এক্সামিনার সহ',
#  'ফুড এক্সামিনার সহ সকল',
#  'এক্সামিনার সহ সকল কিছু',
#  'সহ সকল কিছু রেডি',
#  'সকল কিছু রেডি রাখলাম',
#  'কিছু রেডি রাখলাম ।',
#  'রেডি রাখলাম । রাণীকে',
#  'রাখলাম । রাণীকে আমাদের',
#  '। রাণীকে আমাদের জেলা',
#  'রাণীকে আমাদের জেলা প্রশাসক',
#  'আমাদের জেলা প্রশাসক স্যার',
#  'জেলা প্রশাসক স্যার নরসিংদী',
#  'প্রশাসক স্যার নরসিংদী জেলার',
#  'স্যার নরসিংদী জেলার একটা',
#  'নরসিংদী জেলার একটা টোকেন',
#  'জেলার একটা টোকেন গিফট',
#  'একটা টোকেন গিফট দিবে',
#  'টোকেন গিফট দিবে ।',
#  'গিফট দিবে । সেটাও',
#  'দিবে । সেটাও রেডি',
#  '। সেটাও রেডি করলাম',
#  'সেটাও রেডি করলাম ।',
#  ...]

# %%
# integer encode sequences of words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(lines)
sequences = tokenizer.texts_to_sequences(lines)
# vocabulary size
vocab_size = len(tokenizer.word_index) + 1

# %%
sequences
# Out:
# [[10369, 2568, 49, 20],
#  [2568, 49, 20, 1],
#  [49, 20, 1, 18],
#  [20, 1, 18, 92],
#  [1, 18, 92, 17],
#  [18, 92, 17, 280],
#  [92, 17, 280, 512],
#  [17, 280, 512, 400],
#  [280, 512, 400, 400],
#  [512, 400, 400, 3419],
#  [400, 400, 3419, 1379],
#  [400, 3419, 1379, 3420],
#  [3419, 1379, 3420, 3421],
#  [1379, 3420, 3421, 45],
#  [3420, 3421, 45, 1380],
#  [3421, 45, 1380, 669],
#  [45, 1380, 669, 92],
#  [1380, 669, 92, 456],
#  [669, 92, 456, 1],
#  [92, 456, 1, 4],
#  [456, 1, 4, 1950],
#  [1, 4, 1950, 135],
#  [4, 1950, 135, 1381],
#  [1950, 135, 1381, 84],
#  [135, 1381, 84, 670],
#  [1381, 84, 670, 3422],
#  [84, 670, 3422, 1],
#  [670, 3422, 1, 153],
#  [3422, 1, 153, 3423],
#  [1, 153, 3423, 1381],
#  [153, 3423, 1381, 11],
#  [3423, 1381, 11, 610],
#  [1381, 11, 610, 382],
#  [11, 610, 382, 106],
#  [610, 382, 106, 1],
#  [382, 106, 1, 35],
#  [106, 1, 35, 1381],
#  [1, 35, 1381, 3],
#  [35, 1381, 3, 3424],
#  [1381, 3, 3424, 76],
#  [3, 3424, 76, 3],
#  [3424, 76, 3, 1951],
#  [76, 3, 1951, 211],
#  [3, 1951, 211, 1],
#  [1951, 211, 1, 3425],
#  [211, 1, 3425, 159],
#  [1, 3425, 159, 159],
#  [3425, 159, 159, 2569],
#  [159, 159, 2569, 26],
#  [159, 2569, 26, 1],
#  [2569, 26, 1, 611],
#  [26, 1, 611, 336],
#  [1, 611, 336, 1],
#  [611, 336, 1, 38],
#  [336, 1, 38, 425],
#  [1, 38, 425, 1668],
#  [38, 425, 1668, 749],
#  [425, 1668, 749, 513],
#  [1668, 749, 513, 204],
#  [749, 513, 204, 2570],
#  [513, 204, 2570, 18],
#  [204, 2570, 18, 1669],
#  [2570, 18, 1669, 3426],
#  [18, 1669, 3426, 110],
#  [1669, 3426, 110, 3],
#  [3426, 110, 3, 1],
#  [110, 3, 1, 749],
#  [3, 1, 749, 922],
#  [1, 749, 922, 176],
#  [749, 922, 176, 2571],
#  [922, 176, 2571, 457],
#  [176, 2571, 457, 750],
#  [2571, 457, 750, 189],
#  [457, 750, 189, 1022],
#  [750, 189, 1022, 92],
#  [189, 1022, 92, 612],
#  [1022, 92, 612, 247],
#  [92, 612, 247, 671],
#  [612, 247, 671, 54],
#  [247, 671, 54, 824],
#  [671, 54, 824, 51],
#  [54, 824, 51, 1199],
#  [824, 51, 1199, 2572],
#  [51, 1199, 2572, 205],
#  [1199, 2572, 205, 1],
#  [2572, 205, 1, 321],
#  [205, 1, 321, 3427],
#  [1, 321, 3427, 19],
#  [321, 3427, 19, 3428],
#  [3427, 19, 3428, 1952],
#  [19, 3428, 1952, 8],
#  [3428, 1952, 8, 2573],
#  [1952, 8, 2573, 672],
#  [8, 2573, 672, 10],
#  [2573, 672, 10, 6],
#  [672, 10, 6, 220],
#  [10, 6, 220, 673],
#  [6, 220, 673, 8],
#  [220, 673, 8, 1023],
#  [673, 8, 1023, 426],
#  [8, 1023, 426, 2574],
#  [1023, 426, 2574, 1],
#  [426, 2574, 1, 8],
#  [2574, 1, 8, 923],
#  [1, 8, 923, 1670],
#  [8, 923, 1670, 5986],
#  [923, 1670, 5986, 337],
#  [1670, 5986, 337, 1],
#  [5986, 337, 1, 136],
#  [337, 1, 136, 190],
#  [1, 136, 190, 3429],
#  [136, 190, 3429, 1],
#  [190, 3429, 1, 344],
#  [3429, 1, 344, 6],
#  [1, 344, 6, 1382],
#  [344, 6, 1382, 673],
#  [6, 1382, 673, 1953],
#  [1382, 673, 1953, 1023],
#  [673, 1953, 1023, 16],
#  [1953, 1023, 16, 749],
#  [1023, 16, 749, 513],
#  [16, 749, 513, 204],
#  [749, 513, 204, 824],
#  [513, 204, 824, 41],
#  [204, 824, 41, 1],
#  [824, 41, 1, 1954],
#  [41, 1, 1954, 168],
#  [1, 1954, 168, 177],
#  [1954, 168, 177, 294],
#  [168, 177, 294, 84],
#  [177, 294, 84, 2575],
#  [294, 84, 2575, 3430],
#  [84, 2575, 3430, 3431],
#  [2575, 3430, 3431, 514],
#  [3430, 3431, 514, 1955],
#  [3431, 514, 1955, 2576],
#  [514, 1955, 2576, 824],
#  [1955, 2576, 824, 265],
#  [2576, 824, 265, 674],
#  [824, 265, 674, 1382],
#  [265, 674, 1382, 673],
#  [674, 1382, 673, 1],
#  [1382, 673, 1, 1671],
#  [673, 1, 1671, 513],
#  [1, 1671, 513, 204],
#  [1671, 513, 204, 16],
#  [513, 204, 16, 1200],
#  [204, 16, 1200, 458],
#  [16, 1200, 458, 671],
#  [1200, 458, 671, 1024],
#  [458, 671, 1024, 1],
#  [671, 1024, 1, 459],
#  [1024, 1, 459, 3432],
#  [1, 459, 3432, 30],
#  [459, 3432, 30, 3433],
#  [3432, 30, 3433, 825],
#  [30, 3433, 825, 3434],
#  [3433, 825, 3434, 1],
#  [825, 3434, 1, 675],
#  [3434, 1, 675, 191],
#  [1, 675, 191, 1956],
#  [675, 191, 1956, 1957],
#  [191, 1956, 1957, 3435],
#  [1956, 1957, 3435, 295],
#  [1957, 3435, 295, 212],
#  [3435, 295, 212, 181],
#  [295, 212, 181, 345],
#  [212, 181, 345, 295],
#  [181, 345, 295, 102],
#  [345, 295, 102, 3436],
#  [295, 102, 3436, 116],
#  [102, 3436, 116, 26],
#  [3436, 116, 26, 62],
#  [116, 26, 62, 21],
#  [26, 62, 21, 3437],
#  [62, 21, 3437, 50],
#  [21, 3437, 50, 1],
#  [3437, 50, 1, 37],
#  [50, 1, 37, 924],
#  [1, 37, 924, 182],
#  [37, 924, 182, 248],
#  [924, 182, 248, 30],
#  [182, 248, 30, 37],
#  [248, 30, 37, 3438],
#  [30, 37, 3438, 3439],
#  [37, 3438, 3439, 751],
#  [3438, 3439, 751, 3440],
#  [3439, 751, 3440, 35],
#  [751, 3440, 35, 4],
#  [3440, 35, 4, 1383],
#  [35, 4, 1383, 16],
#  [4, 1383, 16, 294],
#  [1383, 16, 294, 25],
#  [16, 294, 25, 322],
#  [294, 25, 322, 1],
#  [25, 322, 1, 2577],
#  [322, 1, 2577, 752],
#  [1, 2577, 752, 199],
#  [2577, 752, 199, 120],
#  [752, 199, 120, 29],
#  [199, 120, 29, 3441],
#  [120, 29, 3441, 21],
#  [29, 3441, 21, 53],
#  [3441, 21, 53, 515],
#  [21, 53, 515, 1384],
#  [53, 515, 1384, 1385],
#  [515, 1384, 1385, 554],
#  [1384, 1385, 554, 555],
#  [1385, 554, 555, 1],
#  [554, 555, 1, 1958],
#  [555, 1, 1958, 1386],
#  [1, 1958, 1386, 3442],
#  [1958, 1386, 3442, 676],
#  [1386, 3442, 676, 3443],
#  [3442, 676, 3443, 200],
#  [676, 3443, 200, 200],
#  [3443, 200, 200, 427],
#  [200, 200, 427, 1387],
#  [200, 427, 1387, 1959],
#  [427, 1387, 1959, 20],
#  [1387, 1959, 20, 1],
#  [1959, 20, 1, 3444],
#  [20, 1, 3444, 37],
#  [1, 3444, 37, 58],
#  [3444, 37, 58, 515],
#  [37, 58, 515, 383],
#  [58, 515, 383, 1201],
#  [515, 383, 1201, 3445],
#  [383, 1201, 3445, 294],
#  [1201, 3445, 294, 25],
#  [3445, 294, 25, 26],
#  [294, 25, 26, 7],
#  [25, 26, 7, 554],
#  [26, 7, 554, 555],
#  [7, 554, 555, 1672],
#  [554, 555, 1672, 35],
#  [555, 1672, 35, 1387],
#  [1672, 35, 1387, 16],
#  [35, 1387, 16, 294],
#  [1387, 16, 294, 25],
#  [16, 294, 25, 322],
#  [294, 25, 322, 1],
#  [25, 322, 1, 3446],
#  [322, 1, 3446, 1388],
#  [1, 3446, 1388, 1673],
#  [3446, 1388, 1673, 3447],
#  [1388, 1673, 3447, 281],
#  [1673, 3447, 281, 1],
#  [3447, 281, 1, 2578],
#  [281, 1, 2578, 1383],
#  [1, 2578, 1383, 2579],
#  [2578, 1383, 2579, 3448],
#  [1383, 2579, 3448, 1960],
#  [2579, 3448, 1960, 37],
#  [3448, 1960, 37, 16],
#  [1960, 37, 16, 13],
#  [37, 16, 13, 3449],
#  [16, 13, 3449, 26],
#  [13, 3449, 26, 1],
#  [3449, 26, 1, 1961],
#  [26, 1, 1961, 675],
#  [1, 1961, 675, 1962],
#  [1961, 675, 1962, 31],
#  [675, 1962, 31, 3450],
#  [1962, 31, 3450, 67],
#  [31, 3450, 67, 1],
#  [3450, 67, 1, 46],
#  [67, 1, 46, 99],
#  [1, 46, 99, 3451],
#  [46, 99, 3451, 1963],
#  [99, 3451, 1963, 47],
#  [3451, 1963, 47, 1],
#  [1963, 47, 1, 1964],
#  [47, 1, 1964, 1387],
#  [1, 1964, 1387, 3452],
#  [1964, 1387, 3452, 18],
#  [1387, 3452, 18, 1025],
#  [3452, 18, 1025, 3453],
#  [18, 1025, 3453, 401],
#  [1025, 3453, 401, 826],
#  [3453, 401, 826, 427],
#  [401, 826, 427, 3454],
#  [826, 427, 3454, 120],
#  [427, 3454, 120, 485],
#  [3454, 120, 485, 7],
#  [120, 485, 7, 460],
#  [485, 7, 460, 401],
#  [7, 460, 401, 485],
#  [460, 401, 485, 1961],
#  [401, 485, 1961, 824],
#  [485, 1961, 824, 1674],
#  [1961, 824, 1674, 1],
#  [824, 1674, 1, 3455],
#  [1674, 1, 3455, 1965],
#  [1, 3455, 1965, 296],
#  [3455, 1965, 296, 1],
#  [1965, 296, 1, 102],
#  [296, 1, 102, 514],
#  [1, 102, 514, 13],
#  [102, 514, 13, 2580],
#  [514, 13, 2580, 99],
#  [13, 2580, 99, 17],
#  [2580, 99, 17, 200],
#  [99, 17, 200, 200],
#  [17, 200, 200, 427],
#  [200, 200, 427, 4],
#  [200, 427, 4, 3456],
#  [427, 4, 3456, 3457],
#  [4, 3456, 3457, 1959],
#  [3456, 3457, 1959, 1],
#  [3457, 1959, 1, 1671],
#  [1959, 1, 1671, 513],
#  [1, 1671, 513, 204],
#  [1671, 513, 204, 16],
#  [513, 204, 16, 1200],
#  [204, 16, 1200, 458],
#  [16, 1200, 458, 671],
#  [1200, 458, 671, 1],
#  [458, 671, 1, 675],
#  [671, 1, 675, 3458],
#  [1, 675, 3458, 3459],
#  [675, 3458, 3459, 2581],
#  [3458, 3459, 2581, 3460],
#  [3459, 2581, 3460, 249],
#  [2581, 3460, 249, 1966],
#  [3460, 249, 1966, 2582],
#  [249, 1966, 2582, 1389],
#  [1966, 2582, 1389, 1026],
#  [2582, 1389, 1026, 16],
#  [1389, 1026, 16, 4],
#  [1026, 16, 4, 671],
#  [16, 4, 671, 1],
#  [4, 671, 1, 37],
#  [671, 1, 37, 827],
#  [1, 37, 827, 105],
#  [37, 827, 105, 128],
#  [827, 105, 128, 114],
#  [105, 128, 114, 31],
#  [128, 114, 31, 282],
#  [114, 31, 282, 1025],
#  [31, 282, 1025, 16],
#  [282, 1025, 16, 294],
#  [1025, 16, 294, 25],
#  [16, 294, 25, 322],
#  [294, 25, 322, 1],
#  [25, 322, 1, 1965],
#  [322, 1, 1965, 296],
#  [1, 1965, 296, 297],
#  [1965, 296, 297, 1],
#  [296, 297, 1, 3461],
#  [297, 1, 3461, 48],
#  [1, 3461, 48, 1960],
#  [3461, 48, 1960, 7],
#  [48, 1960, 7, 3462],
#  [1960, 7, 3462, 427],
#  [7, 3462, 427, 10],
#  [3462, 427, 10, 1385],
#  [427, 10, 1385, 554],
#  [10, 1385, 554, 555],
#  [1385, 554, 555, 199],
#  [554, 555, 199, 1],
#  [555, 199, 1, 2583],
#  [199, 1, 2583, 458],
#  [1, 2583, 458, 671],
#  [2583, 458, 671, 1],
#  [458, 671, 1, 753],
#  [671, 1, 753, 3463],
#  [1, 753, 3463, 30],
#  [753, 3463, 30, 3464],
#  [3463, 30, 3464, 925],
#  [30, 3464, 925, 926],
#  [3464, 925, 926, 169],
#  [925, 926, 169, 3465],
#  [926, 169, 3465, 1],
#  [169, 3465, 1, 828],
#  [3465, 1, 828, 3466],
#  [1, 828, 3466, 98],
#  [828, 3466, 98, 29],
#  [3466, 98, 29, 3467],
#  [98, 29, 3467, 3468],
#  [29, 3467, 3468, 1390],
#  [3467, 3468, 1390, 3469],
#  [3468, 1390, 3469, 1],
#  [1390, 3469, 1, 1025],
#  [3469, 1, 1025, 176],
#  [1, 1025, 176, 2584],
#  [1025, 176, 2584, 21],
#  [176, 2584, 21, 515],
#  [2584, 21, 515, 294],
#  [21, 515, 294, 25],
#  [515, 294, 25, 1675],
#  [294, 25, 1675, 1],
#  [25, 1675, 1, 3470],
#  [1675, 1, 3470, 294],
#  [1, 3470, 294, 1386],
#  [3470, 294, 1386, 26],
#  [294, 1386, 26, 1],
#  [1386, 26, 1, 105],
#  [26, 1, 105, 35],
#  [1, 105, 35, 1967],
#  [105, 35, 1967, 16],
#  [35, 1967, 16, 2585],
#  [1967, 16, 2585, 1391],
#  [16, 2585, 1391, 282],
#  [2585, 1391, 282, 1968],
#  [1391, 282, 1968, 206],
#  [282, 1968, 206, 427],
#  [1968, 206, 427, 3471],
#  [206, 427, 3471, 3],
#  [427, 3471, 3, 485],
#  [3471, 3, 485, 1],
#  [3, 485, 1, 2586],
#  [485, 1, 2586, 201],
#  [1, 2586, 201, 3472],
#  [2586, 201, 3472, 16],
#  [201, 3472, 16, 51],
#  [3472, 16, 51, 1202],
#  [16, 51, 1202, 48],
#  [51, 1202, 48, 824],
#  [1202, 48, 824, 7],
#  [48, 824, 7, 1203],
#  [824, 7, 1203, 1],
#  [7, 1203, 1, 213],
#  [1203, 1, 213, 3],
#  [1, 213, 3, 3473],
#  [213, 3, 3473, 2587],
#  [3, 3473, 2587, 3474],
#  [3473, 2587, 3474, 191],
#  [2587, 3474, 191, 3475],
#  [3474, 191, 3475, 55],
#  [191, 3475, 55, 16],
#  [3475, 55, 16, 181],
#  [55, 16, 181, 169],
#  [16, 181, 169, 3476],
#  [181, 169, 3476, 1],
#  [169, 3476, 1, 3477],
#  [3476, 1, 3477, 48],
#  [1, 3477, 48, 298],
#  [3477, 48, 298, 199],
#  [48, 298, 199, 1],
#  [298, 199, 1, 4],
#  [199, 1, 4, 1383],
#  [1, 4, 1383, 754],
#  [4, 1383, 754, 29],
#  [1383, 754, 29, 516],
#  [754, 29, 516, 3478],
#  [29, 516, 3478, 3479],
#  [516, 3478, 3479, 3480],
#  [3478, 3479, 3480, 257],
#  [3479, 3480, 257, 137],
#  [3480, 257, 137, 128],
#  [257, 137, 128, 515],
#  [137, 128, 515, 3481],
#  [128, 515, 3481, 128],
#  [515, 3481, 128, 927],
#  [3481, 128, 927, 3482],
#  [128, 927, 3482, 3483],
#  [927, 3482, 3483, 3484],
#  [3482, 3483, 3484, 1],
#  [3483, 3484, 1, 1967],
#  [3484, 1, 1967, 2588],
#  [1, 1967, 2588, 169],
#  [1967, 2588, 169, 48],
#  [2588, 169, 48, 1],
#  [169, 48, 1, 21],
#  [48, 1, 21, 677],
#  [1, 21, 677, 672],
#  [21, 677, 672, 2589],
#  [677, 672, 2589, 1],
#  [672, 2589, 1, 755],
#  [2589, 1, 755, 678],
#  [1, 755, 678, 427],
#  [755, 678, 427, 10],
#  [678, 427, 10, 35],
#  [427, 10, 35, 1385],
#  [10, 35, 1385, 554],
#  [35, 1385, 554, 555],
#  [1385, 554, 555, 679],
#  [554, 555, 679, 35],
#  [555, 679, 35, 3485],
#  [679, 35, 3485, 294],
#  [35, 3485, 294, 25],
#  [3485, 294, 25, 322],
#  [294, 25, 322, 1],
#  [25, 322, 1, 3486],
#  [322, 1, 3486, 238],
#  [1, 3486, 238, 199],
#  [3486, 238, 199, 1],
#  [238, 199, 1, 427],
#  [199, 1, 427, 554],
#  [1, 427, 554, 1392],
#  [427, 554, 1392, 96],
#  [554, 1392, 96, 3487],
#  [1392, 96, 3487, 294],
#  [96, 3487, 294, 25],
#  [3487, 294, 25, 26],
#  [294, 25, 26, 1],
#  [25, 26, 1, 675],
#  [26, 1, 675, 3488],
#  [1, 675, 3488, 3489],
#  [675, 3488, 3489, 1962],
#  [3488, 3489, 1962, 42],
#  [3489, 1962, 42, 3490],
#  [1962, 42, 3490, 138],
#  [42, 3490, 138, 46],
#  [3490, 138, 46, 99],
#  [138, 46, 99, 1],
#  [46, 99, 1, 755],
#  [99, 1, 755, 48],
#  [1, 755, 48, 3491],
#  [755, 48, 3491, 515],
#  [48, 3491, 515, 1027],
#  [3491, 515, 1027, 42],
#  [515, 1027, 42, 554],
#  [1027, 42, 554, 555],
#  [42, 554, 555, 41],
#  [554, 555, 41, 4],
#  [555, 41, 4, 3492],
#  [41, 4, 3492, 294],
#  [4, 3492, 294, 25],
#  [3492, 294, 25, 31],
#  [294, 25, 31, 1],
#  [25, 31, 1, 675],
#  [31, 1, 675, 3493],
#  [1, 675, 3493, 3494],
#  [675, 3493, 3494, 3495],
#  [3493, 3494, 3495, 16],
#  [3494, 3495, 16, 4],
#  [3495, 16, 4, 671],
#  [16, 4, 671, 238],
#  [4, 671, 238, 31],
#  [671, 238, 31, 1],
#  [238, 31, 1, 753],
#  [31, 1, 753, 13],
#  [1, 753, 13, 1393],
#  [753, 13, 1393, 199],
#  [13, 1393, 199, 1],
#  [1393, 199, 1, 1969],
#  [199, 1, 1969, 612],
#  [1, 1969, 612, 45],
#  [1969, 612, 45, 362],
#  [612, 45, 362, 149],
#  [45, 362, 149, 3496],
#  [362, 149, 3496, 206],
#  [149, 3496, 206, 1393],
#  [3496, 206, 1393, 1969],
#  [206, 1393, 1969, 3497],
#  [1393, 1969, 3497, 45],
#  [1969, 3497, 45, 485],
#  [3497, 45, 485, 1],
#  [45, 485, 1, 3498],
#  [485, 1, 3498, 176],
#  [1, 3498, 176, 1393],
#  [3498, 176, 1393, 26],
#  [176, 1393, 26, 3499],
#  [1393, 26, 3499, 18],
#  [26, 3499, 18, 169],
#  [3499, 18, 169, 2590],
#  [18, 169, 2590, 1],
#  [169, 2590, 1, 1028],
#  [2590, 1, 1028, 21],
#  [1, 1028, 21, 2591],
#  [1028, 21, 2591, 238],
#  [21, 2591, 238, 1394],
#  [2591, 238, 1394, 1],
#  [238, 1394, 1, 37],
#  [1394, 1, 37, 514],
#  [1, 37, 514, 2592],
#  [37, 514, 2592, 2593],
#  [514, 2592, 2593, 54],
#  [2592, 2593, 54, 1029],
#  [2593, 54, 1029, 54],
#  [54, 1029, 54, 37],
#  [1029, 54, 37, 3500],
#  [54, 37, 3500, 3501],
#  [37, 3500, 3501, 10],
#  [3500, 3501, 10, 37],
#  [3501, 10, 37, 257],
#  [10, 37, 257, 1970],
#  [37, 257, 1970, 555],
#  [257, 1970, 555, 199],
#  [1970, 555, 199, 1],
#  [555, 199, 1, 22],
#  [199, 1, 22, 176],
#  [1, 22, 176, 17],
#  [22, 176, 17, 206],
#  [176, 17, 206, 1970],
#  [17, 206, 1970, 485],
#  [206, 1970, 485, 829],
#  [1970, 485, 829, 3502],
#  [485, 829, 3502, 3503],
#  [829, 3502, 3503, 34],
#  [3502, 3503, 34, 1971],
#  [3503, 34, 1971, 116],
#  [34, 1971, 116, 26],
#  [1971, 116, 26, 1],
#  [116, 26, 1, 11],
#  [26, 1, 11, 37],
#  [1, 11, 37, 1395],
#  [11, 37, 1395, 2594],
#  [37, 1395, 2594, 30],
#  [1395, 2594, 30, 3504],
#  [2594, 30, 3504, 680],
#  [30, 3504, 680, 3505],
#  [3504, 680, 3505, 1],
#  [680, 3505, 1, 830],
#  [3505, 1, 830, 3506],
#  [1, 830, 3506, 3507],
#  [830, 3506, 3507, 176],
#  [3506, 3507, 176, 1676],
#  [3507, 176, 1676, 1391],
#  [176, 1676, 1391, 30],
#  [1676, 1391, 30, 58],
#  [1391, 30, 58, 250],
#  [30, 58, 250, 1972],
#  [58, 250, 1972, 1396],
#  [250, 1972, 1396, 1973],
#  [1972, 1396, 1973, 1],
#  [1396, 1973, 1, 68],
#  [1973, 1, 68, 1395],
#  [1, 68, 1395, 45],
#  [68, 1395, 45, 1972],
#  [1395, 45, 1972, 1396],
#  [45, 1972, 1396, 1030],
#  [1972, 1396, 1030, 1],
#  [1396, 1030, 1, 750],
#  [1030, 1, 750, 1030],
#  [1, 750, 1030, 206],
#  [750, 1030, 206, 97],
#  [1030, 206, 97, 32],
#  [206, 97, 32, 258],
#  [97, 32, 258, 384],
#  [32, 258, 384, 3508],
#  [258, 384, 3508, 2],
#  [384, 3508, 2, 1],
#  [3508, 2, 1, 229],
#  [2, 1, 229, 25],
#  [1, 229, 25, 26],
#  [229, 25, 26, 1],
#  [25, 26, 1, 68],
#  [26, 1, 68, 57],
#  [1, 68, 57, 1974],
#  [68, 57, 1974, 25],
#  [57, 1974, 25, 26],
#  [1974, 25, 26, 1],
#  [25, 26, 1, 1031],
#  [26, 1, 1031, 3509],
#  [1, 1031, 3509, 77],
#  [1031, 3509, 77, 3510],
#  [3509, 77, 3510, 3511],
#  [77, 3510, 3511, 4],
#  [3510, 3511, 4, 1032],
#  [3511, 4, 1032, 238],
#  [4, 1032, 238, 31],
#  [1032, 238, 31, 1],
#  [238, 31, 1, 1033],
#  [31, 1, 1033, 110],
#  [1, 1033, 110, 29],
#  [1033, 110, 29, 1975],
#  [110, 29, 1975, 1031],
#  [29, 1975, 1031, 3512],
#  [1975, 1031, 3512, 30],
#  [1031, 3512, 30, 1031],
#  [3512, 30, 1031, 2595],
#  [30, 1031, 2595, 486],
#  [1031, 2595, 486, 831],
#  [2595, 486, 831, 674],
#  [486, 831, 674, 3513],
#  [831, 674, 3513, 3514],
#  [674, 3513, 3514, 238],
#  [3513, 3514, 238, 1],
#  [3514, 238, 1, 149],
#  [238, 1, 149, 2596],
#  [1, 149, 2596, 21],
#  [149, 2596, 21, 3515],
#  [2596, 21, 3515, 299],
#  [21, 3515, 299, 3516],
#  [3515, 299, 3516, 9],
#  [299, 3516, 9, 1397],
#  [3516, 9, 1397, 5],
#  [9, 1397, 5, 1976],
#  [1397, 5, 1976, 832],
#  [5, 1976, 832, 43],
#  [1976, 832, 43, 1],
#  [832, 43, 1, 9],
#  [43, 1, 9, 3517],
#  [1, 9, 3517, 1397],
#  [9, 3517, 1397, 3518],
#  [3517, 1397, 3518, 265],
#  [1397, 3518, 265, 832],
#  [3518, 265, 832, 43],
#  [265, 832, 43, 30],
#  [832, 43, 30, 517],
#  [43, 30, 517, 1976],
#  [30, 517, 1976, 3519],
#  [517, 1976, 3519, 681],
#  [1976, 3519, 681, 1977],
#  [3519, 681, 1977, 1978],
#  [681, 1977, 1978, 3520],
#  [1977, 1978, 3520, 3521],
#  [1978, 3520, 3521, 1677],
#  [3520, 3521, 1677, 1979],
#  [3521, 1677, 1979, 3522],
#  [1677, 1979, 3522, 3523],
#  [1979, 3522, 3523, 1980],
#  [3522, 3523, 1980, 556],
#  [3523, 1980, 556, 15],
#  [1980, 556, 15, 199],
#  [556, 15, 199, 14],
#  [15, 199, 14, 1678],
#  [199, 14, 1678, 613],
#  [14, 1678, 613, 1981],
#  [1678, 613, 1981, 25],
#  [613, 1981, 25, 31],
#  [1981, 25, 31, 4],
#  [25, 31, 4, 1033],
#  [31, 4, 1033, 1],
#  [4, 1033, 1, 1033],
#  [1033, 1, 1033, 826],
#  [1, 1033, 826, 2597],
#  [1033, 826, 2597, 192],
#  [826, 2597, 192, 20],
#  [2597, 192, 20, 120],
#  [192, 20, 120, 111],
#  [20, 120, 111, 461],
#  [120, 111, 461, 1203],
#  [111, 461, 1203, 1],
#  [461, 1203, 1, 1204],
#  [1203, 1, 1204, 3524],
#  [1, 1204, 3524, 3525],
#  [1204, 3524, 3525, 105],
#  [3524, 3525, 105, 97],
#  [3525, 105, 97, 192],
#  [105, 97, 192, 3],
#  [97, 192, 3, 36],
#  [192, 3, 36, 178],
#  [3, 36, 178, 681],
#  [36, 178, 681, 199],
#  [178, 681, 199, 1],
#  [681, 199, 1, 298],
#  [199, 1, 298, 199],
#  [1, 298, 199, 3526],
#  [298, 199, 3526, 1],
#  [199, 3526, 1, 178],
#  [3526, 1, 178, 4],
#  [1, 178, 4, 833],
#  [178, 4, 833, 275],
#  [4, 833, 275, 1],
#  [833, 275, 1, 669],
#  [275, 1, 669, 1033],
#  [1, 669, 1033, 3527],
#  [669, 1033, 3527, 300],
#  [1033, 3527, 300, 928],
#  [3527, 300, 928, 43],
#  [300, 928, 43, 199],
#  [928, 43, 199, 1],
#  [43, 199, 1, 51],
#  [199, 1, 51, 385],
#  [1, 51, 385, 3528],
#  [51, 385, 3528, 110],
#  [385, 3528, 110, 30],
#  [3528, 110, 30, 3529],
#  [110, 30, 3529, 110],
#  [30, 3529, 110, 49],
#  [3529, 110, 49, 2598],
#  [110, 49, 2598, 1],
#  [49, 2598, 1, 6],
#  [2598, 1, 6, 1398],
#  [1, 6, 1398, 3530],
#  [6, 1398, 3530, 15],
#  [1398, 3530, 15, 14],
#  [3530, 15, 14, 3531],
#  [15, 14, 3531, 8],
#  [14, 3531, 8, 16],
#  [3531, 8, 16, 518],
#  [8, 16, 518, 2599],
#  [16, 518, 2599, 1],
#  [518, 2599, 1, 6],
#  [2599, 1, 6, 2600],
#  [1, 6, 2600, 2601],
#  [6, 2600, 2601, 2602],
#  [2600, 2601, 2602, 3532],
#  [2601, 2602, 3532, 10],
#  [2602, 3532, 10, 1034],
#  [3532, 10, 1034, 192],
#  [10, 1034, 192, 834],
#  [1034, 192, 834, 614],
#  [192, 834, 614, 1679],
#  [834, 614, 1679, 1],
#  [614, 1679, 1, 46],
#  [1679, 1, 46, 3533],
#  [1, 46, 3533, 7],
#  [46, 3533, 7, 1034],
#  [3533, 7, 1034, 192],
#  [7, 1034, 192, 756],
#  [1034, 192, 756, 1680],
#  [192, 756, 1680, 2603],
#  [756, 1680, 2603, 1],
#  [1680, 2603, 1, 55],
#  [2603, 1, 55, 110],
#  [1, 55, 110, 557],
#  [55, 110, 557, 3534],
#  [110, 557, 3534, 321],
#  [557, 3534, 321, 517],
#  [3534, 321, 517, 1399],
#  [321, 517, 1399, 3535],
#  [517, 1399, 3535, 43],
#  [1399, 3535, 43, 1],
#  [3535, 43, 1, 55],
#  [43, 1, 55, 1397],
#  [1, 55, 1397, 3536],
#  [55, 1397, 3536, 486],
#  [1397, 3536, 486, 2604],
#  [3536, 486, 2604, 3537],
#  [486, 2604, 3537, 1032],
#  [2604, 3537, 1032, 2605],
#  [3537, 1032, 2605, 3538],
#  [1032, 2605, 3538, 8],
#  [2605, 3538, 8, 929],
#  [3538, 8, 929, 1],
#  [8, 929, 1, 2606],
#  [929, 1, 2606, 3539],
#  [1, 2606, 3539, 207],
#  [2606, 3539, 207, 3540],
#  [3539, 207, 3540, 3541],
#  [207, 3540, 3541, 1982],
#  [3540, 3541, 1982, 1982],
#  [3541, 1982, 1982, 337],
#  [1982, 1982, 337, 55],
#  [1982, 337, 55, 1399],
#  [337, 55, 1399, 3542],
#  [55, 1399, 3542, 16],
#  [1399, 3542, 16, 3543],
#  [3542, 16, 3543, 1681],
#  [16, 3543, 1681, 3544],
#  [3543, 1681, 3544, 10],
#  [1681, 3544, 10, 76],
#  [3544, 10, 76, 3],
#  [10, 76, 3, 613],
#  [76, 3, 613, 1035],
#  [3, 613, 1035, 338],
#  [613, 1035, 338, 29],
#  [1035, 338, 29, 1],
#  [338, 29, 1, 1983],
#  [29, 1, 1983, 1984],
#  [1, 1983, 1984, 1400],
#  [1983, 1984, 1400, 3545],
#  [1984, 1400, 3545, 1],
#  [1400, 3545, 1, 3546],
#  [3545, 1, 3546, 1],
#  [1, 3546, 1, 192],
#  [3546, 1, 192, 45],
#  [1, 192, 45, 1985],
#  [192, 45, 1985, 178],
#  [45, 1985, 178, 92],
#  [1985, 178, 92, 1682],
#  [178, 92, 1682, 7],
#  [92, 1682, 7, 3547],
#  [1682, 7, 3547, 3548],
#  [7, 3547, 3548, 682],
#  [3547, 3548, 682, 462],
#  [3548, 682, 462, 56],
#  [682, 462, 56, 1],
#  [462, 56, 1, 8],
#  [56, 1, 8, 64],
#  [1, 8, 64, 3549],
#  [8, 64, 3549, 1977],
#  [64, 3549, 1977, 1978],
#  [3549, 1977, 1978, 1036],
#  [1977, 1978, 1036, 1],
#  [1978, 1036, 1, 928],
#  [1036, 1, 928, 230],
#  [1, 928, 230, 1],
#  [928, 230, 1, 3550],
#  [230, 1, 3550, 3551],
#  [1, 3550, 3551, 558],
#  [3550, 3551, 558, 192],
#  [3551, 558, 192, 45],
#  [558, 192, 45, 1985],
#  [192, 45, 1985, 178],
#  [45, 1985, 178, 92],
#  [1985, 178, 92, 3552],
#  [178, 92, 3552, 1],
#  [92, 3552, 1, 1683],
#  [3552, 1, 1683, 928],
#  [1, 1683, 928, 56],
#  [1683, 928, 56, 1],
#  [928, 56, 1, 1400],
#  [56, 1, 1400, 1399],
#  [1, 1400, 1399, 3553],
#  [1400, 1399, 3553, 1205],
#  [1399, 3553, 1205, 1984],
#  [3553, 1205, 1984, 13],
#  [1205, 1984, 13, 3554],
#  [1984, 13, 3554, 462],
#  [13, 3554, 462, 230],
#  [3554, 462, 230, 3555],
#  [462, 230, 3555, 1],
#  [230, 3555, 1, 1986],
#  [3555, 1, 1986, 363],
#  [1, 1986, 363, 12],
#  [1986, 363, 12, 1987],
#  [363, 12, 1987, 428],
#  [12, 1987, 428, 18],
#  [1987, 428, 18, 1988],
#  [428, 18, 1988, 835],
#  [18, 1988, 835, 25],
#  [1988, 835, 25, 26],
#  [835, 25, 26, 1],
#  [25, 26, 1, 3556],
#  [26, 1, 3556, 3557],
#  [1, 3556, 3557, 2607],
#  [3556, 3557, 2607, 3558],
#  [3557, 2607, 3558, 193],
#  [2607, 3558, 193, 3559],
#  [3558, 193, 3559, 1988],
#  [193, 3559, 1988, 3560],
#  [3559, 1988, 3560, 1],
#  [1988, 3560, 1, 1989],
#  [3560, 1, 1989, 29],
#  [1, 1989, 29, 1],
#  [1989, 29, 1, 3561],
#  [29, 1, 3561, 30],
#  [1, 3561, 30, 3562],
#  [3561, 30, 3562, 3563],
#  [30, 3562, 3563, 298],
#  [3562, 3563, 298, 3564],
#  [3563, 298, 3564, 16],
#  [298, 3564, 16, 2608],
#  [3564, 16, 2608, 681],
#  [16, 2608, 681, 199],
#  [2608, 681, 199, 1],
#  [681, 199, 1, 230],
#  [199, 1, 230, 928],
#  [1, 230, 928, 1],
#  [230, 928, 1, 51],
#  [928, 1, 51, 163],
#  [1, 51, 163, 2609],
#  [51, 163, 2609, 183],
#  [163, 2609, 183, 29],
#  [2609, 183, 29, 1986],
#  [183, 29, 1986, 105],
#  [29, 1986, 105, 2610],
#  [1986, 105, 2610, 25],
#  [105, 2610, 25, 301],
#  [2610, 25, 301, 282],
#  [25, 301, 282, 3565],
#  [301, 282, 3565, 15],
#  [282, 3565, 15, 26],
#  [3565, 15, 26, 1],
#  [15, 26, 1, 3566],
#  [26, 1, 3566, 3567],
#  [1, 3566, 3567, 3568],
#  [3566, 3567, 3568, 1206],
#  [3567, 3568, 1206, 1990],
#  [3568, 1206, 1990, 519],
#  [1206, 1990, 519, 1],
#  [1990, 519, 1, 8],
#  [519, 1, 8, 3569],
#  [1, 8, 3569, 193],
#  [8, 3569, 193, 2611],
#  [3569, 193, 2611, 25],
#  [193, 2611, 25, 1],
#  [2611, 25, 1, 487],
#  [25, 1, 487, 1401],
#  [1, 487, 1401, 173],
#  [487, 1401, 173, 7],
#  [1401, 173, 7, 429],
#  [173, 7, 429, 1037],
#  [7, 429, 1037, 1],
#  [429, 1037, 1, 3570],
#  [1037, 1, 3570, 16],
#  [1, 3570, 16, 1207],
#  [3570, 16, 1207, 1205],
#  [16, 1207, 1205, 2612],
#  [1207, 1205, 2612, 3571],
#  [1205, 2612, 3571, 2613],
#  [2612, 3571, 2613, 3572],
#  [3571, 2613, 3572, 1208],
#  [2613, 3572, 1208, 486],
#  [3572, 1208, 486, 32],
#  [1208, 486, 32, 835],
#  [486, 32, 835, 3573],
#  [32, 835, 3573, 1],
#  [835, 3573, 1, 3574],
#  [3573, 1, 3574, 38],
#  [1, 3574, 38, 1031],
#  [3574, 38, 1031, 3575],
#  [38, 1031, 3575, 178],
#  [1031, 3575, 178, 1991],
#  [3575, 178, 1991, 517],
#  [178, 1991, 517, 13],
#  [1991, 517, 13, 3576],
#  [517, 13, 3576, 2614],
#  [13, 3576, 2614, 485],
#  [3576, 2614, 485, 1],
#  [2614, 485, 1, 669],
#  [485, 1, 669, 835],
#  [1, 669, 835, 230],
#  [669, 835, 230, 1],
#  ...]

# %%
length = 4

# %%
print(len(sequences))
print(sequences[0][0])
# Out:
# 60235
# 10369

# %%
sequences = array(sequences)
sequences
# Out:
# array([list([10369, 2568, 49, 20]), list([2568, 49, 20, 1]),
#        list([49, 20, 1, 18]), ..., list([1329, 484, 1, 10368]),
#        list([484, 1, 10368, 4]), list([1, 10368, 4, 10370])], dtype=object)

# %%
c=1
h=0
while(c!=0):
    limit = sequences.size
    d =[]
    c=0
    for i in range(0 , limit):
        l=len(sequences[i])
        if(l!=length):
            print(sequences[i])
            sequences = np.delete(sequences, i, 0)
            
            c=1
            print("error at ", i)
            print("Deleting :_________________________ ") 
            h = h+1
            break        
print("Total deletion: ", h)
# Out:
# [7, 979, 20]
# error at  6667
# Deleting :_________________________
# [979, 20, 197]
# error at  6667
# Deleting :_________________________
# [20, 197, 6]
# error at  6667
# Deleting :_________________________
# [197, 6, 237]
# error at  6667
# Deleting :_________________________
# [10, 85, 148]
# error at  7719
# Deleting :_________________________
# [85, 148, 6]
# error at  7719
# Deleting :_________________________
# [148, 6, 4032]
# error at  7719
# Deleting :_________________________
# [6, 4032, 4033]
# error at  7719
# Deleting :_________________________
# [69, 2, 24]
# error at  7823
# Deleting :_________________________
# [2, 24, 24]
# error at  7823
# Deleting :_________________________
# [24, 24, 85]
# error at  7823
# Deleting :_________________________
# [24, 85, 174]
# error at  7823
# Deleting :_________________________
# [3, 69, 2]
# error at  7939
# Deleting :_________________________
# [69, 2, 6]
# error at  7939
# Deleting :_________________________
# [2, 6, 89]
# error at  7939
# Deleting :_________________________
# [6, 89, 12]
# error at  7939
# Deleting :_________________________
# [261, 193, 148]
# error at  7944
# Deleting :_________________________
# [193, 148, 24]
# error at  7944
# Deleting :_________________________
# [148, 24, 85]
# error at  7944
# Deleting :_________________________
# [24, 85, 88]
# error at  7944
# Deleting :_________________________
# [52, 2, 616]
# error at  7953
# Deleting :_________________________
# [2, 616, 6]
# error at  7953
# Deleting :_________________________
# [616, 6, 193]
# error at  7953
# Deleting :_________________________
# [6, 193, 148]
# error at  7953
# Deleting :_________________________
# [6, 193, 148]
# error at  7953
# Deleting :_________________________
# [193, 148, 24]
# error at  7953
# Deleting :_________________________
# [148, 24, 85]
# error at  7953
# Deleting :_________________________
# [24, 85, 6]
# error at  7953
# Deleting :_________________________
# [148, 4060, 24]
# error at  7992
# Deleting :_________________________
# [4060, 24, 24]
# error at  7992
# Deleting :_________________________
# [24, 24, 8]
# error at  7992
# Deleting :_________________________
# [24, 8, 67]
# error at  7992
# Deleting :_________________________
# [1511, 691, 73]
# error at  8205
# Deleting :_________________________
# [691, 73, 4078]
# error at  8205
# Deleting :_________________________
# [73, 4078, 1469]
# error at  8205
# Deleting :_________________________
# [4078, 1469, 4079]
# error at  8205
# Deleting :_________________________
# [86, 106, 4092]
# error at  8342
# Deleting :_________________________
# [106, 4092, 4093]
# error at  8342
# Deleting :_________________________
# [4092, 4093, 373]
# error at  8342
# Deleting :_________________________
# [4093, 373, 156]
# error at  8342
# Deleting :_________________________
# [71, 711, 232]
# error at  8515
# Deleting :_________________________
# [711, 232, 1233]
# error at  8515
# Deleting :_________________________
# [232, 1233, 2896]
# error at  8515
# Deleting :_________________________
# [1233, 2896, 881]
# error at  8515
# Deleting :_________________________
# [1413, 418, 15]
# error at  8531
# Deleting :_________________________
# [418, 15, 490]
# error at  8531
# Deleting :_________________________
# [15, 490, 4112]
# error at  8531
# Deleting :_________________________
# [490, 4112, 584]
# error at  8531
# Deleting :_________________________
# [15, 208, 1766]
# error at  8552
# Deleting :_________________________
# [208, 1766, 4114]
# error at  8552
# Deleting :_________________________
# [1766, 4114, 4]
# error at  8552
# Deleting :_________________________
# [4114, 4, 2194]
# error at  8552
# Deleting :_________________________
# [251, 208, 359]
# error at  8579
# Deleting :_________________________
# [208, 359, 35]
# error at  8579
# Deleting :_________________________
# [359, 35, 70]
# error at  8579
# Deleting :_________________________
# [35, 70, 236]
# error at  8579
# Deleting :_________________________
# [70, 236, 626]
# error at  8580
# Deleting :_________________________
# [236, 626, 1515]
# error at  8580
# Deleting :_________________________
# [626, 1515, 988]
# error at  8580
# Deleting :_________________________
# [1515, 988, 219]
# error at  8580
# Deleting :_________________________
# [1515, 988, 219]
# error at  8580
# Deleting :_________________________
# [988, 219, 35]
# error at  8580
# Deleting :_________________________
# [219, 35, 1515]
# error at  8580
# Deleting :_________________________
# [35, 1515, 4117]
# error at  8580
# Deleting :_________________________
# [1515, 4117, 4118]
# error at  8581
# Deleting :_________________________
# [4117, 4118, 33]
# error at  8581
# Deleting :_________________________
# [4118, 33, 37]
# error at  8581
# Deleting :_________________________
# [33, 37, 203]
# error at  8581
# Deleting :_________________________
# [37, 203, 799]
# error at  8582
# Deleting :_________________________
# [203, 799, 35]
# error at  8582
# Deleting :_________________________
# [799, 35, 1509]
# error at  8582
# Deleting :_________________________
# [35, 1509, 626]
# error at  8582
# Deleting :_________________________
# [35, 1509, 626]
# error at  8582
# Deleting :_________________________
# [1509, 626, 60]
# error at  8582
# Deleting :_________________________
# [626, 60, 1509]
# error at  8582
# Deleting :_________________________
# [60, 1509, 226]
# error at  8582
# Deleting :_________________________
# [70, 86, 651]
# error at  8600
# Deleting :_________________________
# [86, 651, 136]
# error at  8600
# Deleting :_________________________
# [651, 136, 226]
# error at  8600
# Deleting :_________________________
# [136, 226, 571]
# error at  8600
# Deleting :_________________________
# [120, 15, 297]
# error at  8616
# Deleting :_________________________
# [15, 297, 4]
# error at  8616
# Deleting :_________________________
# [297, 4, 1504]
# error at  8616
# Deleting :_________________________
# [4, 1504, 882]
# error at  8616
# Deleting :_________________________
# [882, 61, 219]
# error at  8641
# Deleting :_________________________
# [61, 219, 4]
# error at  8641
# Deleting :_________________________
# [219, 4, 158]
# error at  8641
# Deleting :_________________________
# [4, 158, 4123]
# error at  8641
# Deleting :_________________________
# [20, 1, 520]
# error at  8644
# Deleting :_________________________
# [1, 520, 955]
# error at  8644
# Deleting :_________________________
# [520, 955, 166]
# error at  8644
# Deleting :_________________________
# [955, 166, 1]
# error at  8644
# Deleting :_________________________
# [208, 244, 2]
# error at  8668
# Deleting :_________________________
# [244, 2, 258]
# error at  8668
# Deleting :_________________________
# [2, 258, 487]
# error at  8668
# Deleting :_________________________
# [258, 487, 398]
# error at  8668
# Deleting :_________________________
# [1, 171, 3]
# error at  8692
# Deleting :_________________________
# [171, 3, 1300]
# error at  8692
# Deleting :_________________________
# [3, 1300, 85]
# error at  8692
# Deleting :_________________________
# [1300, 85, 1504]
# error at  8692
# Deleting :_________________________
# [2199, 1507, 2200]
# error at  8707
# Deleting :_________________________
# [1507, 2200, 158]
# error at  8707
# Deleting :_________________________
# [2200, 158, 262]
# error at  8707
# Deleting :_________________________
# [158, 262, 13]
# error at  8707
# Deleting :_________________________
# [1, 15, 297]
# error at  8728
# Deleting :_________________________
# [15, 297, 321]
# error at  8728
# Deleting :_________________________
# [297, 321, 158]
# error at  8728
# Deleting :_________________________
# [321, 158, 1519]
# error at  8728
# Deleting :_________________________
# [365, 52, 111]
# error at  8755
# Deleting :_________________________
# [52, 111, 365]
# error at  8755
# Deleting :_________________________
# [111, 365, 52]
# error at  8755
# Deleting :_________________________
# [365, 52, 2]
# error at  8755
# Deleting :_________________________
# [2202, 2, 148]
# error at  8771
# Deleting :_________________________
# [2, 148, 11]
# error at  8771
# Deleting :_________________________
# [148, 11, 271]
# error at  8771
# Deleting :_________________________
# [11, 271, 49]
# error at  8771
# Deleting :_________________________
# [4139, 90, 4140]
# error at  8800
# Deleting :_________________________
# [90, 4140, 1269]
# error at  8800
# Deleting :_________________________
# [4140, 1269, 2899]
# error at  8800
# Deleting :_________________________
# [1269, 2899, 501]
# error at  8800
# Deleting :_________________________
# [90, 392, 876]
# error at  8806
# Deleting :_________________________
# [392, 876, 62]
# error at  8806
# Deleting :_________________________
# [876, 62, 12]
# error at  8806
# Deleting :_________________________
# [62, 12, 111]
# error at  8806
# Deleting :_________________________
# [7, 97, 50]
# error at  8836
# Deleting :_________________________
# [97, 50, 263]
# error at  8836
# Deleting :_________________________
# [50, 263, 320]
# error at  8836
# Deleting :_________________________
# [263, 320, 133]
# error at  8836
# Deleting :_________________________
# [1725, 15, 20]
# error at  8856
# Deleting :_________________________
# [15, 20, 119]
# error at  8856
# Deleting :_________________________
# [20, 119, 800]
# error at  8856
# Deleting :_________________________
# [119, 800, 717]
# error at  8856
# Deleting :_________________________
# [15, 90, 1238]
# error at  8964
# Deleting :_________________________
# [90, 1238, 374]
# error at  8964
# Deleting :_________________________
# [1238, 374, 1456]
# error at  8964
# Deleting :_________________________
# [374, 1456, 3]
# error at  8964
# Deleting :_________________________
# [52, 15, 3]
# error at  9002
# Deleting :_________________________
# [15, 3, 34]
# error at  9002
# Deleting :_________________________
# [3, 34, 49]
# error at  9002
# Deleting :_________________________
# [34, 49, 12]
# error at  9002
# Deleting :_________________________
# [15, 976, 255]
# error at  9026
# Deleting :_________________________
# [976, 255, 4156]
# error at  9026
# Deleting :_________________________
# [255, 4156, 12]
# error at  9026
# Deleting :_________________________
# [4156, 12, 1120]
# error at  9026
# Deleting :_________________________
# [1, 15, 470]
# error at  9038
# Deleting :_________________________
# [15, 470, 60]
# error at  9038
# Deleting :_________________________
# [470, 60, 4158]
# error at  9038
# Deleting :_________________________
# [60, 4158, 218]
# error at  9038
# Deleting :_________________________
# [398, 219, 598]
# error at  9207
# Deleting :_________________________
# [219, 598, 881]
# error at  9207
# Deleting :_________________________
# [598, 881, 2210]
# error at  9207
# Deleting :_________________________
# [881, 2210, 28]
# error at  9207
# Deleting :_________________________
# [63, 1124, 2211]
# error at  9242
# Deleting :_________________________
# [1124, 2211, 851]
# error at  9242
# Deleting :_________________________
# [2211, 851, 3]
# error at  9242
# Deleting :_________________________
# [851, 3, 119]
# error at  9242
# Deleting :_________________________
# [2212, 119, 988]
# error at  9256
# Deleting :_________________________
# [119, 988, 119]
# error at  9256
# Deleting :_________________________
# [988, 119, 218]
# error at  9256
# Deleting :_________________________
# [119, 218, 1525]
# error at  9256
# Deleting :_________________________
# [15, 3, 2212]
# error at  9275
# Deleting :_________________________
# [3, 2212, 502]
# error at  9275
# Deleting :_________________________
# [2212, 502, 49]
# error at  9275
# Deleting :_________________________
# [502, 49, 1705]
# error at  9275
# Deleting :_________________________
# [1, 203, 1303]
# error at  9279
# Deleting :_________________________
# [203, 1303, 502]
# error at  9279
# Deleting :_________________________
# [1303, 502, 358]
# error at  9279
# Deleting :_________________________
# [502, 358, 1]
# error at  9279
# Deleting :_________________________
# [336, 2214, 10]
# error at  9285
# Deleting :_________________________
# [2214, 10, 15]
# error at  9285
# Deleting :_________________________
# [10, 15, 1125]
# error at  9285
# Deleting :_________________________
# [15, 1125, 119]
# error at  9285
# Deleting :_________________________
# [1, 219, 78]
# error at  9297
# Deleting :_________________________
# [219, 78, 618]
# error at  9297
# Deleting :_________________________
# [78, 618, 58]
# error at  9297
# Deleting :_________________________
# [618, 58, 1121]
# error at  9297
# Deleting :_________________________
# [78, 219, 398]
# error at  9321
# Deleting :_________________________
# [219, 398, 320]
# error at  9321
# Deleting :_________________________
# [398, 320, 791]
# error at  9321
# Deleting :_________________________
# [320, 791, 1512]
# error at  9321
# Deleting :_________________________
# [210, 1, 148]
# error at  9329
# Deleting :_________________________
# [1, 148, 588]
# error at  9329
# Deleting :_________________________
# [148, 588, 588]
# error at  9329
# Deleting :_________________________
# [588, 588, 97]
# error at  9329
# Deleting :_________________________
# [87, 90, 4178]
# error at  9365
# Deleting :_________________________
# [90, 4178, 171]
# error at  9365
# Deleting :_________________________
# [4178, 171, 3]
# error at  9365
# Deleting :_________________________
# [171, 3, 447]
# error at  9365
# Deleting :_________________________
# [171, 3, 447]
# error at  9365
# Deleting :_________________________
# [3, 447, 87]
# error at  9365
# Deleting :_________________________
# [447, 87, 2203]
# error at  9365
# Deleting :_________________________
# [87, 2203, 90]
# error at  9365
# Deleting :_________________________
# [221, 1058, 267]
# error at  9368
# Deleting :_________________________
# [1058, 267, 6]
# error at  9368
# Deleting :_________________________
# [267, 6, 68]
# error at  9368
# Deleting :_________________________
# [6, 68, 131]
# error at  9368
# Deleting :_________________________
# [39, 81, 1797]
# error at  9389
# Deleting :_________________________
# [81, 1797, 726]
# error at  9389
# Deleting :_________________________
# [1797, 726, 1076]
# error at  9389
# Deleting :_________________________
# [726, 1076, 90]
# error at  9389
# Deleting :_________________________
# [282, 15, 2916]
# error at  9396
# Deleting :_________________________
# [15, 2916, 6]
# error at  9396
# Deleting :_________________________
# [2916, 6, 4182]
# error at  9396
# Deleting :_________________________
# [6, 4182, 90]
# error at  9396
# Deleting :_________________________
# [1, 1528, 148]
# error at  9419
# Deleting :_________________________
# [1528, 148, 132]
# error at  9419
# Deleting :_________________________
# [148, 132, 209]
# error at  9419
# Deleting :_________________________
# [132, 209, 360]
# error at  9419
# Deleting :_________________________
# [132, 2217, 219]
# error at  9452
# Deleting :_________________________
# [2217, 219, 120]
# error at  9452
# Deleting :_________________________
# [219, 120, 97]
# error at  9452
# Deleting :_________________________
# [120, 97, 370]
# error at  9452
# Deleting :_________________________
# [370, 2, 520]
# error at  9457
# Deleting :_________________________
# [2, 520, 4190]
# error at  9457
# Deleting :_________________________
# [520, 4190, 2805]
# error at  9457
# Deleting :_________________________
# [4190, 2805, 714]
# error at  9457
# Deleting :_________________________
# [2218, 1803, 3]
# error at  9486
# Deleting :_________________________
# [1803, 3, 4197]
# error at  9486
# Deleting :_________________________
# [3, 4197, 4198]
# error at  9486
# Deleting :_________________________
# [4197, 4198, 173]
# error at  9486
# Deleting :_________________________
# [4202, 61, 219]
# error at  9527
# Deleting :_________________________
# [61, 219, 1804]
# error at  9527
# Deleting :_________________________
# [219, 1804, 139]
# error at  9527
# Deleting :_________________________
# [1804, 139, 1]
# error at  9527
# Deleting :_________________________
# [21, 728, 20]
# error at  9579
# Deleting :_________________________
# [728, 20, 1482]
# error at  9579
# Deleting :_________________________
# [20, 1482, 645]
# error at  9579
# Deleting :_________________________
# [1482, 645, 72]
# error at  9579
# Deleting :_________________________
# [1221, 404, 1415]
# error at  9605
# Deleting :_________________________
# [404, 1415, 456]
# error at  9605
# Deleting :_________________________
# [1415, 456, 2]
# error at  9605
# Deleting :_________________________
# [456, 2, 1]
# error at  9605
# Deleting :_________________________
# [404, 798, 139]
# error at  9629
# Deleting :_________________________
# [798, 139, 2]
# error at  9629
# Deleting :_________________________
# [139, 2, 102]
# error at  9629
# Deleting :_________________________
# [2, 102, 9]
# error at  9629
# Deleting :_________________________
# [93, 359, 1050]
# error at  9684
# Deleting :_________________________
# [359, 1050, 2223]
# error at  9684
# Deleting :_________________________
# [1050, 2223, 562]
# error at  9684
# Deleting :_________________________
# [2223, 562, 1]
# error at  9684
# Deleting :_________________________
# [2208, 2228, 2]
# error at  9815
# Deleting :_________________________
# [2228, 2, 1266]
# error at  9815
# Deleting :_________________________
# [2, 1266, 1108]
# error at  9815
# Deleting :_________________________
# [1266, 1108, 67]
# error at  9815
# Deleting :_________________________
# [65, 36, 886]
# error at  9856
# Deleting :_________________________
# [36, 886, 2223]
# error at  9856
# Deleting :_________________________
# [886, 2223, 18]
# error at  9856
# Deleting :_________________________
# [2223, 18, 35]
# error at  9856
# Deleting :_________________________
# [623, 201, 2229]
# error at  9860
# Deleting :_________________________
# [201, 2229, 15]
# error at  9860
# Deleting :_________________________
# [2229, 15, 801]
# error at  9860
# Deleting :_________________________
# [15, 801]
# error at  9860
# Deleting :_________________________
# [15, 801, 6]
# error at  9860
# Deleting :_________________________
# [801, 6, 127]
# error at  9860
# Deleting :_________________________
# [6, 127, 247]
# error at  9860
# Deleting :_________________________
# [87, 101, 497]
# error at  9864
# Deleting :_________________________
# [101, 497, 148]
# error at  9864
# Deleting :_________________________
# [497, 148, 1128]
# error at  9864
# Deleting :_________________________
# [148, 1128, 2]
# error at  9864
# Deleting :_________________________
# [148, 1128, 2]
# error at  9864
# Deleting :_________________________
# [1128, 2, 379]
# error at  9864
# Deleting :_________________________
# [2, 379, 137]
# error at  9864
# Deleting :_________________________
# [379, 137, 1129]
# error at  9864
# Deleting :_________________________
# [62, 4224, 148]
# error at  9920
# Deleting :_________________________
# [4224, 148, 263]
# error at  9920
# Deleting :_________________________
# [148, 263, 320]
# error at  9920
# Deleting :_________________________
# [263, 320, 215]
# error at  9920
# Deleting :_________________________
# [92, 4264, 15]
# error at  10398
# Deleting :_________________________
# [4264, 15, 599]
# error at  10398
# Deleting :_________________________
# [15, 599, 314]
# error at  10398
# Deleting :_________________________
# [599, 314, 331]
# error at  10398
# Deleting :_________________________
# [2937, 153, 15]
# error at  10440
# Deleting :_________________________
# [153, 15, 184]
# error at  10440
# Deleting :_________________________
# [15, 184, 273]
# error at  10440
# Deleting :_________________________
# [184, 273, 2245]
# error at  10440
# Deleting :_________________________
# [4279, 51, 754]
# error at  10527
# Deleting :_________________________
# [51, 754, 53]
# error at  10527
# Deleting :_________________________
# [754, 53, 4280]
# error at  10527
# Deleting :_________________________
# [53, 4280, 131]
# error at  10527
# Deleting :_________________________
# [291, 4, 110]
# error at  10571
# Deleting :_________________________
# [4, 110, 13]
# error at  10571
# Deleting :_________________________
# [110, 13, 2941]
# error at  10571
# Deleting :_________________________
# [13, 2941, 995]
# error at  10571
# Deleting :_________________________
# [995, 115, 4292]
# error at  10573
# Deleting :_________________________
# [115, 4292, 4]
# error at  10573
# Deleting :_________________________
# [4292, 4, 449]
# error at  10573
# Deleting :_________________________
# [4, 449, 504]
# error at  10573
# Deleting :_________________________
# [1, 2256, 15]
# error at  10580
# Deleting :_________________________
# [2256, 15, 5]
# error at  10580
# Deleting :_________________________
# [15, 5, 17]
# error at  10580
# Deleting :_________________________
# [5, 17, 8]
# error at  10580
# Deleting :_________________________
# [58, 291, 361]
# error at  10594
# Deleting :_________________________
# [291, 361, 4]
# error at  10594
# Deleting :_________________________
# [361, 4, 449]
# error at  10594
# Deleting :_________________________
# [4, 449, 4296]
# error at  10594
# Deleting :_________________________
# [4298, 893, 20]
# error at  10607
# Deleting :_________________________
# [893, 20, 22]
# error at  10607
# Deleting :_________________________
# [20, 22, 291]
# error at  10607
# Deleting :_________________________
# [22, 291, 236]
# error at  10607
# Deleting :_________________________
# [236, 314, 569]
# error at  10609
# Deleting :_________________________
# [314, 569, 273]
# error at  10609
# Deleting :_________________________
# [569, 273, 36]
# error at  10609
# Deleting :_________________________
# [273, 36, 87]
# error at  10609
# Deleting :_________________________
# [70, 1087, 894]
# error at  10612
# Deleting :_________________________
# [1087, 894, 22]
# error at  10612
# Deleting :_________________________
# [894, 22, 17]
# error at  10612
# Deleting :_________________________
# [22, 17, 8]
# error at  10612
# Deleting :_________________________
# [4305, 20, 224]
# error at  10635
# Deleting :_________________________
# [20, 224, 314]
# error at  10635
# Deleting :_________________________
# [224, 314, 278]
# error at  10635
# Deleting :_________________________
# [314, 278, 1124]
# error at  10635
# Deleting :_________________________
# [130, 2258, 4310]
# error at  10657
# Deleting :_________________________
# [2258, 4310, 2257]
# error at  10657
# Deleting :_________________________
# [4310, 2257, 4311]
# error at  10657
# Deleting :_________________________
# [2257, 4311, 167]
# error at  10657
# Deleting :_________________________
# [4318, 4319, 2]
# error at  10698
# Deleting :_________________________
# [4319, 2, 543]
# error at  10698
# Deleting :_________________________
# [2, 543, 1545]
# error at  10698
# Deleting :_________________________
# [543, 1545, 1]
# error at  10698
# Deleting :_________________________
# [292, 262, 203]
# error at  10702
# Deleting :_________________________
# [262, 203, 5]
# error at  10702
# Deleting :_________________________
# [203, 5, 158]
# error at  10702
# Deleting :_________________________
# [5, 158, 2259]
# error at  10702
# Deleting :_________________________
# [878, 203, 2951]
# error at  11141
# Deleting :_________________________
# [203, 2951, 186]
# error at  11141
# Deleting :_________________________
# [2951, 186, 2952]
# error at  11141
# Deleting :_________________________
# [186, 2952, 3]
# error at  11141
# Deleting :_________________________
# [1, 4374, 224]
# error at  11187
# Deleting :_________________________
# [4374, 224, 957]
# error at  11187
# Deleting :_________________________
# [224, 957, 2954]
# error at  11187
# Deleting :_________________________
# [957, 2954, 4375]
# error at  11187
# Deleting :_________________________
# [52, 731, 849]
# error at  11292
# Deleting :_________________________
# [731, 849, 4389]
# error at  11292
# Deleting :_________________________
# [849, 4389, 1819]
# error at  11292
# Deleting :_________________________
# [4389, 1819, 2177]
# error at  11292
# Deleting :_________________________
# [4390, 4391, 15]
# error at  11295
# Deleting :_________________________
# [4391, 15, 1553]
# error at  11295
# Deleting :_________________________
# [15, 1553, 60]
# error at  11295
# Deleting :_________________________
# [1553, 60, 20]
# error at  11295
# Deleting :_________________________
# [4394, 4395, 15]
# error at  11309
# Deleting :_________________________
# [4395, 15, 82]
# error at  11309
# Deleting :_________________________
# [15, 82, 53]
# error at  11309
# Deleting :_________________________
# [82, 53, 4396]
# error at  11309
# Deleting :_________________________
# [1, 279, 15]
# error at  11350
# Deleting :_________________________
# [279, 15, 279]
# error at  11350
# Deleting :_________________________
# [15, 279, 32]
# error at  11350
# Deleting :_________________________
# [279, 32, 2]
# error at  11350
# Deleting :_________________________
# [2958, 1558, 4402]
# error at  11360
# Deleting :_________________________
# [1558, 4402, 145]
# error at  11360
# Deleting :_________________________
# [4402, 145, 4403]
# error at  11360
# Deleting :_________________________
# [145, 4403, 205]
# error at  11360
# Deleting :_________________________
# [1, 60, 2]
# error at  11367
# Deleting :_________________________
# [60, 2, 900]
# error at  11367
# Deleting :_________________________
# [2, 900, 901]
# error at  11367
# Deleting :_________________________
# [900, 901, 1317]
# error at  11367
# Deleting :_________________________
# [353, 4414, 148]
# error at  11439
# Deleting :_________________________
# [4414, 148, 779]
# error at  11439
# Deleting :_________________________
# [148, 779, 60]
# error at  11439
# Deleting :_________________________
# [779, 60, 722]
# error at  11439
# Deleting :_________________________
# [4420, 15, 141]
# error at  11475
# Deleting :_________________________
# [15, 141, 82]
# error at  11475
# Deleting :_________________________
# [141, 82, 2282]
# error at  11475
# Deleting :_________________________
# [82, 2282, 2282]
# error at  11475
# Deleting :_________________________
# [1, 69, 224]
# error at  11484
# Deleting :_________________________
# [69, 224, 7]
# error at  11484
# Deleting :_________________________
# [224, 7, 334]
# error at  11484
# Deleting :_________________________
# [7, 334, 178]
# error at  11484
# Deleting :_________________________
# [4429, 54, 15]
# error at  11549
# Deleting :_________________________
# [54, 15, 180]
# error at  11549
# Deleting :_________________________
# [15, 180, 3]
# error at  11549
# Deleting :_________________________
# [180, 3, 4430]
# error at  11549
# Deleting :_________________________
# [1, 35, 203]
# error at  11642
# Deleting :_________________________
# [35, 203, 15]
# error at  11642
# Deleting :_________________________
# [203, 15, 85]
# error at  11642
# Deleting :_________________________
# [15, 85]
# error at  11642
# Deleting :_________________________
# [15, 85, 8]
# error at  11642
# Deleting :_________________________
# [85, 8, 2286]
# error at  11642
# Deleting :_________________________
# [8, 2286, 63]
# error at  11642
# Deleting :_________________________
# [15, 56, 35]
# error at  11651
# Deleting :_________________________
# [56, 35, 6]
# error at  11651
# Deleting :_________________________
# [35, 6, 77]
# error at  11651
# Deleting :_________________________
# [6, 77, 2287]
# error at  11651
# Deleting :_________________________
# [37, 319, 219]
# error at  11663
# Deleting :_________________________
# [319, 219, 4441]
# error at  11663
# Deleting :_________________________
# [219, 4441, 237]
# error at  11663
# Deleting :_________________________
# [4441, 237, 4442]
# error at  11663
# Deleting :_________________________
# [1143, 12, 493]
# error at  11735
# Deleting :_________________________
# [12, 493, 103]
# error at  11735
# Deleting :_________________________
# [493, 103, 23]
# error at  11735
# Deleting :_________________________
# [103, 23, 1143]
# error at  11735
# Deleting :_________________________
# [1047, 1, 447]
# error at  11833
# Deleting :_________________________
# [1, 447, 82]
# error at  11833
# Deleting :_________________________
# [447, 82, 499]
# error at  11833
# Deleting :_________________________
# [82, 499, 499]
# error at  11833
# Deleting :_________________________
# [259, 15, 259]
# error at  11881
# Deleting :_________________________
# [15, 259, 547]
# error at  11881
# Deleting :_________________________
# [259, 547, 687]
# error at  11881
# Deleting :_________________________
# [547, 687, 15]
# error at  11881
# Deleting :_________________________
# [687, 15, 259]
# error at  11882
# Deleting :_________________________
# [15, 259, 904]
# error at  11882
# Deleting :_________________________
# [259, 904, 247]
# error at  11882
# Deleting :_________________________
# [904, 247, 1]
# error at  11882
# Deleting :_________________________
# [4479, 2, 224]
# error at  11955
# Deleting :_________________________
# [2, 224, 60]
# error at  11955
# Deleting :_________________________
# [224, 60, 4480]
# error at  11955
# Deleting :_________________________
# [60, 4480, 1]
# error at  11955
# Deleting :_________________________
# [12, 151, 497]
# error at  11999
# Deleting :_________________________
# [151, 497, 480]
# error at  11999
# Deleting :_________________________
# [497, 480, 13]
# error at  11999
# Deleting :_________________________
# [480, 13, 12]
# error at  11999
# Deleting :_________________________
# [1570, 734, 341]
# error at  12025
# Deleting :_________________________
# [734, 341, 459]
# error at  12025
# Deleting :_________________________
# [341, 459, 341]
# error at  12025
# Deleting :_________________________
# [459, 341, 1]
# error at  12025
# Deleting :_________________________
# [215, 50, 148]
# error at  12053
# Deleting :_________________________
# [50, 148, 451]
# error at  12053
# Deleting :_________________________
# [148, 451, 1525]
# error at  12053
# Deleting :_________________________
# [451, 1525, 1]
# error at  12053
# Deleting :_________________________
# [15, 60, 413]
# error at  12089
# Deleting :_________________________
# [60, 413, 1562]
# error at  12089
# Deleting :_________________________
# [413, 1562, 1563]
# error at  12089
# Deleting :_________________________
# [1562, 1563, 26]
# error at  12089
# Deleting :_________________________
# [1562, 1563, 26]
# error at  12089
# Deleting :_________________________
# [1563, 26, 102]
# error at  12089
# Deleting :_________________________
# [26, 102, 15]
# error at  12089
# Deleting :_________________________
# [102, 15]
# error at  12089
# Deleting :_________________________
# [102, 15, 1319]
# error at  12089
# Deleting :_________________________
# [15, 1319, 1142]
# error at  12089
# Deleting :_________________________
# [1319, 1142, 507]
# error at  12089
# Deleting :_________________________
# [507, 109, 337]
# error at  12091
# Deleting :_________________________
# [109, 337, 6]
# error at  12091
# Deleting :_________________________
# [337, 6, 37]
# error at  12091
# Deleting :_________________________
# [6, 37, 23]
# error at  12091
# Deleting :_________________________
# [1, 69, 715]
# error at  12095
# Deleting :_________________________
# [69, 715, 1824]
# error at  12095
# Deleting :_________________________
# [715, 1824, 1]
# error at  12095
# Deleting :_________________________
# [1824, 1, 18]
# error at  12095
# Deleting :_________________________
# [1, 60, 2]
# error at  12305
# Deleting :_________________________
# [60, 2, 82]
# error at  12305
# Deleting :_________________________
# [2, 82, 1239]
# error at  12305
# Deleting :_________________________
# [82, 1239, 95]
# error at  12305
# Deleting :_________________________
# [15, 3, 4518]
# error at  12309
# Deleting :_________________________
# [3, 4518, 8]
# error at  12309
# Deleting :_________________________
# [4518, 8, 71]
# error at  12309
# Deleting :_________________________
# [8, 71, 4519]
# error at  12309
# Deleting :_________________________
# [4523, 151, 1324]
# error at  12384
# Deleting :_________________________
# [151, 1324, 82]
# error at  12384
# Deleting :_________________________
# [1324, 82, 374]
# error at  12384
# Deleting :_________________________
# [82, 374, 4524]
# error at  12384
# Deleting :_________________________
# [55, 231, 12]
# error at  12503
# Deleting :_________________________
# [231, 12, 1562]
# error at  12503
# Deleting :_________________________
# [12, 1562, 1563]
# error at  12503
# Deleting :_________________________
# [1562, 1563, 880]
# error at  12503
# Deleting :_________________________
# [1731, 1531, 20]
# error at  12506
# Deleting :_________________________
# [1531, 20, 1824]
# error at  12506
# Deleting :_________________________
# [20, 1824, 2]
# error at  12506
# Deleting :_________________________
# [1824, 2, 1]
# error at  12506
# Deleting :_________________________
# [7, 4555, 4556]
# error at  12643
# Deleting :_________________________
# [4555, 4556, 82]
# error at  12643
# Deleting :_________________________
# [4556, 82, 1026]
# error at  12643
# Deleting :_________________________
# [82, 1026, 989]
# error at  12643
# Deleting :_________________________
# [15, 1324, 87]
# error at  13094
# Deleting :_________________________
# [1324, 87, 293]
# error at  13094
# Deleting :_________________________
# [87, 293, 64]
# error at  13094
# Deleting :_________________________
# [293, 64, 243]
# error at  13094
# Deleting :_________________________
# [205, 1583, 1004]
# error at  13155
# Deleting :_________________________
# [1583, 1004, 264]
# error at  13155
# Deleting :_________________________
# [1004, 264, 2988]
# error at  13155
# Deleting :_________________________
# [264, 2988, 85]
# error at  13155
# Deleting :_________________________
# [335, 116, 73]
# error at  13169
# Deleting :_________________________
# [116, 73, 1120]
# error at  13169
# Deleting :_________________________
# [73, 1120, 87]
# error at  13169
# Deleting :_________________________
# [1120, 87, 347]
# error at  13169
# Deleting :_________________________
# [15, 3, 628]
# error at  13247
# Deleting :_________________________
# [3, 628, 452]
# error at  13247
# Deleting :_________________________
# [628, 452, 1005]
# error at  13247
# Deleting :_________________________
# [452, 1005, 4619]
# error at  13247
# Deleting :_________________________
# [351, 116, 73]
# error at  13506
# Deleting :_________________________
# [116, 73, 293]
# error at  13506
# Deleting :_________________________
# [73, 293, 64]
# error at  13506
# Deleting :_________________________
# [293, 64, 65]
# error at  13506
# Deleting :_________________________
# [95, 219, 4675]
# error at  13607
# Deleting :_________________________
# [219, 4675, 6]
# error at  13607
# Deleting :_________________________
# [4675, 6, 1266]
# error at  13607
# Deleting :_________________________
# [6, 1266, 328]
# error at  13607
# Deleting :_________________________
# [335, 447, 604]
# error at  13660
# Deleting :_________________________
# [447, 604, 1587]
# error at  13660
# Deleting :_________________________
# [604, 1587, 482]
# error at  13660
# Deleting :_________________________
# [1587, 482, 482]
# error at  13660
# Deleting :_________________________
# [423, 188, 1841]
# error at  14211
# Deleting :_________________________
# [188, 1841, 999]
# error at  14211
# Deleting :_________________________
# [1841, 999, 737]
# error at  14211
# Deleting :_________________________
# [999, 737, 1841]
# error at  14211
# Deleting :_________________________
# [70, 37, 1163]
# error at  14411
# Deleting :_________________________
# [37, 1163, 299]
# error at  14411
# Deleting :_________________________
# [1163, 299, 453]
# error at  14411
# Deleting :_________________________
# [299, 453, 951]
# error at  14411
# Deleting :_________________________
# [1, 171, 1230]
# error at  16662
# Deleting :_________________________
# [171, 1230, 87]
# error at  16662
# Deleting :_________________________
# [1230, 87, 171]
# error at  16662
# Deleting :_________________________
# [87, 171, 1230]
# error at  16662
# Deleting :_________________________
# [87, 171, 1230]
# error at  16662
# Deleting :_________________________
# [171, 1230, 35]
# error at  16662
# Deleting :_________________________
# [1230, 35, 171]
# error at  16662
# Deleting :_________________________
# [35, 171, 465]
# error at  16662
# Deleting :_________________________
# [35, 171, 465]
# error at  16662
# Deleting :_________________________
# [171, 465, 624]
# error at  16662
# Deleting :_________________________
# [465, 624, 171]
# error at  16662
# Deleting :_________________________
# [624, 171, 3694]
# error at  16662
# Deleting :_________________________
# [624, 171, 3694]
# error at  16662
# Deleting :_________________________
# [171, 3694, 6]
# error at  16662
# Deleting :_________________________
# [3694, 6, 364]
# error at  16662
# Deleting :_________________________
# [6, 364, 434]
# error at  16662
# Deleting :_________________________
# [70, 468, 87]
# error at  16675
# Deleting :_________________________
# [468, 87, 61]
# error at  16675
# Deleting :_________________________
# [87, 61, 70]
# error at  16675
# Deleting :_________________________
# [61, 70, 468]
# error at  16675
# Deleting :_________________________
# [70, 468, 87]
# error at  16676
# Deleting :_________________________
# [468, 87, 61]
# error at  16676
# Deleting :_________________________
# [87, 61, 70]
# error at  16676
# Deleting :_________________________
# [61, 70, 232]
# error at  16676
# Deleting :_________________________
# [70, 232, 87]
# error at  16677
# Deleting :_________________________
# [232, 87, 492]
# error at  16677
# Deleting :_________________________
# [87, 492, 2715]
# error at  16677
# Deleting :_________________________
# [492, 2715, 979]
# error at  16677
# Deleting :_________________________
# [492, 2715, 979]
# error at  16677
# Deleting :_________________________
# [2715, 979, 87]
# error at  16677
# Deleting :_________________________
# [979, 87, 70]
# error at  16677
# Deleting :_________________________
# [87, 70, 88]
# error at  16677
# Deleting :_________________________
# [88, 386, 2718]
# error at  16679
# Deleting :_________________________
# [386, 2718, 386]
# error at  16679
# Deleting :_________________________
# [2718, 386, 237]
# error at  16679
# Deleting :_________________________
# [386, 237, 4753]
# error at  16679
# Deleting :_________________________
# [103, 763, 171]
# error at  16805
# Deleting :_________________________
# [763, 171, 19]
# error at  16805
# Deleting :_________________________
# [171, 19, 74]
# error at  16805
# Deleting :_________________________
# [19, 74, 905]
# error at  16805
# Deleting :_________________________
# [364, 1230, 135]
# error at  16812
# Deleting :_________________________
# [1230, 135, 8]
# error at  16812
# Deleting :_________________________
# [135, 8, 6453]
# error at  16812
# Deleting :_________________________
# [8, 6453, 320]
# error at  16812
# Deleting :_________________________
# [237, 70, 6457]
# error at  16842
# Deleting :_________________________
# [70, 6457, 1489]
# error at  16842
# Deleting :_________________________
# [6457, 1489, 477]
# error at  16842
# Deleting :_________________________
# [1489, 477, 43]
# error at  16842
# Deleting :_________________________
# [571, 492, 2715]
# error at  16897
# Deleting :_________________________
# [492, 2715, 112]
# error at  16897
# Deleting :_________________________
# [2715, 112, 1055]
# error at  16897
# Deleting :_________________________
# [112, 1055, 3]
# error at  16897
# Deleting :_________________________
# [942, 336, 75]
# error at  16956
# Deleting :_________________________
# [336, 75, 348]
# error at  16956
# Deleting :_________________________
# [75, 348, 1057]
# error at  16956
# Deleting :_________________________
# [348, 1057, 3700]
# error at  16956
# Deleting :_________________________
# [1226, 2719, 942]
# error at  16981
# Deleting :_________________________
# [2719, 942, 103]
# error at  16981
# Deleting :_________________________
# [942, 103, 1226]
# error at  16981
# Deleting :_________________________
# [103, 1226, 942]
# error at  16981
# Deleting :_________________________
# [103, 1226, 942]
# error at  16981
# Deleting :_________________________
# [1226, 942, 103]
# error at  16981
# Deleting :_________________________
# [942, 103, 760]
# error at  16981
# Deleting :_________________________
# [103, 760, 70]
# error at  16981
# Deleting :_________________________
# [760, 70, 885]
# error at  16982
# Deleting :_________________________
# [70, 885, 103]
# error at  16982
# Deleting :_________________________
# [885, 103, 4756]
# error at  16982
# Deleting :_________________________
# [103, 4756, 6458]
# error at  16982
# Deleting :_________________________
# [2045, 3703, 337]
# error at  16992
# Deleting :_________________________
# [3703, 337, 3704]
# error at  16992
# Deleting :_________________________
# [337, 3704, 76]
# error at  16992
# Deleting :_________________________
# [3704, 76, 468]
# error at  16992
# Deleting :_________________________
# [344, 2046, 164]
# error at  16996
# Deleting :_________________________
# [2046, 164, 2720]
# error at  16996
# Deleting :_________________________
# [164, 2720, 12]
# error at  16996
# Deleting :_________________________
# [2720, 12, 27]
# error at  16996
# Deleting :_________________________
# [70, 156, 195]
# error at  17005
# Deleting :_________________________
# [156, 195, 571]
# error at  17005
# Deleting :_________________________
# [195, 571, 528]
# error at  17005
# Deleting :_________________________
# [571, 528, 106]
# error at  17005
# Deleting :_________________________
# [571, 528, 106]
# error at  17005
# Deleting :_________________________
# [528, 106, 103]
# error at  17005
# Deleting :_________________________
# [106, 103, 528]
# error at  17005
# Deleting :_________________________
# [103, 528, 492]
# error at  17005
# Deleting :_________________________
# [103, 528, 492]
# error at  17005
# Deleting :_________________________
# [528, 492, 87]
# error at  17005
# Deleting :_________________________
# [492, 87, 6460]
# error at  17005
# Deleting :_________________________
# [87, 6460, 2713]
# error at  17005
# Deleting :_________________________
# [87, 6460, 2713]
# error at  17005
# Deleting :_________________________
# [6460, 2713, 103]
# error at  17005
# Deleting :_________________________
# [2713, 103, 924]
# error at  17005
# Deleting :_________________________
# [103, 924, 167]
# error at  17005
# Deleting :_________________________
# [103, 924, 167]
# error at  17005
# Deleting :_________________________
# [924, 167, 103]
# error at  17005
# Deleting :_________________________
# [167, 103, 146]
# error at  17005
# Deleting :_________________________
# [103, 146, 3002]
# error at  17005
# Deleting :_________________________
# [87, 70, 4761]
# error at  17034
# Deleting :_________________________
# [70, 4761, 103]
# error at  17034
# Deleting :_________________________
# [4761, 103, 4762]
# error at  17034
# Deleting :_________________________
# [103, 4762, 6464]
# error at  17034
# Deleting :_________________________
# [6464, 4, 170]
# error at  17036
# Deleting :_________________________
# [4, 170, 3004]
# error at  17036
# Deleting :_________________________
# [170, 3004, 331]
# error at  17036
# Deleting :_________________________
# [3004, 331, 6465]
# error at  17036
# Deleting :_________________________
# [6465, 25, 73]
# error at  17038
# Deleting :_________________________
# [25, 73, 3004]
# error at  17038
# Deleting :_________________________
# [73, 3004, 331]
# error at  17038
# Deleting :_________________________
# [3004, 331, 6466]
# error at  17038
# Deleting :_________________________
# [6466, 25, 73]
# error at  17040
# Deleting :_________________________
# [25, 73, 70]
# error at  17040
# Deleting :_________________________
# [73, 70, 110]
# error at  17040
# Deleting :_________________________
# [70, 110, 4761]
# error at  17040
# Deleting :_________________________
# [4766, 129, 26]
# error at  17120
# Deleting :_________________________
# [129, 26, 7]
# error at  17120
# Deleting :_________________________
# [26, 7, 4766]
# error at  17120
# Deleting :_________________________
# [7, 4766, 6474]
# error at  17120
# Deleting :_________________________
# [4766, 6474, 26]
# error at  17121
# Deleting :_________________________
# [6474, 26, 6475]
# error at  17121
# Deleting :_________________________
# [26, 6475, 4767]
# error at  17121
# Deleting :_________________________
# [6475, 4767, 3007]
# error at  17121
# Deleting :_________________________
# [3022, 25, 73]
# error at  17885
# Deleting :_________________________
# [25, 73, 4802]
# error at  17885
# Deleting :_________________________
# [73, 4802, 49]
# error at  17885
# Deleting :_________________________
# [4802, 49, 37]
# error at  17885
# Deleting :_________________________
# [70, 28, 31]
# error at  17888
# Deleting :_________________________
# [28, 31, 8]
# error at  17888
# Deleting :_________________________
# [31, 8, 28]
# error at  17888
# Deleting :_________________________
# [8, 28, 31]
# error at  17888
# Deleting :_________________________
# [15, 738, 282]
# error at  17982
# Deleting :_________________________
# [738, 282, 103]
# error at  17982
# Deleting :_________________________
# [282, 103, 6587]
# error at  17982
# Deleting :_________________________
# [103, 6587, 6588]
# error at  17982
# Deleting :_________________________
# [622, 6643, 1606]
# error at  18333
# Deleting :_________________________
# [6643, 1606, 311]
# error at  18333
# Deleting :_________________________
# [1606, 311, 2]
# error at  18333
# Deleting :_________________________
# [311, 2, 4826]
# error at  18333
# Deleting :_________________________
# [70, 6650, 216]
# error at  18374
# Deleting :_________________________
# [6650, 216, 206]
# error at  18374
# Deleting :_________________________
# [216, 206, 466]
# error at  18374
# Deleting :_________________________
# [206, 466, 10]
# error at  18374
# Deleting :_________________________
# [1997, 6685, 4765]
# error at  18828
# Deleting :_________________________
# [6685, 4765, 2880]
# error at  18828
# Deleting :_________________________
# [4765, 2880, 6686]
# error at  18828
# Deleting :_________________________
# [2880, 6686, 6687]
# error at  18828
# Deleting :_________________________
# [229, 842, 930]
# error at  18997
# Deleting :_________________________
# [842, 930, 121]
# error at  18997
# Deleting :_________________________
# [930, 121, 35]
# error at  18997
# Deleting :_________________________
# [121, 35, 202]
# error at  18997
# Deleting :_________________________
# [1983, 846, 12]
# error at  19742
# Deleting :_________________________
# [846, 12, 846]
# error at  19742
# Deleting :_________________________
# [12, 846, 46]
# error at  19742
# Deleting :_________________________
# [846, 46, 2093]
# error at  19742
# Deleting :_________________________
# [1051, 214, 2]
# error at  19865
# Deleting :_________________________
# [214, 2, 2]
# error at  19865
# Deleting :_________________________
# [2, 2, 240]
# error at  19865
# Deleting :_________________________
# [2, 240, 4]
# error at  19865
# Deleting :_________________________
# [1, 1874, 651]
# error at  20463
# Deleting :_________________________
# [1874, 651, 6933]
# error at  20463
# Deleting :_________________________
# [651, 6933, 54]
# error at  20463
# Deleting :_________________________
# [6933, 54, 6934]
# error at  20463
# Deleting :_________________________
# [70, 221, 4948]
# error at  21206
# Deleting :_________________________
# [221, 4948, 92]
# error at  21206
# Deleting :_________________________
# [4948, 92, 70]
# error at  21206
# Deleting :_________________________
# [92, 70, 357]
# error at  21206
# Deleting :_________________________
# [3033, 60, 25]
# error at  21214
# Deleting :_________________________
# [60, 25, 38]
# error at  21214
# Deleting :_________________________
# [25, 38, 656]
# error at  21214
# Deleting :_________________________
# [38, 656, 1168]
# error at  21214
# Deleting :_________________________
# [294, 25, 1128]
# error at  23848
# Deleting :_________________________
# [25, 1128, 11]
# error at  23848
# Deleting :_________________________
# [1128, 11, 88]
# error at  23848
# Deleting :_________________________
# [11, 88, 304]
# error at  23848
# Deleting :_________________________
# [2431, 93, 15]
# error at  25619
# Deleting :_________________________
# [93, 15, 1900]
# error at  25619
# Deleting :_________________________
# [15, 1900, 15]
# error at  25619
# Deleting :_________________________
# [1900, 15]
# error at  25619
# Deleting :_________________________
# [1900, 15, 5114]
# error at  25619
# Deleting :_________________________
# [15, 5114, 5]
# error at  25619
# Deleting :_________________________
# [5114, 5, 437]
# error at  25619
# Deleting :_________________________
# [185, 80, 106]
# error at  25624
# Deleting :_________________________
# [80, 106, 62]
# error at  25624
# Deleting :_________________________
# [106, 62, 32]
# error at  25624
# Deleting :_________________________
# [62, 32, 423]
# error at  25624
# Deleting :_________________________
# [561, 5185, 141]
# error at  26027
# Deleting :_________________________
# [5185, 141, 14]
# error at  26027
# Deleting :_________________________
# [141, 14, 605]
# error at  26027
# Deleting :_________________________
# [14, 605, 57]
# error at  26027
# Deleting :_________________________
# [1634, 317, 422]
# error at  26072
# Deleting :_________________________
# [317, 422, 5193]
# error at  26072
# Deleting :_________________________
# [422, 5193, 5]
# error at  26072
# Deleting :_________________________
# [5193, 5, 5194]
# error at  26072
# Deleting :_________________________
# [1183, 26, 148]
# error at  26776
# Deleting :_________________________
# [26, 148, 2466]
# error at  26776
# Deleting :_________________________
# [148, 2466, 378]
# error at  26776
# Deleting :_________________________
# [2466, 378, 59]
# error at  26776
# Deleting :_________________________
# [2431, 93, 15]
# error at  28296
# Deleting :_________________________
# [93, 15, 1900]
# error at  28296
# Deleting :_________________________
# [15, 1900, 15]
# error at  28296
# Deleting :_________________________
# [1900, 15]
# error at  28296
# Deleting :_________________________
# [1900, 15, 5114]
# error at  28296
# Deleting :_________________________
# [15, 5114, 5]
# error at  28296
# Deleting :_________________________
# [5114, 5, 437]
# error at  28296
# Deleting :_________________________
# [185, 80, 106]
# error at  28301
# Deleting :_________________________
# [80, 106, 62]
# error at  28301
# Deleting :_________________________
# [106, 62, 32]
# error at  28301
# Deleting :_________________________
# [62, 32, 423]
# error at  28301
# Deleting :_________________________
# [561, 5185, 141]
# error at  28704
# Deleting :_________________________
# [5185, 141, 14]
# error at  28704
# Deleting :_________________________
# [141, 14, 605]
# error at  28704
# ...
# error at  53030
# Deleting :_________________________
# [2, 148, 9616]
# error at  53030
# Deleting :_________________________
# [148, 9616, 97]
# error at  53030
# Deleting :_________________________
# [9616, 97, 49]
# error at  53030
# Deleting :_________________________
# [31, 15, 3]
# error at  53077
# Deleting :_________________________
# [15, 3, 5886]
# error at  53077
# Deleting :_________________________
# [3, 5886, 9627]
# error at  53077
# Deleting :_________________________
# [5886, 9627, 311]
# error at  53077
# Deleting :_________________________
# [203, 4, 910]
# error at  53151
# Deleting :_________________________
# [4, 910, 9638]
# error at  53151
# Deleting :_________________________
# [910, 9638, 130]
# error at  53151
# Deleting :_________________________
# [9638, 130, 5616]
# error at  53151
# Deleting :_________________________
# [130, 5616, 9]
# error at  53152
# Deleting :_________________________
# [5616, 9, 88]
# error at  53152
# Deleting :_________________________
# [9, 88, 11]
# error at  53152
# Deleting :_________________________
# [88, 11, 9639]
# error at  53152
# Deleting :_________________________
# [9639, 3, 920]
# error at  53154
# Deleting :_________________________
# [3, 920, 1360]
# error at  53154
# Deleting :_________________________
# [920, 1360, 42]
# error at  53154
# Deleting :_________________________
# [1360, 42, 778]
# error at  53154
# Deleting :_________________________
# [492, 78, 11]
# error at  53317
# Deleting :_________________________
# [78, 11, 472]
# error at  53317
# Deleting :_________________________
# [11, 472, 74]
# error at  53317
# Deleting :_________________________
# [472, 74, 773]
# error at  53317
# Deleting :_________________________
# [102, 15, 29]
# error at  53384
# Deleting :_________________________
# [15, 29, 2093]
# error at  53384
# Deleting :_________________________
# [29, 2093, 780]
# error at  53384
# Deleting :_________________________
# [2093, 780, 970]
# error at  53384
# Deleting :_________________________
# [469, 80, 1368]
# error at  53479
# Deleting :_________________________
# [80, 1368, 6]
# error at  53479
# Deleting :_________________________
# [1368, 6, 5890]
# error at  53479
# Deleting :_________________________
# [6, 5890, 347]
# error at  53479
# Deleting :_________________________
# [299, 15, 20]
# error at  53505
# Deleting :_________________________
# [15, 20, 36]
# error at  53505
# Deleting :_________________________
# [20, 36, 11]
# error at  53505
# Deleting :_________________________
# [36, 11, 9675]
# error at  53505
# Deleting :_________________________
# [9692, 224, 608]
# error at  53671
# Deleting :_________________________
# [224, 608, 2896]
# error at  53671
# Deleting :_________________________
# [608, 2896, 2]
# error at  53671
# Deleting :_________________________
# [2896, 2, 3]
# error at  53671
# Deleting :_________________________
# [1, 920, 822]
# error at  53730
# Deleting :_________________________
# [920, 822, 58]
# error at  53730
# Deleting :_________________________
# [822, 58, 250]
# error at  53730
# Deleting :_________________________
# [58, 250, 9701]
# error at  53730
# Deleting :_________________________
# [250, 9701, 224]
# error at  53731
# Deleting :_________________________
# [9701, 224, 11]
# error at  53731
# Deleting :_________________________
# [224, 11, 9702]
# error at  53731
# Deleting :_________________________
# [11, 9702, 442]
# error at  53731
# Deleting :_________________________
# [5915, 295, 2]
# error at  53803
# Deleting :_________________________
# [295, 2, 1592]
# error at  53803
# Deleting :_________________________
# [2, 1592, 1]
# error at  53803
# Deleting :_________________________
# [1592, 1, 148]
# error at  53803
# Deleting :_________________________
# [148, 2858, 49]
# error at  53805
# Deleting :_________________________
# [2858, 49, 11]
# error at  53805
# Deleting :_________________________
# [49, 11, 99]
# error at  53805
# Deleting :_________________________
# [11, 99, 5916]
# error at  53805
# Deleting :_________________________
# [1, 5916, 492]
# error at  53829
# Deleting :_________________________
# [5916, 492, 113]
# error at  53829
# Deleting :_________________________
# [492, 113, 5919]
# error at  53829
# Deleting :_________________________
# [113, 5919, 1]
# error at  53829
# Deleting :_________________________
# [3403, 9708, 142]
# error at  53844
# Deleting :_________________________
# [9708, 142, 1592]
# error at  53844
# Deleting :_________________________
# [142, 1592, 1]
# error at  53844
# Deleting :_________________________
# [1592, 1, 9709]
# error at  53844
# Deleting :_________________________
# [35, 1765, 224]
# error at  53849
# Deleting :_________________________
# [1765, 224, 1407]
# error at  53849
# Deleting :_________________________
# [224, 1407, 8]
# error at  53849
# Deleting :_________________________
# [1407, 8, 215]
# error at  53849
# Deleting :_________________________
# [98, 70, 748]
# error at  53864
# Deleting :_________________________
# [70, 748, 5921]
# error at  53864
# Deleting :_________________________
# [748, 5921, 748]
# error at  53864
# Deleting :_________________________
# [5921, 748, 1]
# error at  53864
# Deleting :_________________________
# [275, 3402, 240]
# error at  53910
# Deleting :_________________________
# [3402, 240, 21]
# error at  53910
# Deleting :_________________________
# [240, 21, 833]
# error at  53910
# Deleting :_________________________
# [21, 833, 224]
# error at  53910
# Deleting :_________________________
# [21, 833, 224]
# error at  53910
# Deleting :_________________________
# [833, 224, 6]
# error at  53910
# Deleting :_________________________
# [224, 6, 374]
# error at  53910
# Deleting :_________________________
# [6, 374, 9717]
# error at  53910
# Deleting :_________________________
# [275, 3402, 240]
# error at  53964
# Deleting :_________________________
# [3402, 240, 763]
# error at  53964
# Deleting :_________________________
# [240, 763, 195]
# error at  53964
# Deleting :_________________________
# [763, 195, 9722]
# error at  53964
# Deleting :_________________________
# [195, 9722, 224]
# error at  53965
# Deleting :_________________________
# [9722, 224, 62]
# error at  53965
# Deleting :_________________________
# [224, 62, 1326]
# error at  53965
# Deleting :_________________________
# [62, 1326, 148]
# error at  53965
# Deleting :_________________________
# [62, 1326, 148]
# error at  53965
# Deleting :_________________________
# [1326, 148, 19]
# error at  53965
# Deleting :_________________________
# [148, 19, 3007]
# error at  53965
# Deleting :_________________________
# [19, 3007, 595]
# error at  53965
# Deleting :_________________________
# [715, 103, 3399]
# error at  54135
# Deleting :_________________________
# [103, 3399, 1883]
# error at  54135
# Deleting :_________________________
# [3399, 1883, 1]
# error at  54135
# Deleting :_________________________
# [1883, 1, 9744]
# error at  54135
# Deleting :_________________________
# [1, 963, 1765]
# error at  54179
# Deleting :_________________________
# [963, 1765, 6]
# error at  54179
# Deleting :_________________________
# [1765, 6, 374]
# error at  54179
# Deleting :_________________________
# [6, 374, 9746]
# error at  54179
# Deleting :_________________________
# [566, 418, 15]
# error at  54946
# Deleting :_________________________
# [418, 15, 2057]
# error at  54946
# Deleting :_________________________
# [15, 2057, 353]
# error at  54946
# Deleting :_________________________
# [2057, 353, 55]
# error at  54946
# Deleting :_________________________
# [371, 422, 224]
# error at  54953
# Deleting :_________________________
# [422, 224, 4]
# error at  54953
# Deleting :_________________________
# [224, 4, 1598]
# error at  54953
# Deleting :_________________________
# [4, 1598, 45]
# error at  54953
# Deleting :_________________________
# [5937, 200, 67]
# error at  55109
# Deleting :_________________________
# [200, 67, 609]
# error at  55109
# Deleting :_________________________
# [67, 609, 63]
# error at  55109
# Deleting :_________________________
# [609, 63, 787]
# error at  55109
# Deleting :_________________________
# [1, 920, 1097]
# error at  55240
# Deleting :_________________________
# [920, 1097, 287]
# error at  55240
# Deleting :_________________________
# [1097, 287, 49]
# error at  55240
# Deleting :_________________________
# [287, 49, 21]
# error at  55240
# Deleting :_________________________
# [70, 3405, 2]
# error at  55255
# Deleting :_________________________
# [3405, 2, 1592]
# error at  55255
# Deleting :_________________________
# [2, 1592, 1]
# error at  55255
# Deleting :_________________________
# [1592, 1, 9900]
# error at  55255
# Deleting :_________________________
# [920, 2430, 9902]
# error at  55270
# Deleting :_________________________
# [2430, 9902, 567]
# error at  55270
# Deleting :_________________________
# [9902, 567, 14]
# error at  55270
# Deleting :_________________________
# [567, 14, 131]
# error at  55270
# Deleting :_________________________
# [777, 1606, 103]
# error at  55289
# Deleting :_________________________
# [1606, 103, 9904]
# error at  55289
# Deleting :_________________________
# [103, 9904, 1]
# error at  55289
# Deleting :_________________________
# [9904, 1, 520]
# error at  55289
# Deleting :_________________________
# [23, 9910, 585]
# error at  55325
# Deleting :_________________________
# [9910, 585, 5881]
# error at  55325
# Deleting :_________________________
# [585, 5881, 1]
# error at  55325
# Deleting :_________________________
# [5881, 1, 2941]
# error at  55325
# Deleting :_________________________
# [1, 2941, 9911]
# error at  55326
# Deleting :_________________________
# [2941, 9911, 567]
# error at  55326
# Deleting :_________________________
# [9911, 567, 32]
# error at  55326
# Deleting :_________________________
# [567, 32, 2]
# error at  55326
# Deleting :_________________________
# [969, 34, 65, 1240, 1118]
# error at  55497
# Deleting :_________________________
# [34, 65, 1240, 1118, 34]
# error at  55497
# Deleting :_________________________
# [65, 1240, 1118, 34, 788]
# error at  55497
# Deleting :_________________________
# [1240, 1118, 34, 788, 579]
# error at  55497
# Deleting :_________________________
# [9971, 9972, 70]
# error at  55734
# Deleting :_________________________
# [9972, 70, 2]
# error at  55734
# Deleting :_________________________
# [70, 2, 28]
# error at  55734
# Deleting :_________________________
# [2, 28, 31]
# error at  55734
# Deleting :_________________________
# [54, 15, 307]
# error at  55741
# Deleting :_________________________
# [15, 307, 150]
# error at  55741
# Deleting :_________________________
# [307, 150, 9973]
# error at  55741
# Deleting :_________________________
# [150, 9973, 307]
# error at  55741
# Deleting :_________________________
# [74, 1606, 9990]
# error at  55856
# Deleting :_________________________
# [1606, 9990, 9991]
# error at  55856
# Deleting :_________________________
# [9990, 9991, 127]
# error at  55856
# Deleting :_________________________
# [9991, 127, 1]
# error at  55856
# Deleting :_________________________
# [3, 2563, 70]
# error at  55938
# Deleting :_________________________
# [2563, 70, 408]
# error at  55938
# Deleting :_________________________
# [70, 408, 697]
# error at  55938
# Deleting :_________________________
# [408, 697, 5951]
# error at  55938
# Deleting :_________________________
# [497, 49, 10009]
# error at  56058
# Deleting :_________________________
# [49, 10009, 772]
# error at  56058
# Deleting :_________________________
# [10009, 772, 10]
# error at  56058
# Deleting :_________________________
# [772, 10, 567]
# error at  56058
# Deleting :_________________________
# [257, 116, 73]
# error at  56371
# Deleting :_________________________
# [116, 73, 1755]
# error at  56371
# Deleting :_________________________
# [73, 1755, 3]
# error at  56371
# Deleting :_________________________
# [1755, 3, 1347]
# error at  56371
# Deleting :_________________________
# [768, 1947, 31]
# error at  56387
# Deleting :_________________________
# [1947, 31, 15]
# error at  56387
# Deleting :_________________________
# [31, 15, 51]
# error at  56387
# Deleting :_________________________
# [15, 51, 1666]
# error at  56387
# Deleting :_________________________
# [15, 51, 1666]
# error at  56387
# Deleting :_________________________
# [51, 1666, 1032]
# error at  56387
# Deleting :_________________________
# [1666, 1032, 7]
# error at  56387
# Deleting :_________________________
# [1032, 7, 10067]
# error at  56387
# Deleting :_________________________
# [305, 10072, 49]
# error at  56409
# Deleting :_________________________
# [10072, 49, 981]
# error at  56409
# Deleting :_________________________
# [49, 981, 708]
# error at  56409
# Deleting :_________________________
# [981, 708, 1214]
# error at  56409
# Deleting :_________________________
# [4, 10082, 10083]
# error at  56469
# Deleting :_________________________
# [10082, 10083, 981]
# error at  56469
# Deleting :_________________________
# [10083, 981, 36]
# error at  56469
# Deleting :_________________________
# [981, 36, 709]
# error at  56469
# Deleting :_________________________
# [10086, 924, 167]
# error at  56494
# Deleting :_________________________
# [924, 167, 11]
# error at  56494
# Deleting :_________________________
# [167, 11, 331]
# error at  56494
# Deleting :_________________________
# [11, 331, 1]
# error at  56494
# Deleting :_________________________
# [254, 920, 930]
# error at  56577
# Deleting :_________________________
# [920, 930, 1241]
# error at  56577
# Deleting :_________________________
# [930, 1241, 258]
# error at  56577
# Deleting :_________________________
# [1241, 258, 10094]
# error at  56577
# Deleting :_________________________
# [763, 195, 5811]
# error at  56685
# Deleting :_________________________
# [195, 5811, 1346]
# error at  56685
# Deleting :_________________________
# [5811, 1346, 36]
# error at  56685
# Deleting :_________________________
# [1346, 36, 1]
# error at  56685
# Deleting :_________________________
# [63, 90, 26]
# error at  56690
# Deleting :_________________________
# [90, 26, 4]
# error at  56690
# Deleting :_________________________
# [26, 4, 36]
# error at  56690
# Deleting :_________________________
# [4, 36, 11]
# error at  56690
# Deleting :_________________________
# [3401, 276, 106]
# error at  57580
# Deleting :_________________________
# [276, 106, 38]
# error at  57580
# Deleting :_________________________
# [106, 38, 971]
# error at  57580
# Deleting :_________________________
# [38, 971, 21]
# error at  57580
# Deleting :_________________________
# [1506, 1411, 15]
# error at  57778
# Deleting :_________________________
# [1411, 15, 6]
# error at  57778
# Deleting :_________________________
# [15, 6, 304]
# error at  57778
# Deleting :_________________________
# [6, 304, 42]
# error at  57778
# Deleting :_________________________
# [1506, 1411, 439]
# error at  57801
# Deleting :_________________________
# [1411, 439, 1794]
# error at  57801
# Deleting :_________________________
# [439, 1794, 156]
# error at  57801
# Deleting :_________________________
# [1794, 156, 3411]
# error at  57801
# Deleting :_________________________
# [481, 10293, 492]
# error at  58136
# Deleting :_________________________
# [10293, 492, 8]
# error at  58136
# Deleting :_________________________
# [492, 8, 2775]
# error at  58136
# Deleting :_________________________
# [8, 2775, 10294]
# error at  58136
# Deleting :_________________________
# [1, 148, 2564]
# error at  58144
# Deleting :_________________________
# [148, 2564, 6]
# error at  58144
# Deleting :_________________________
# [2564, 6, 10297]
# error at  58144
# Deleting :_________________________
# [6, 10297, 407]
# error at  58144
# Deleting :_________________________
# [79, 10314, 10315]
# error at  58238
# Deleting :_________________________
# [10314, 10315, 11]
# error at  58238
# Deleting :_________________________
# [10315, 11, 127]
# error at  58238
# Deleting :_________________________
# [11, 127, 1]
# error at  58238
# Deleting :_________________________
# [942, 484, 336]
# error at  58426
# Deleting :_________________________
# [484, 336, 694]
# error at  58426
# Deleting :_________________________
# [336, 694, 10338]
# error at  58426
# Deleting :_________________________
# [694, 10338, 10339]
# error at  58426
# Deleting :_________________________
# [1, 2389, 40]
# error at  58444
# Deleting :_________________________
# [2389, 40, 484]
# error at  58444
# Deleting :_________________________
# [40, 484, 3027]
# error at  58444
# Deleting :_________________________
# [484, 3027, 224]
# error at  58444
# Deleting :_________________________
# [1745, 10361, 396]
# error at  58563
# Deleting :_________________________
# [10361, 396, 10362]
# error at  58563
# Deleting :_________________________
# [396, 10362, 10363]
# error at  58563
# Deleting :_________________________
# [10362, 10363, 269]
# error at  58563
# Deleting :_________________________
# Total deletion:  1650

# %%
print(sequences[564])
print(sequences.size)
# Out:
# [2591, 238, 1394, 1]
# 58585

# %%
sequences = np.array(sequences.tolist())
sequences
# Out:
# array([[10369,  2568,    49,    20],
#        [ 2568,    49,    20,     1],
#        [   49,    20,     1,    18],
#        ...,
#        [ 1329,   484,     1, 10368],
#        [  484,     1, 10368,     4],
#        [    1, 10368,     4, 10370]])

# %%
sequences.shape
# Out:
# (58585, 4)

# %%
# separate into input and output
sequences = array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
y = to_categorical(y, num_classes=vocab_size)
seq_length = X.shape[1]

# %%
# define model
model = Sequential()
model.add(Embedding(vocab_size, 50, input_length=seq_length))
model.add(GRU(100, return_sequences=True))
model.add(GRU(100))
model.add(Dense(100, activation='relu'))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit model
csv_logger = CSVLogger('training_3_1.log')
model.fit(X, y, batch_size=500, epochs=1000, callbacks=[csv_logger])

# %%
# save the model to file
model.save('model_3_1.h5')
#model.save(r'C:\Users\OFR\Desktop\Thesis work\version three\model_3_1.h5')
# save the tokenizer
dump(tokenizer, open(r'tokenizer_3_1.pkl', 'wb'))
