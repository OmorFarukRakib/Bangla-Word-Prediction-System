# %%
import string
import io
import codecs

# %%
# load doc into memory
def load_doc(filename):
    with io.open(filename, 'r', encoding='utf8') as f:
        text = f.read()
    return text

# %%
# turn a doc into clean tokens
def clean_doc(doc):
    # replace '--' with a space ' '
    doc = doc.replace('?', ' ? ')
    doc = doc.replace('।', ' । ')
    doc = doc.replace(',', ' । ')
    doc = doc.replace('-', ' । ')
    doc = doc.replace('(', ' । ')
    doc = doc.replace(')', ' । ')
    doc = doc.replace('{', ' । ')
    doc = doc.replace('}', ' । ')
    doc = doc.replace('[', ' । ')
    doc = doc.replace(']', ' । ')
    doc = doc.replace('*', ' ')
    doc = doc.replace('^', ' ')
    doc = doc.replace('#', ' ')
    doc = doc.replace('~', ' ')
    doc = doc.replace('`', ' ')
    doc = doc.replace('/', ' ')
    doc = doc.replace('_', ' ')
    doc = doc.replace('’', ' ')
    doc = doc.replace('‘', ' ')
    doc = doc.replace('.', ' । ')
    
    
    # split into tokens by white space
    tokens = doc.split()
    # remove punctuation from each token
    #table = str.maketrans('', '', string.punctuation)
    #tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    #tokens = [word for word in tokens if word.isalpha()]
    # make lower case
    tokens = [word.lower() for word in tokens]
    return tokens

# %%
# save tokens to file, one dialog per line
def save_doc(lines, filename):
	data = '\n'.join(lines)
	file = open(filename, 'w', encoding='utf8')
	file.write(data)
	file.close()

# %%
# load document
in_filename = r'C:\Users\OFR\Desktop\Thesis work\version four\Main Dataset.txt'
doc = load_doc(in_filename)
print(doc[:200])
# Out:
# ﻿কর্পোরেশনের দোষ তো আছে । কিন্তু আমরা যে সুযোগ বুঝে হাজার হাজার কোটি টাকার ট্যাক্স ফাকি দিয়ে আসছি সেটাও আমরা জানি । এই ভয়ে সবাই স্যু করার সাহস পাবেনা । কারণ উলটা স্যু সে নিজে খেয়ে যাবে । আপনি স্যু করে

# %%
# clean document

tokens = clean_doc(doc)
#tokens = doc
print(tokens[:200])
print('Total Tokens: %d' % len(tokens))
print('Unique Tokens: %d' % len(set(tokens)))
# Out:
# ['\ufeffকর্পোরেশনের', 'দোষ', 'তো', 'আছে', '।', 'কিন্তু', 'আমরা', 'যে', 'সুযোগ', 'বুঝে', 'হাজার', 'হাজার', 'কোটি', 'টাকার', 'ট্যাক্স', 'ফাকি', 'দিয়ে', 'আসছি', 'সেটাও', 'আমরা', 'জানি', '।', 'এই', 'ভয়ে', 'সবাই', 'স্যু', 'করার', 'সাহস', 'পাবেনা', '।', 'কারণ', 'উলটা', 'স্যু', 'সে', 'নিজে', 'খেয়ে', 'যাবে', '।', 'আপনি', 'স্যু', 'করে', 'দৃষ্টান্ত', 'শুরু', 'করে', 'দিলেই', 'পারেন', '।', 'অন্যরাও', 'ধীরে', 'ধীরে', 'উৎসাহিত', 'হবে', '।', 'পরিবর্তন', 'আসবে', '।', 'আমাদের', 'সবার', 'মনেই', 'বিদেশে', 'পড়তে', 'যাওয়ার', 'সুপ্ত', 'কিন্তু', 'তীব্র', 'আকাঙ্ক্ষা', 'কাজ', 'করে', '।', 'বিদেশে', 'পড়ার', 'ক্ষেত্রে', 'খরচের', 'ব্যাপারটা', 'মাথায়', 'আসে', 'বলেই', 'আমরা', 'অনেকেই', 'চাই', 'বৃত্তি', 'বা', 'স্কলারশিপ', 'এর', 'ব্যাপারে', 'খোঁজ', 'নিতে', '।', 'পুরো', 'প্রক্রিয়াটি', 'অনেক', 'বিশদ', 'হওয়ায়', 'আমার', 'ক্ষুদ্র', 'অভিজ্ঞতা', 'থেকে', 'আমি', 'চেষ্টা', 'করবো', 'আমার', 'শিক্ষার্থীদের', 'কিছুটা', 'জানানোর', '।', 'আমার', 'লেখাটা', 'টি', 'পর্বে', 'থাকবে', '।', 'আজ', 'প্রথম', 'পর্ব', '।', 'আজকে', 'আমি', 'আলোচনা', 'করবো', 'বাংলাদেশি', 'শিক্ষার্থীদের', 'জন্য', 'বিদেশে', 'পড়তে', 'যাওয়ার', 'স্কলারশিপ', 'নিয়ে', '।', 'পরবর্তীতে', 'বিভিন্ন', 'দেশে', 'এপ্লাই', 'করার', 'প্রক্রিয়া', 'ক্রেডিট', 'ট্রান্সফার', 'বিশ্ববিদ্যালয়ের', 'ইন', 'হাউস', 'স্কলারশিপ', 'ইত্যাদি', 'বিষয়ে', 'আলোচনা', 'করবো', '।', 'যুক্তরাজ্যে', 'পড়তে', 'যাওয়ার', 'জন্য', 'ব্রিটিশ', 'সরকারের', 'বৃত্তি', 'এটি', '।', 'অত্যন্ত', 'সম্মানজনক', 'এবং', 'সেইসাথে', 'খুবই', 'প্রতিযোগিতামূলক', '।', 'সাধারণত', 'যারা', 'শিক্ষকতা', 'পেশায়', 'নিয়োজিত', 'থাকেন', 'তারা', 'এটা', 'পেয়ে', 'থাকেন', 'তবে', 'শিক্ষকই', 'হতে', 'হবে', 'এমন', 'কোনো', 'বাধ্যবাধকতা', 'নেই', '।', 'আপনার', 'বয়স', 'কম', 'হলে', 'এবং', 'আপনার', 'ব্যাচেলর', 'ডিগ্রিতে', 'নম্বর', 'থাকলেই', 'আপনি', 'এই', 'স্কলারশিপের', 'জন্য', 'এপ্লাই', 'করতে', 'পারবেন', '।', 'এক্ষেত্রে', 'যেটা']
# Total Tokens: 176559
# Unique Tokens: 22561

# %%
# organize into sequences of tokens
length = 1 + 1
sequences = list()
for i in range(length, len(tokens)):
	# select sequence of tokens
	seq = tokens[i-length:i]
	# convert into a line
	line = ' '.join(seq)
	# store
	sequences.append(line)
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 176557

# %%
sequences
# Out:
# ['\ufeffকর্পোরেশনের দোষ',
#  'দোষ তো',
#  'তো আছে',
#  'আছে ।',
#  '। কিন্তু',
#  'কিন্তু আমরা',
#  'আমরা যে',
#  'যে সুযোগ',
#  'সুযোগ বুঝে',
#  'বুঝে হাজার',
#  'হাজার হাজার',
#  'হাজার কোটি',
#  'কোটি টাকার',
#  'টাকার ট্যাক্স',
#  'ট্যাক্স ফাকি',
#  'ফাকি দিয়ে',
#  'দিয়ে আসছি',
#  'আসছি সেটাও',
#  'সেটাও আমরা',
#  'আমরা জানি',
#  'জানি ।',
#  '। এই',
#  'এই ভয়ে',
#  'ভয়ে সবাই',
#  'সবাই স্যু',
#  'স্যু করার',
#  'করার সাহস',
#  'সাহস পাবেনা',
#  'পাবেনা ।',
#  '। কারণ',
#  'কারণ উলটা',
#  'উলটা স্যু',
#  'স্যু সে',
#  'সে নিজে',
#  'নিজে খেয়ে',
#  'খেয়ে যাবে',
#  'যাবে ।',
#  '। আপনি',
#  'আপনি স্যু',
#  'স্যু করে',
#  'করে দৃষ্টান্ত',
#  'দৃষ্টান্ত শুরু',
#  'শুরু করে',
#  'করে দিলেই',
#  'দিলেই পারেন',
#  'পারেন ।',
#  '। অন্যরাও',
#  'অন্যরাও ধীরে',
#  'ধীরে ধীরে',
#  'ধীরে উৎসাহিত',
#  'উৎসাহিত হবে',
#  'হবে ।',
#  '। পরিবর্তন',
#  'পরিবর্তন আসবে',
#  'আসবে ।',
#  '। আমাদের',
#  'আমাদের সবার',
#  'সবার মনেই',
#  'মনেই বিদেশে',
#  'বিদেশে পড়তে',
#  'পড়তে যাওয়ার',
#  'যাওয়ার সুপ্ত',
#  'সুপ্ত কিন্তু',
#  'কিন্তু তীব্র',
#  'তীব্র আকাঙ্ক্ষা',
#  'আকাঙ্ক্ষা কাজ',
#  'কাজ করে',
#  'করে ।',
#  '। বিদেশে',
#  'বিদেশে পড়ার',
#  'পড়ার ক্ষেত্রে',
#  'ক্ষেত্রে খরচের',
#  'খরচের ব্যাপারটা',
#  'ব্যাপারটা মাথায়',
#  'মাথায় আসে',
#  'আসে বলেই',
#  'বলেই আমরা',
#  'আমরা অনেকেই',
#  'অনেকেই চাই',
#  'চাই বৃত্তি',
#  'বৃত্তি বা',
#  'বা স্কলারশিপ',
#  'স্কলারশিপ এর',
#  'এর ব্যাপারে',
#  'ব্যাপারে খোঁজ',
#  'খোঁজ নিতে',
#  'নিতে ।',
#  '। পুরো',
#  'পুরো প্রক্রিয়াটি',
#  'প্রক্রিয়াটি অনেক',
#  'অনেক বিশদ',
#  'বিশদ হওয়ায়',
#  'হওয়ায় আমার',
#  'আমার ক্ষুদ্র',
#  'ক্ষুদ্র অভিজ্ঞতা',
#  'অভিজ্ঞতা থেকে',
#  'থেকে আমি',
#  'আমি চেষ্টা',
#  'চেষ্টা করবো',
#  'করবো আমার',
#  'আমার শিক্ষার্থীদের',
#  'শিক্ষার্থীদের কিছুটা',
#  'কিছুটা জানানোর',
#  'জানানোর ।',
#  '। আমার',
#  'আমার লেখাটা',
#  'লেখাটা টি',
#  'টি পর্বে',
#  'পর্বে থাকবে',
#  'থাকবে ।',
#  '। আজ',
#  'আজ প্রথম',
#  'প্রথম পর্ব',
#  'পর্ব ।',
#  '। আজকে',
#  'আজকে আমি',
#  'আমি আলোচনা',
#  'আলোচনা করবো',
#  'করবো বাংলাদেশি',
#  'বাংলাদেশি শিক্ষার্থীদের',
#  'শিক্ষার্থীদের জন্য',
#  'জন্য বিদেশে',
#  'বিদেশে পড়তে',
#  'পড়তে যাওয়ার',
#  'যাওয়ার স্কলারশিপ',
#  'স্কলারশিপ নিয়ে',
#  'নিয়ে ।',
#  '। পরবর্তীতে',
#  'পরবর্তীতে বিভিন্ন',
#  'বিভিন্ন দেশে',
#  'দেশে এপ্লাই',
#  'এপ্লাই করার',
#  'করার প্রক্রিয়া',
#  'প্রক্রিয়া ক্রেডিট',
#  'ক্রেডিট ট্রান্সফার',
#  'ট্রান্সফার বিশ্ববিদ্যালয়ের',
#  'বিশ্ববিদ্যালয়ের ইন',
#  'ইন হাউস',
#  'হাউস স্কলারশিপ',
#  'স্কলারশিপ ইত্যাদি',
#  'ইত্যাদি বিষয়ে',
#  'বিষয়ে আলোচনা',
#  'আলোচনা করবো',
#  'করবো ।',
#  '। যুক্তরাজ্যে',
#  'যুক্তরাজ্যে পড়তে',
#  'পড়তে যাওয়ার',
#  'যাওয়ার জন্য',
#  'জন্য ব্রিটিশ',
#  'ব্রিটিশ সরকারের',
#  'সরকারের বৃত্তি',
#  'বৃত্তি এটি',
#  'এটি ।',
#  '। অত্যন্ত',
#  'অত্যন্ত সম্মানজনক',
#  'সম্মানজনক এবং',
#  'এবং সেইসাথে',
#  'সেইসাথে খুবই',
#  'খুবই প্রতিযোগিতামূলক',
#  'প্রতিযোগিতামূলক ।',
#  '। সাধারণত',
#  'সাধারণত যারা',
#  'যারা শিক্ষকতা',
#  'শিক্ষকতা পেশায়',
#  'পেশায় নিয়োজিত',
#  'নিয়োজিত থাকেন',
#  'থাকেন তারা',
#  'তারা এটা',
#  'এটা পেয়ে',
#  'পেয়ে থাকেন',
#  'থাকেন তবে',
#  'তবে শিক্ষকই',
#  'শিক্ষকই হতে',
#  'হতে হবে',
#  'হবে এমন',
#  'এমন কোনো',
#  'কোনো বাধ্যবাধকতা',
#  'বাধ্যবাধকতা নেই',
#  'নেই ।',
#  '। আপনার',
#  'আপনার বয়স',
#  'বয়স কম',
#  'কম হলে',
#  'হলে এবং',
#  'এবং আপনার',
#  'আপনার ব্যাচেলর',
#  'ব্যাচেলর ডিগ্রিতে',
#  'ডিগ্রিতে নম্বর',
#  'নম্বর থাকলেই',
#  'থাকলেই আপনি',
#  'আপনি এই',
#  'এই স্কলারশিপের',
#  'স্কলারশিপের জন্য',
#  'জন্য এপ্লাই',
#  'এপ্লাই করতে',
#  'করতে পারবেন',
#  'পারবেন ।',
#  '। এক্ষেত্রে',
#  'এক্ষেত্রে যেটা',
#  'যেটা লাগবে',
#  'লাগবে সেটা',
#  'সেটা হলো',
#  'হলো যুক্তরাজ্যের',
#  'যুক্তরাজ্যের কোনো',
#  'কোনো একটি',
#  'একটি বিশ্ববিদ্যালয়ে',
#  'বিশ্ববিদ্যালয়ে ভর্তির',
#  'ভর্তির আনকন্ডিশনাল',
#  'আনকন্ডিশনাল অফার',
#  'অফার লেটার',
#  'লেটার ।',
#  '। গুগল',
#  'গুগল করলেই',
#  'করলেই লিস্ট',
#  'লিস্ট পাবেন',
#  'পাবেন ব্রিটেনের',
#  'ব্রিটেনের কোন',
#  'কোন কোন',
#  'কোন বিশ্ববিদ্যালয়',
#  'বিশ্ববিদ্যালয় কমনওয়েলথের',
#  'কমনওয়েলথের আওতায়',
#  'আওতায় আছে',
#  'আছে ।',
#  '। তারমানে',
#  'তারমানে আপনার',
#  'আপনার আগে',
#  'আগে বিশ্ববিদ্যালয়ে',
#  'বিশ্ববিদ্যালয়ে ওদের',
#  'ওদের নিজস্ব',
#  'নিজস্ব সিস্টেমে',
#  'সিস্টেমে এপ্লাই',
#  'এপ্লাই করতে',
#  'করতে হবে',
#  'হবে আর',
#  'আর অফার',
#  'অফার লেটার',
#  'লেটার পেলেই',
#  'পেলেই আপনি',
#  'আপনি কমনওয়েলথের',
#  'কমনওয়েলথের জন্য',
#  'জন্য এপ্লাই',
#  'এপ্লাই করতে',
#  'করতে পারবেন',
#  'পারবেন ।',
#  '। দুটোর',
#  'দুটোর ক্ষেত্রেই',
#  'ক্ষেত্রেই এপ্লিকেশন',
#  'এপ্লিকেশন প্রোসেস',
#  'প্রোসেস ভিন্ন',
#  'ভিন্ন ।',
#  '। এছাড়া',
#  'এছাড়া স্কলারশিপের',
#  'স্কলারশিপের ক্ষেত্রেও',
#  'ক্ষেত্রেও আইল্টসের',
#  'আইল্টসের স্কোর',
#  'স্কোর আপনার',
#  'আপনার জন্য',
#  'জন্য একটা',
#  'একটা ফ্যাক্টর',
#  'ফ্যাক্টর হবে',
#  'হবে ।',
#  '। কমনওয়েলথ',
#  'কমনওয়েলথ সাধারণত',
#  'সাধারণত ওপেন',
#  'ওপেন হয়',
#  'হয় নভেম্বরের',
#  'নভেম্বরের দিকে',
#  'দিকে ।',
#  '। সময়',
#  'সময় থাকে',
#  'থাকে ২',
#  '২ মাসের',
#  'মাসের মতো',
#  'মতো ।',
#  '। এটাও',
#  'এটাও কমনওয়েলথের',
#  'কমনওয়েলথের মতই',
#  'মতই কিন্তু',
#  'কিন্তু এটার',
#  'এটার ফাণ্ডিং',
#  'ফাণ্ডিং অর্ধেক',
#  'অর্ধেক যেই',
#  'যেই বিশ্ববিদ্যালয়',
#  'বিশ্ববিদ্যালয় এফিলিয়েটেড',
#  'এফিলিয়েটেড সেটা',
#  'সেটা দিবে',
#  'দিবে আর',
#  'আর বাকি',
#  'বাকি অর্ধেক',
#  'অর্ধেক দিবে',
#  'দিবে কমনওয়েলথ',
#  'কমনওয়েলথ স্কলারশিপ',
#  'স্কলারশিপ কমিটি',
#  'কমিটি ।',
#  '। বাকিসব',
#  'বাকিসব ক্রাইটেরিয়া',
#  'ক্রাইটেরিয়া একই',
#  'একই ।',
#  '। তবে',
#  'তবে বিশ্ববিদ্যালয়ের',
#  'বিশ্ববিদ্যালয়ের একটা',
#  'একটা তালিকা',
#  'তালিকা থাকে',
#  'থাকে যে',
#  'যে কোন',
#  'কোন কোন',
#  'কোন বিশ্ববিদ্যালয়',
#  'বিশ্ববিদ্যালয় এই',
#  'এই শেয়ারড',
#  'শেয়ারড প্রোগ্রামের',
#  'প্রোগ্রামের আওতায়',
#  'আওতায় ।',
#  '। যুক্তরাজ্যে',
#  'যুক্তরাজ্যে পড়তে',
#  'পড়তে যাওয়ার',
#  'যাওয়ার জন্য',
#  'জন্য ব্রিটিশ',
#  'ব্রিটিশ সরকারের',
#  'সরকারের বৃত্তি',
#  'বৃত্তি ।',
#  '। সাধারণত',
#  'সাধারণত এনজিও',
#  'এনজিও কর্মী',
#  'কর্মী সরকারী',
#  'সরকারী চাকুরে',
#  'চাকুরে বাংলাদেশ',
#  'বাংলাদেশ ব্যাংকের',
#  'ব্যাংকের কর্মকর্তা',
#  'কর্মকর্তা উদ্যোক্তা',
#  'উদ্যোক্তা এদের',
#  'এদের জন্য',
#  'জন্য এই',
#  'এই বৃত্তি',
#  'বৃত্তি ।',
#  '। আপনার',
#  'আপনার চাকরি',
#  'চাকরি যদি',
#  'যদি দুই',
#  'দুই বছর',
#  'বছর হয়',
#  'হয় তাহলে',
#  'তাহলে এটার',
#  'এটার জন্য',
#  'জন্য এপ্লাই',
#  'এপ্লাই করতে',
#  'করতে পারবেন',
#  'পারবেন ।',
#  '। ক্রাইটেরিয়া',
#  'ক্রাইটেরিয়া একই',
#  'একই রকম',
#  'রকম ।',
#  '। আইল্টসে',
#  'আইল্টসে ভালো',
#  'ভালো স্কোর',
#  'স্কোর আর',
#  'আর ইউকের',
#  'ইউকের বিশ্ববিদ্যালয়',
#  'বিশ্ববিদ্যালয় থেকে',
#  'থেকে আনকন্ডিশনাল',
#  'আনকন্ডিশনাল অফার',
#  'অফার লেটার',
#  'লেটার লাগবে',
#  'লাগবে ।',
#  '। মার্কিন',
#  'মার্কিন সরকারের',
#  'সরকারের বৃত্তি',
#  'বৃত্তি ।',
#  '। দারুণ',
#  'দারুণ প্রেস্টিজিয়াস',
#  'প্রেস্টিজিয়াস এবং',
#  'এবং আর্থিক',
#  'আর্থিক দিক',
#  'দিক থেকেও',
#  'থেকেও বেশ',
#  'বেশ লাভজনক',
#  'লাভজনক ।',
#  '। মূল',
#  'মূল বৃত্তিটির',
#  'বৃত্তিটির নাম',
#  'নাম হলো',
#  'হলো ফুলব্রাইট',
#  'ফুলব্রাইট ফরেন',
#  'ফরেন স্টুডেন্ট',
#  'স্টুডেন্ট প্রোগ্রাম',
#  'প্রোগ্রাম ।',
#  '। এটার',
#  'এটার ক্ষেত্রে',
#  'ক্ষেত্রে আলাদাভাবে',
#  'আলাদাভাবে কোনো',
#  'কোনো বিশ্ববিদ্যালয়ে',
#  'বিশ্ববিদ্যালয়ে এপ্লাই',
#  'এপ্লাই করতে',
#  'করতে হবেনা',
#  'হবেনা ।',
#  '। ফুলব্রাইটে',
#  'ফুলব্রাইটে এপ্লাই',
#  'এপ্লাই করলেই',
#  'করলেই হবে',
#  'হবে ।',
#  '। যদি',
#  'যদি আপনি',
#  'আপনি বৃত্তির',
#  'বৃত্তির জন্য',
#  'জন্য মনোনীত',
#  'মনোনীত হোন',
#  'হোন তাহলে',
#  'তাহলে তারাই',
#  'তারাই আপনাকে',
#  'আপনাকে বিশ্ববিদ্যালয়',
#  'বিশ্ববিদ্যালয় নির্ধারণ',
#  'নির্ধারণ করে',
#  'করে দিবে',
#  'দিবে ।',
#  '। ইয়োরোপ',
#  'ইয়োরোপ ঘুরে',
#  'ঘুরে বেড়ানোর',
#  'বেড়ানোর জন্য',
#  'জন্য এর',
#  'এর চাইতে',
#  'চাইতে ভালো',
#  'ভালো স্কলারশিপ',
#  'স্কলারশিপ আর',
#  'আর হয়না',
#  'হয়না ।',
#  '। বিশেষ',
#  'বিশেষ করে',
#  'করে সায়েন্স',
#  'সায়েন্স এন্ড',
#  'এন্ড টেকনোলজিতে',
#  'টেকনোলজিতে যারা',
#  'যারা পড়ছেন',
#  'পড়ছেন তাদের',
#  'তাদের জন্য',
#  'জন্য এটা',
#  'এটা বেশ',
#  'বেশ লিউক্রেটিভ',
#  'লিউক্রেটিভ ।',
#  '। সিজিপিএ',
#  'সিজিপিএ ভালো',
#  'ভালো থাকা',
#  'থাকা লাগবে',
#  'লাগবে ।',
#  '। এই',
#  'এই স্কলারশিপের',
#  'স্কলারশিপের মজা',
#  'মজা হলো',
#  'হলো ওরা',
#  'ওরা আ',
#  'আ পনাকে',
#  'পনাকে ইয়োরোপের',
#  'ইয়োরোপের দুটো',
#  'দুটো দেশের',
#  'দেশের দুই',
#  'দুই বিশ্ববিদ্যালয়ে',
#  'বিশ্ববিদ্যালয়ে যৌথভাবে',
#  'যৌথভাবে দুই',
#  'দুই বছরের',
#  'বছরের মাস্টার্স',
#  'মাস্টার্স ডিগ্রি',
#  'ডিগ্রি করাবে',
#  'করাবে ।',
#  '। বৃত্তির',
#  'বৃত্তির পরিমাণ',
#  'পরিমাণ বেশ',
#  'বেশ ভালো',
#  'ভালো ।',
#  '। কোনো',
#  'কোনো চাকরির',
#  'চাকরির অভিজ্ঞতা',
#  'অভিজ্ঞতা লাগবেনা',
#  'লাগবেনা ।',
#  '। বিশ্বের',
#  'বিশ্বের যেকোনো',
#  'যেকোনো বিশ্ববিদ্যালয়',
#  'বিশ্ববিদ্যালয় থেকে',
#  'থেকে আপনি',
#  'আপনি আনকন্ডিশনাল',
#  'আনকন্ডিশনাল অফার',
#  'অফার লেটার',
#  'লেটার পেলে',
#  'পেলে আপনি',
#  'আপনি এটায়',
#  'এটায় এপ্লাই',
#  'এপ্লাই করতে',
#  'করতে পারবেন',
#  'পারবেন ।',
#  '। আইল্টস',
#  'আইল্টস দেওয়া',
#  'দেওয়া লাগবে',
#  'লাগবে ।',
#  '। বিশ্ববিদ্যালয়',
#  'বিশ্ববিদ্যালয় অফার',
#  'অফার পাওয়ার',
#  'পাওয়ার পর',
#  'পর আলদাভাবে',
#  'আলদাভাবে এপ্লাই',
#  'এপ্লাই করতে',
#  'করতে হবে',
#  'হবে ।',
#  '। সাধারণত',
#  'সাধারণত জানুয়ারি',
#  'জানুয়ারি ফেব্রুয়ারিতে',
#  'ফেব্রুয়ারিতে ওপেন',
#  'ওপেন হয়ে',
#  'হয়ে এপ্রিল',
#  'এপ্রিল পর্যন্ত',
#  'পর্যন্ত সময়',
#  'সময় থাকে',
#  'থাকে ।',
#  '। বিশ্বের',
#  'বিশ্বের ভালো',
#  'ভালো র\u200d্যাংকের',
#  'র\u200d্যাংকের বিশ্ববিদ্যালয়ে',
#  'বিশ্ববিদ্যালয়ে ভর্তি',
#  'ভর্তি হয়ে',
#  'হয়ে অফার',
#  'অফার লেটার',
#  'লেটার নিয়ে',
#  'নিয়ে এই',
#  'এই স্কলারশিপে',
#  'স্কলারশিপে এপ্লাই',
#  'এপ্লাই করতে',
#  'করতে হয়',
#  'হয় ।',
#  '। সাধারণত',
#  'সাধারণত উন্নয়ন',
#  'উন্নয়ন বিষয়ক',
#  'বিষয়ক পড়ালেখার',
#  'পড়ালেখার জন্য',
#  'জন্য এই',
#  'এই বৃত্তি',
#  'বৃত্তি দেওয়া',
#  'দেওয়া হয়',
#  'হয় ।',
#  '। দারুণ',
#  'দারুণ একটা',
#  'একটা সিভি',
#  'সিভি লাগবে',
#  'লাগবে ।',
#  '। ফরম্যাট',
#  'ফরম্যাট অনেকেই',
#  'অনেকেই দিয়ে',
#  'দিয়ে দেয়',
#  'দেয় যেমন',
#  'যেমন ইরেসমাসে',
#  'ইরেসমাসে আপনাকে',
#  'আপনাকে সিভি',
#  'সিভি ফরম্যাট',
#  'ফরম্যাট ওরাই',
#  'ওরাই দিয়ে',
#  'দিয়ে দিবে',
#  'দিবে ।',
#  '। বাকিগুলোর',
#  'বাকিগুলোর ক্ষেত্রে',
#  'ক্ষেত্রে সিভি',
#  'সিভি হবে',
#  'হবে সিম্পল',
#  'সিম্পল কিন্তু',
#  'কিন্তু বেশ',
#  'বেশ ঝকঝকে',
#  'ঝকঝকে ।',
#  '। মিথ্যা',
#  'মিথ্যা কোনো',
#  'কোনো ইনফরমেশন',
#  'ইনফরমেশন দেওয়া',
#  'দেওয়া যাবেনা',
#  'যাবেনা ।',
#  '। আপনার',
#  'আপনার বিশ্ববিদ্যালয়ের',
#  'বিশ্ববিদ্যালয়ের থিসিস',
#  'থিসিস সুপারভাইজর',
#  'সুপারভাইজর বা',
#  'বা শিক্ষক',
#  'শিক্ষক বা',
#  'বা আপনার',
#  'আপনার কর্মক্ষেত্রের',
#  'কর্মক্ষেত্রের বস',
#  'বস থেকে',
#  'থেকে আপনার',
#  'আপনার দুটো',
#  'দুটো রেফারেন্স',
#  'রেফারেন্স লেটার',
#  'লেটার লাগবে',
#  'লাগবে ।',
#  '। এ',
#  'এ ক্ষেত্রে',
#  'ক্ষেত্রে যে',
#  'যে আপনাকে',
#  'আপনাকে রেফারেন্স',
#  'রেফারেন্স দিবে',
#  'দিবে অর্থাৎ',
#  'অর্থাৎ রেফারির',
#  'রেফারির যোগ্যতাও',
#  'যোগ্যতাও সেই',
#  'সেই লেভেলের',
#  'লেভেলের হতে',
#  'হতে হবে',
#  'হবে ।',
#  '। সে',
#  'সে আপনার',
#  'আপনার যোগ্যতা',
#  'যোগ্যতা দুর্বলতা',
#  'দুর্বলতা এবং',
#  'এবং পোটেনশিয়াল',
#  'পোটেনশিয়াল সম্পর্কে',
#  'সম্পর্কে জানবে',
#  'জানবে ।',
#  '। কাজেই',
#  'কাজেই রেফারি',
#  'রেফারি নির্বাচনের',
#  'নির্বাচনের ক্ষেত্রে',
#  'ক্ষেত্রে সতর্ক',
#  'সতর্ক হোন',
#  'হোন এবং',
#  'এবং আগে',
#  'আগে থেকেই',
#  'থেকেই সুসম্পর্ক',
#  'সুসম্পর্ক বজায়',
#  'বজায় রাখুন',
#  'রাখুন ।',
#  '। নিজের',
#  'নিজের যোগ্যতা',
#  'যোগ্যতা দিয়ে',
#  'দিয়ে সুসম্পর্ক',
#  'সুসম্পর্ক বজায়',
#  'বজায় রাখবেন',
#  'রাখবেন ।',
#  '। মাথায়',
#  'মাথায় রাখবেন',
#  'রাখবেন আপনাকে',
#  'আপনাকে কেউ',
#  'কেউ কিছু',
#  'কিছু মুখে',
#  'মুখে তুলে',
#  'তুলে খাওয়াবে',
#  'খাওয়াবে না',
#  'না ।',
#  '। কষ্ট',
#  'কষ্ট করতে',
#  'করতে হবে',
#  'হবে ।',
#  '। নিজের',
#  'নিজের সাথে',
#  'সাথে প্রতিযোগিতা',
#  'প্রতিযোগিতা করতে',
#  'করতে হবে',
#  'হবে ।',
#  '। জেলা',
#  'জেলা প্রশাসনের',
#  'প্রশাসনের একজন',
#  'একজন এক্সিকিউটিভ',
#  'এক্সিকিউটিভ ম্যাজিস্ট্রেটকে',
#  'ম্যাজিস্ট্রেটকে এই',
#  'এই দায়িত্ব',
#  'দায়িত্ব দেওয়া',
#  'দেওয়া হয়',
#  'হয় ।',
#  '। এনডিসির',
#  'এনডিসির কাজ',
#  'কাজ হলো',
#  'হলো মূলত',
#  'মূলত জেলা',
#  'জেলা প্রশাসন',
#  'প্রশাসন এবং',
#  'এবং জেলা',
#  'জেলা সংশ্লিষ্ট',
#  'সংশ্লিষ্ট সকল',
#  'সকল সরকারি',
#  'সরকারি বিষয়ে',
#  'বিষয়ে লজিস্টিকস',
#  'লজিস্টিকস সাপোর্ট',
#  'সাপোর্ট দেওয়া',
#  'দেওয়া ।',
#  '। যেমন',
#  'যেমন জেলায়',
#  'জেলায় কোনো',
#  'কোনো ভিআইপি',
#  'ভিআইপি আসলে',
#  'আসলে যথাযোগ্যভাবে',
#  'যথাযোগ্যভাবে তার',
#  'তার আবাসন',
#  'আবাসন ও',
#  'ও পরিবহন',
#  'পরিবহন নিশ্চিত',
#  'নিশ্চিত করা',
#  'করা ।',
#  '। তার',
#  'তার সফরসঙ্গীদের',
#  'সফরসঙ্গীদের আবাসন',
#  'আবাসন আহার',
#  'আহার ইত্যাদি',
#  'ইত্যাদি নিশ্চিত',
#  'নিশ্চিত করা',
#  'করা এবং',
#  'এবং জেলার',
#  'জেলার পরিবহন',
#  'পরিবহন পুলের',
#  'পুলের গাড়ি',
#  'গাড়ি সার্কিট',
#  'সার্কিট হাউজ',
#  'হাউজ ব্যবস্থাপনা',
#  'ব্যবস্থাপনা শ্রদ্ধেয়',
#  'শ্রদ্ধেয় ডিসি',
#  'ডিসি স্যারের',
#  'স্যারের বাংলোর',
#  'বাংলোর তদারকি',
#  'তদারকি অফিসের',
#  'অফিসের কার',
#  'কার কী',
#  'কী লাগবে',
#  'লাগবে এক',
#  'এক কথায়',
#  'কথায় সবকিছু',
#  'সবকিছু দেখভাল',
#  'দেখভাল করতে',
#  'করতে হয়',
#  'হয় এই',
#  'এই এনডিসির',
#  'এনডিসির ।',
#  '। এনডিসির',
#  'এনডিসির যেই',
#  'যেই অফিশিয়াল',
#  'অফিশিয়াল ফোন',
#  'ফোন আছে',
#  'আছে সেটা',
#  'সেটা কখনো',
#  'কখনো বন্ধ',
#  'বন্ধ হয়না',
#  'হয়না ।',
#  '। রোজ',
#  'রোজ কেয়ামতের',
#  'কেয়ামতের দিনেও',
#  'দিনেও যদি',
#  'যদি কেউ',
#  'কেউ ফোন',
#  'ফোন করে',
#  'করে বলে',
#  'বলে স্যার',
#  'স্যার গাড়ি',
#  'গাড়ি লাগবে',
#  'লাগবে ।',
#  '। থাকা',
#  'থাকা লাগবে',
#  'লাগবে নরসিংদীতে',
#  'নরসিংদীতে ।',
#  '। স্যার',
#  'স্যার এই',
#  'এই সমস্যা',
#  'সমস্যা হয়েছে',
#  'হয়েছে ।',
#  '। সেটাও',
#  'সেটাও এনডিসির',
#  'এনডিসির যেভাবেই',
#  'যেভাবেই হোক',
#  'হোক ম্যানেজ',
#  'ম্যানেজ করা',
#  'করা লাগবে',
#  'লাগবে ।',
#  '। এর',
#  'এর পাশাপাশি',
#  'পাশাপাশি দাপ্তরিক',
#  'দাপ্তরিক কাজ',
#  'কাজ এবং',
#  'এবং বিচারিক',
#  'বিচারিক কাজ',
#  'কাজ তো',
#  'তো আছেই',
#  'আছেই ।',
#  '। আমি',
#  'আমি তখনো',
#  'তখনো বুঝিনি',
#  'বুঝিনি কী',
#  'কী এক',
#  'এক কর্মযজ্ঞ',
#  'কর্মযজ্ঞ আমার',
#  'আমার জন্য',
#  'জন্য অপেক্ষা',
#  'অপেক্ষা করছিলো',
#  'করছিলো ।',
#  '। আমি',
#  'আমি মাননীয়',
#  'মাননীয় প্রধানমন্ত্রীর',
#  'প্রধানমন্ত্রীর কার্যালয়ের',
#  'কার্যালয়ের এটুআই',
#  'এটুআই থেকে',
#  'থেকে মেইল',
#  'মেইল ফোন',
#  'ফোন কল',
#  'কল পেতে',
#  'পেতে থাকলাম',
#  'থাকলাম ।',
#  '। সময়',
#  'সময় গড়ায়',
#  'গড়ায় আর',
#  'আর মেইল',
#  'মেইল ফোন',
#  'ফোন কলের',
#  'কলের গতি',
#  'গতি বাড়ে',
#  'বাড়ে ।',
#  '। তাদের',
#  'তাদের কাজ',
#  'কাজ ছিলো',
#  'ছিলো নরসিংদীর',
#  'নরসিংদীর পুরো',
#  'পুরো জেলার',
#  'জেলার সিক্যিউরিটি',
#  'সিক্যিউরিটি এনশিউর',
#  'এনশিউর করা',
#  'করা ।',
#  '। তাদের',
#  'তাদের আবাসন',
#  'আবাসন গাড়িসহ',
#  'গাড়িসহ সকল',
#  'সকল ধরণের',
#  'ধরণের রিকোয়ারমেন্টের',
#  'রিকোয়ারমেন্টের দায়িত্ব',
#  'দায়িত্ব যথারীতি',
#  'যথারীতি পড়লো',
#  'পড়লো আমার',
#  'আমার কাঁধে',
#  'কাঁধে ।',
#  '। নিরাপত্তা',
#  'নিরাপত্তা ইস্যু',
#  'ইস্যু হিসেবে',
#  'হিসেবে তারিখের',
#  'তারিখের প্রোগ্রামে',
#  'প্রোগ্রামে কারা',
#  'কারা কারা',
#  'কারা থাকবে',
#  'থাকবে তাদের',
#  'তাদের সিক্যিউরিটি',
#  'সিক্যিউরিটি ক্লিয়ারেন্সের',
#  'ক্লিয়ারেন্সের জন্য',
#  'জন্য ডিএসবি',
#  'ডিএসবি পাস',
#  'পাস করানো',
#  'করানো থেকে',
#  'থেকে শুরু',
#  'শুরু করে',
#  'করে সবকিছু',
#  'সবকিছু খেয়াল',
#  'খেয়াল রাখতে',
#  'রাখতে হলো',
#  'হলো ।',
#  '। তারিখ',
#  'তারিখ আসলো',
#  'আসলো সেনাবাহিনীর',
#  'সেনাবাহিনীর ডগ',
#  'ডগ ।',
#  '। স্কোয়াড',
#  'স্কোয়াড ।',
#  '। ফোন',
#  'ফোন দিয়ে',
#  'দিয়ে বললো',
#  'বললো স্যার',
#  'স্যার আমরা',
#  'আমরা মেম্বার',
#  'মেম্বার আর',
#  'আর ছয়টা',
#  'ছয়টা কুকুর',
#  'কুকুর থাকার',
#  'থাকার ব্যবস্থা',
#  'ব্যবস্থা করেন',
#  'করেন ।',
#  '। আমার',
#  'আমার তখন',
#  'তখন অলরেডি',
#  'অলরেডি সার্কিট',
#  'সার্কিট হাউজ',
#  'হাউজ ফুল',
#  'ফুল ।',
#  '। ম্যানেজ',
#  'ম্যানেজ করলাম',
#  'করলাম ।',
#  '। নেভির',
#  'নেভির ডাইভার',
#  'ডাইভার দল',
#  'দল ফোন',
#  'ফোন দিয়ে',
#  'দিয়ে বললো',
#  'বললো স্যার',
#  'স্যার আমরা',
#  'আমরা আসতেছি',
#  'আসতেছি ।',
#  '। থাকবো',
#  'থাকবো ম্যানেজ',
#  'ম্যানেজ করেন',
#  'করেন ।',
#  '। সেনাবাহিনীর',
#  'সেনাবাহিনীর সিক্যিউরিটি',
#  'সিক্যিউরিটি সুইপিং',
#  'সুইপিং টিম',
#  'টিম আসলো',
#  'আসলো একটা',
#  'একটা আবাসনের',
#  'আবাসনের ব্যবস্থা',
#  'ব্যবস্থা করলাম',
#  'করলাম তাদেরও',
#  'তাদেরও ।',
#  '। রাণী',
#  'রাণী আসার',
#  'আসার কথা',
#  'কথা সড়ক',
#  'সড়ক পথে',
#  'পথে কিন্তু',
#  'কিন্তু হেলিপ্যাড',
#  'হেলিপ্যাড রেডি',
#  'রেডি করতে',
#  'করতে হবে',
#  'হবে ।',
#  '। গণপূর্তের',
#  'গণপূর্তের নির্বাহী',
#  'নির্বাহী প্রকৌশলী',
#  'প্রকৌশলী মহোদয়কে',
#  'মহোদয়কে বললাম',
#  'বললাম স্টেডিয়ামে',
#  'স্টেডিয়ামে হেলিপ্যাড',
#  'হেলিপ্যাড বানান',
#  'বানান ।',
#  '। বানানো',
#  'বানানো হলো',
#  'হলো ।',
#  '। মোটরকেড',
#  'মোটরকেড এবং',
#  'এবং নিরাপত্তার',
#  'নিরাপত্তার দায়িত্বে',
#  'দায়িত্বে থাকা',
#  'থাকা অফিসারের',
#  'অফিসারের জন্য',
#  'জন্য প্রচুর',
#  'প্রচুর গাড়ি',
#  'গাড়ি লাগবে',
#  'লাগবে ।',
#  '। করলাম',
#  'করলাম ম্যানেজ',
#  'ম্যানেজ ।',
#  '। এর',
#  'এর মাঝে',
#  'মাঝে হঠাত',
#  'হঠাত বলা',
#  'বলা হলো',
#  'হলো রাণী',
#  'রাণী যদি',
#  'যদি লাঞ্চ',
#  'লাঞ্চ করতে',
#  'করতে চায়',
#  'চায় তাহলে',
#  'তাহলে মেন্যু',
#  'মেন্যু কী',
#  'কী হবে',
#  'হবে ।',
#  '। নেট',
#  'নেট ঘেঁটে',
#  'ঘেঁটে ডাচদের',
#  'ডাচদের খাবারের',
#  'খাবারের আইডিয়া',
#  'আইডিয়া নিলাম',
#  'নিলাম ।',
#  '। আমার',
#  'আমার বউকেও',
#  'বউকেও বললাম',
#  'বললাম হেল্প',
#  'হেল্প করতে',
#  'করতে ।',
#  '। যদিও',
#  'যদিও ওটা',
#  'ওটা পরে',
#  'পরে আর',
#  'আর প্রয়োজন',
#  'প্রয়োজন হয়নি',
#  'হয়নি ।',
#  '। রাণীর',
#  'রাণীর জন্য',
#  'জন্য মেডিকেল',
#  'মেডিকেল টিম',
#  'টিম ফায়ার',
#  'ফায়ার সার্ভিস',
#  'সার্ভিস ফুড',
#  'ফুড এক্সামিনার',
#  'এক্সামিনার সহ',
#  'সহ সকল',
#  'সকল কিছু',
#  'কিছু রেডি',
#  'রেডি রাখলাম',
#  'রাখলাম ।',
#  '। রাণীকে',
#  'রাণীকে আমাদের',
#  'আমাদের জেলা',
#  'জেলা প্রশাসক',
#  'প্রশাসক স্যার',
#  'স্যার নরসিংদী',
#  'নরসিংদী জেলার',
#  'জেলার একটা',
#  'একটা টোকেন',
#  'টোকেন গিফট',
#  'গিফট দিবে',
#  'দিবে ।',
#  '। সেটাও',
#  'সেটাও রেডি',
#  ...]

# %%
#sequences.shape

# %%
# save sequences to file
out_filename = r'C:\Users\OFR\Desktop\Thesis work\version four\updated_data_1_1.txt'
save_doc(sequences, out_filename)
