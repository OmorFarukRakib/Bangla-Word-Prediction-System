# %%
import string
import io
import codecs

# %%
# load doc into memory
def load_doc(filename):
    with io.open(filename, 'r', encoding='utf8') as f:
        text = f.read()
    return text

# %%
# turn a doc into clean tokens
def clean_doc(doc):
    # replace '--' with a space ' '
    doc = doc.replace('?', ' ? ')
    doc = doc.replace('।', ' । ')
    doc = doc.replace(',', ' । ')
    doc = doc.replace('-', ' । ')
    doc = doc.replace('(', ' । ')
    doc = doc.replace(')', ' । ')
    doc = doc.replace('{', ' । ')
    doc = doc.replace('}', ' । ')
    doc = doc.replace('[', ' । ')
    doc = doc.replace(']', ' । ')
    doc = doc.replace('*', ' ')
    doc = doc.replace('^', ' ')
    doc = doc.replace('#', ' ')
    doc = doc.replace('~', ' ')
    doc = doc.replace('`', ' ')
    doc = doc.replace('/', ' ')
    doc = doc.replace('_', ' ')
    doc = doc.replace('’', ' ')
    doc = doc.replace('‘', ' ')
    doc = doc.replace('.',' । ')
    
    
    # split into tokens by white space
    tokens = doc.split()
    # remove punctuation from each token
    #table = str.maketrans('', '', string.punctuation)
    #tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    #tokens = [word for word in tokens if word.isalpha()]
    # make lower case
    tokens = [word.lower() for word in tokens]
    return tokens

# %%
# save tokens to file, one dialog per line
def save_doc(lines, filename):
	data = '\n'.join(lines)
	file = open(filename, 'w', encoding='utf8')
	file.write(data)
	file.close()

# %%
# load document
in_filename = r'C:\Users\OFR\Desktop\Thesis work\version four\Main Dataset.txt'
doc = load_doc(in_filename)
print(doc[:200])
# Out:
# ﻿কর্পোরেশনের দোষ তো আছে । কিন্তু আমরা যে সুযোগ বুঝে হাজার হাজার কোটি টাকার ট্যাক্স ফাকি দিয়ে আসছি সেটাও আমরা জানি । এই ভয়ে সবাই স্যু করার সাহস পাবেনা । কারণ উলটা স্যু সে নিজে খেয়ে যাবে । আপনি স্যু করে

# %%
# clean document

tokens = clean_doc(doc)
#tokens = doc
print(tokens[:200])
print('Total Tokens: %d' % len(tokens))
print('Unique Tokens: %d' % len(set(tokens)))
# Out:
# ['\ufeffকর্পোরেশনের', 'দোষ', 'তো', 'আছে', '।', 'কিন্তু', 'আমরা', 'যে', 'সুযোগ', 'বুঝে', 'হাজার', 'হাজার', 'কোটি', 'টাকার', 'ট্যাক্স', 'ফাকি', 'দিয়ে', 'আসছি', 'সেটাও', 'আমরা', 'জানি', '।', 'এই', 'ভয়ে', 'সবাই', 'স্যু', 'করার', 'সাহস', 'পাবেনা', '।', 'কারণ', 'উলটা', 'স্যু', 'সে', 'নিজে', 'খেয়ে', 'যাবে', '।', 'আপনি', 'স্যু', 'করে', 'দৃষ্টান্ত', 'শুরু', 'করে', 'দিলেই', 'পারেন', '।', 'অন্যরাও', 'ধীরে', 'ধীরে', 'উৎসাহিত', 'হবে', '।', 'পরিবর্তন', 'আসবে', '।', 'আমাদের', 'সবার', 'মনেই', 'বিদেশে', 'পড়তে', 'যাওয়ার', 'সুপ্ত', 'কিন্তু', 'তীব্র', 'আকাঙ্ক্ষা', 'কাজ', 'করে', '।', 'বিদেশে', 'পড়ার', 'ক্ষেত্রে', 'খরচের', 'ব্যাপারটা', 'মাথায়', 'আসে', 'বলেই', 'আমরা', 'অনেকেই', 'চাই', 'বৃত্তি', 'বা', 'স্কলারশিপ', 'এর', 'ব্যাপারে', 'খোঁজ', 'নিতে', '।', 'পুরো', 'প্রক্রিয়াটি', 'অনেক', 'বিশদ', 'হওয়ায়', 'আমার', 'ক্ষুদ্র', 'অভিজ্ঞতা', 'থেকে', 'আমি', 'চেষ্টা', 'করবো', 'আমার', 'শিক্ষার্থীদের', 'কিছুটা', 'জানানোর', '।', 'আমার', 'লেখাটা', 'টি', 'পর্বে', 'থাকবে', '।', 'আজ', 'প্রথম', 'পর্ব', '।', 'আজকে', 'আমি', 'আলোচনা', 'করবো', 'বাংলাদেশি', 'শিক্ষার্থীদের', 'জন্য', 'বিদেশে', 'পড়তে', 'যাওয়ার', 'স্কলারশিপ', 'নিয়ে', '।', 'পরবর্তীতে', 'বিভিন্ন', 'দেশে', 'এপ্লাই', 'করার', 'প্রক্রিয়া', 'ক্রেডিট', 'ট্রান্সফার', 'বিশ্ববিদ্যালয়ের', 'ইন', 'হাউস', 'স্কলারশিপ', 'ইত্যাদি', 'বিষয়ে', 'আলোচনা', 'করবো', '।', 'যুক্তরাজ্যে', 'পড়তে', 'যাওয়ার', 'জন্য', 'ব্রিটিশ', 'সরকারের', 'বৃত্তি', 'এটি', '।', 'অত্যন্ত', 'সম্মানজনক', 'এবং', 'সেইসাথে', 'খুবই', 'প্রতিযোগিতামূলক', '।', 'সাধারণত', 'যারা', 'শিক্ষকতা', 'পেশায়', 'নিয়োজিত', 'থাকেন', 'তারা', 'এটা', 'পেয়ে', 'থাকেন', 'তবে', 'শিক্ষকই', 'হতে', 'হবে', 'এমন', 'কোনো', 'বাধ্যবাধকতা', 'নেই', '।', 'আপনার', 'বয়স', 'কম', 'হলে', 'এবং', 'আপনার', 'ব্যাচেলর', 'ডিগ্রিতে', 'নম্বর', 'থাকলেই', 'আপনি', 'এই', 'স্কলারশিপের', 'জন্য', 'এপ্লাই', 'করতে', 'পারবেন', '।', 'এক্ষেত্রে', 'যেটা']
# Total Tokens: 176559
# Unique Tokens: 22561

# %%
# organize into sequences of tokens
length = 4 + 1
sequences = list()
for i in range(length, len(tokens)):
	# select sequence of tokens
	seq = tokens[i-length:i]
	# convert into a line
	line = ' '.join(seq)
	# store
	sequences.append(line)
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 176554

# %%
sequences
# Out:
# ['\ufeffকর্পোরেশনের দোষ তো আছে ।',
#  'দোষ তো আছে । কিন্তু',
#  'তো আছে । কিন্তু আমরা',
#  'আছে । কিন্তু আমরা যে',
#  '। কিন্তু আমরা যে সুযোগ',
#  'কিন্তু আমরা যে সুযোগ বুঝে',
#  'আমরা যে সুযোগ বুঝে হাজার',
#  'যে সুযোগ বুঝে হাজার হাজার',
#  'সুযোগ বুঝে হাজার হাজার কোটি',
#  'বুঝে হাজার হাজার কোটি টাকার',
#  'হাজার হাজার কোটি টাকার ট্যাক্স',
#  'হাজার কোটি টাকার ট্যাক্স ফাকি',
#  'কোটি টাকার ট্যাক্স ফাকি দিয়ে',
#  'টাকার ট্যাক্স ফাকি দিয়ে আসছি',
#  'ট্যাক্স ফাকি দিয়ে আসছি সেটাও',
#  'ফাকি দিয়ে আসছি সেটাও আমরা',
#  'দিয়ে আসছি সেটাও আমরা জানি',
#  'আসছি সেটাও আমরা জানি ।',
#  'সেটাও আমরা জানি । এই',
#  'আমরা জানি । এই ভয়ে',
#  'জানি । এই ভয়ে সবাই',
#  '। এই ভয়ে সবাই স্যু',
#  'এই ভয়ে সবাই স্যু করার',
#  'ভয়ে সবাই স্যু করার সাহস',
#  'সবাই স্যু করার সাহস পাবেনা',
#  'স্যু করার সাহস পাবেনা ।',
#  'করার সাহস পাবেনা । কারণ',
#  'সাহস পাবেনা । কারণ উলটা',
#  'পাবেনা । কারণ উলটা স্যু',
#  '। কারণ উলটা স্যু সে',
#  'কারণ উলটা স্যু সে নিজে',
#  'উলটা স্যু সে নিজে খেয়ে',
#  'স্যু সে নিজে খেয়ে যাবে',
#  'সে নিজে খেয়ে যাবে ।',
#  'নিজে খেয়ে যাবে । আপনি',
#  'খেয়ে যাবে । আপনি স্যু',
#  'যাবে । আপনি স্যু করে',
#  '। আপনি স্যু করে দৃষ্টান্ত',
#  'আপনি স্যু করে দৃষ্টান্ত শুরু',
#  'স্যু করে দৃষ্টান্ত শুরু করে',
#  'করে দৃষ্টান্ত শুরু করে দিলেই',
#  'দৃষ্টান্ত শুরু করে দিলেই পারেন',
#  'শুরু করে দিলেই পারেন ।',
#  'করে দিলেই পারেন । অন্যরাও',
#  'দিলেই পারেন । অন্যরাও ধীরে',
#  'পারেন । অন্যরাও ধীরে ধীরে',
#  '। অন্যরাও ধীরে ধীরে উৎসাহিত',
#  'অন্যরাও ধীরে ধীরে উৎসাহিত হবে',
#  'ধীরে ধীরে উৎসাহিত হবে ।',
#  'ধীরে উৎসাহিত হবে । পরিবর্তন',
#  'উৎসাহিত হবে । পরিবর্তন আসবে',
#  'হবে । পরিবর্তন আসবে ।',
#  '। পরিবর্তন আসবে । আমাদের',
#  'পরিবর্তন আসবে । আমাদের সবার',
#  'আসবে । আমাদের সবার মনেই',
#  '। আমাদের সবার মনেই বিদেশে',
#  'আমাদের সবার মনেই বিদেশে পড়তে',
#  'সবার মনেই বিদেশে পড়তে যাওয়ার',
#  'মনেই বিদেশে পড়তে যাওয়ার সুপ্ত',
#  'বিদেশে পড়তে যাওয়ার সুপ্ত কিন্তু',
#  'পড়তে যাওয়ার সুপ্ত কিন্তু তীব্র',
#  'যাওয়ার সুপ্ত কিন্তু তীব্র আকাঙ্ক্ষা',
#  'সুপ্ত কিন্তু তীব্র আকাঙ্ক্ষা কাজ',
#  'কিন্তু তীব্র আকাঙ্ক্ষা কাজ করে',
#  'তীব্র আকাঙ্ক্ষা কাজ করে ।',
#  'আকাঙ্ক্ষা কাজ করে । বিদেশে',
#  'কাজ করে । বিদেশে পড়ার',
#  'করে । বিদেশে পড়ার ক্ষেত্রে',
#  '। বিদেশে পড়ার ক্ষেত্রে খরচের',
#  'বিদেশে পড়ার ক্ষেত্রে খরচের ব্যাপারটা',
#  'পড়ার ক্ষেত্রে খরচের ব্যাপারটা মাথায়',
#  'ক্ষেত্রে খরচের ব্যাপারটা মাথায় আসে',
#  'খরচের ব্যাপারটা মাথায় আসে বলেই',
#  'ব্যাপারটা মাথায় আসে বলেই আমরা',
#  'মাথায় আসে বলেই আমরা অনেকেই',
#  'আসে বলেই আমরা অনেকেই চাই',
#  'বলেই আমরা অনেকেই চাই বৃত্তি',
#  'আমরা অনেকেই চাই বৃত্তি বা',
#  'অনেকেই চাই বৃত্তি বা স্কলারশিপ',
#  'চাই বৃত্তি বা স্কলারশিপ এর',
#  'বৃত্তি বা স্কলারশিপ এর ব্যাপারে',
#  'বা স্কলারশিপ এর ব্যাপারে খোঁজ',
#  'স্কলারশিপ এর ব্যাপারে খোঁজ নিতে',
#  'এর ব্যাপারে খোঁজ নিতে ।',
#  'ব্যাপারে খোঁজ নিতে । পুরো',
#  'খোঁজ নিতে । পুরো প্রক্রিয়াটি',
#  'নিতে । পুরো প্রক্রিয়াটি অনেক',
#  '। পুরো প্রক্রিয়াটি অনেক বিশদ',
#  'পুরো প্রক্রিয়াটি অনেক বিশদ হওয়ায়',
#  'প্রক্রিয়াটি অনেক বিশদ হওয়ায় আমার',
#  'অনেক বিশদ হওয়ায় আমার ক্ষুদ্র',
#  'বিশদ হওয়ায় আমার ক্ষুদ্র অভিজ্ঞতা',
#  'হওয়ায় আমার ক্ষুদ্র অভিজ্ঞতা থেকে',
#  'আমার ক্ষুদ্র অভিজ্ঞতা থেকে আমি',
#  'ক্ষুদ্র অভিজ্ঞতা থেকে আমি চেষ্টা',
#  'অভিজ্ঞতা থেকে আমি চেষ্টা করবো',
#  'থেকে আমি চেষ্টা করবো আমার',
#  'আমি চেষ্টা করবো আমার শিক্ষার্থীদের',
#  'চেষ্টা করবো আমার শিক্ষার্থীদের কিছুটা',
#  'করবো আমার শিক্ষার্থীদের কিছুটা জানানোর',
#  'আমার শিক্ষার্থীদের কিছুটা জানানোর ।',
#  'শিক্ষার্থীদের কিছুটা জানানোর । আমার',
#  'কিছুটা জানানোর । আমার লেখাটা',
#  'জানানোর । আমার লেখাটা টি',
#  '। আমার লেখাটা টি পর্বে',
#  'আমার লেখাটা টি পর্বে থাকবে',
#  'লেখাটা টি পর্বে থাকবে ।',
#  'টি পর্বে থাকবে । আজ',
#  'পর্বে থাকবে । আজ প্রথম',
#  'থাকবে । আজ প্রথম পর্ব',
#  '। আজ প্রথম পর্ব ।',
#  'আজ প্রথম পর্ব । আজকে',
#  'প্রথম পর্ব । আজকে আমি',
#  'পর্ব । আজকে আমি আলোচনা',
#  '। আজকে আমি আলোচনা করবো',
#  'আজকে আমি আলোচনা করবো বাংলাদেশি',
#  'আমি আলোচনা করবো বাংলাদেশি শিক্ষার্থীদের',
#  'আলোচনা করবো বাংলাদেশি শিক্ষার্থীদের জন্য',
#  'করবো বাংলাদেশি শিক্ষার্থীদের জন্য বিদেশে',
#  'বাংলাদেশি শিক্ষার্থীদের জন্য বিদেশে পড়তে',
#  'শিক্ষার্থীদের জন্য বিদেশে পড়তে যাওয়ার',
#  'জন্য বিদেশে পড়তে যাওয়ার স্কলারশিপ',
#  'বিদেশে পড়তে যাওয়ার স্কলারশিপ নিয়ে',
#  'পড়তে যাওয়ার স্কলারশিপ নিয়ে ।',
#  'যাওয়ার স্কলারশিপ নিয়ে । পরবর্তীতে',
#  'স্কলারশিপ নিয়ে । পরবর্তীতে বিভিন্ন',
#  'নিয়ে । পরবর্তীতে বিভিন্ন দেশে',
#  '। পরবর্তীতে বিভিন্ন দেশে এপ্লাই',
#  'পরবর্তীতে বিভিন্ন দেশে এপ্লাই করার',
#  'বিভিন্ন দেশে এপ্লাই করার প্রক্রিয়া',
#  'দেশে এপ্লাই করার প্রক্রিয়া ক্রেডিট',
#  'এপ্লাই করার প্রক্রিয়া ক্রেডিট ট্রান্সফার',
#  'করার প্রক্রিয়া ক্রেডিট ট্রান্সফার বিশ্ববিদ্যালয়ের',
#  'প্রক্রিয়া ক্রেডিট ট্রান্সফার বিশ্ববিদ্যালয়ের ইন',
#  'ক্রেডিট ট্রান্সফার বিশ্ববিদ্যালয়ের ইন হাউস',
#  'ট্রান্সফার বিশ্ববিদ্যালয়ের ইন হাউস স্কলারশিপ',
#  'বিশ্ববিদ্যালয়ের ইন হাউস স্কলারশিপ ইত্যাদি',
#  'ইন হাউস স্কলারশিপ ইত্যাদি বিষয়ে',
#  'হাউস স্কলারশিপ ইত্যাদি বিষয়ে আলোচনা',
#  'স্কলারশিপ ইত্যাদি বিষয়ে আলোচনা করবো',
#  'ইত্যাদি বিষয়ে আলোচনা করবো ।',
#  'বিষয়ে আলোচনা করবো । যুক্তরাজ্যে',
#  'আলোচনা করবো । যুক্তরাজ্যে পড়তে',
#  'করবো । যুক্তরাজ্যে পড়তে যাওয়ার',
#  '। যুক্তরাজ্যে পড়তে যাওয়ার জন্য',
#  'যুক্তরাজ্যে পড়তে যাওয়ার জন্য ব্রিটিশ',
#  'পড়তে যাওয়ার জন্য ব্রিটিশ সরকারের',
#  'যাওয়ার জন্য ব্রিটিশ সরকারের বৃত্তি',
#  'জন্য ব্রিটিশ সরকারের বৃত্তি এটি',
#  'ব্রিটিশ সরকারের বৃত্তি এটি ।',
#  'সরকারের বৃত্তি এটি । অত্যন্ত',
#  'বৃত্তি এটি । অত্যন্ত সম্মানজনক',
#  'এটি । অত্যন্ত সম্মানজনক এবং',
#  '। অত্যন্ত সম্মানজনক এবং সেইসাথে',
#  'অত্যন্ত সম্মানজনক এবং সেইসাথে খুবই',
#  'সম্মানজনক এবং সেইসাথে খুবই প্রতিযোগিতামূলক',
#  'এবং সেইসাথে খুবই প্রতিযোগিতামূলক ।',
#  'সেইসাথে খুবই প্রতিযোগিতামূলক । সাধারণত',
#  'খুবই প্রতিযোগিতামূলক । সাধারণত যারা',
#  'প্রতিযোগিতামূলক । সাধারণত যারা শিক্ষকতা',
#  '। সাধারণত যারা শিক্ষকতা পেশায়',
#  'সাধারণত যারা শিক্ষকতা পেশায় নিয়োজিত',
#  'যারা শিক্ষকতা পেশায় নিয়োজিত থাকেন',
#  'শিক্ষকতা পেশায় নিয়োজিত থাকেন তারা',
#  'পেশায় নিয়োজিত থাকেন তারা এটা',
#  'নিয়োজিত থাকেন তারা এটা পেয়ে',
#  'থাকেন তারা এটা পেয়ে থাকেন',
#  'তারা এটা পেয়ে থাকেন তবে',
#  'এটা পেয়ে থাকেন তবে শিক্ষকই',
#  'পেয়ে থাকেন তবে শিক্ষকই হতে',
#  'থাকেন তবে শিক্ষকই হতে হবে',
#  'তবে শিক্ষকই হতে হবে এমন',
#  'শিক্ষকই হতে হবে এমন কোনো',
#  'হতে হবে এমন কোনো বাধ্যবাধকতা',
#  'হবে এমন কোনো বাধ্যবাধকতা নেই',
#  'এমন কোনো বাধ্যবাধকতা নেই ।',
#  'কোনো বাধ্যবাধকতা নেই । আপনার',
#  'বাধ্যবাধকতা নেই । আপনার বয়স',
#  'নেই । আপনার বয়স কম',
#  '। আপনার বয়স কম হলে',
#  'আপনার বয়স কম হলে এবং',
#  'বয়স কম হলে এবং আপনার',
#  'কম হলে এবং আপনার ব্যাচেলর',
#  'হলে এবং আপনার ব্যাচেলর ডিগ্রিতে',
#  'এবং আপনার ব্যাচেলর ডিগ্রিতে নম্বর',
#  'আপনার ব্যাচেলর ডিগ্রিতে নম্বর থাকলেই',
#  'ব্যাচেলর ডিগ্রিতে নম্বর থাকলেই আপনি',
#  'ডিগ্রিতে নম্বর থাকলেই আপনি এই',
#  'নম্বর থাকলেই আপনি এই স্কলারশিপের',
#  'থাকলেই আপনি এই স্কলারশিপের জন্য',
#  'আপনি এই স্কলারশিপের জন্য এপ্লাই',
#  'এই স্কলারশিপের জন্য এপ্লাই করতে',
#  'স্কলারশিপের জন্য এপ্লাই করতে পারবেন',
#  'জন্য এপ্লাই করতে পারবেন ।',
#  'এপ্লাই করতে পারবেন । এক্ষেত্রে',
#  'করতে পারবেন । এক্ষেত্রে যেটা',
#  'পারবেন । এক্ষেত্রে যেটা লাগবে',
#  '। এক্ষেত্রে যেটা লাগবে সেটা',
#  'এক্ষেত্রে যেটা লাগবে সেটা হলো',
#  'যেটা লাগবে সেটা হলো যুক্তরাজ্যের',
#  'লাগবে সেটা হলো যুক্তরাজ্যের কোনো',
#  'সেটা হলো যুক্তরাজ্যের কোনো একটি',
#  'হলো যুক্তরাজ্যের কোনো একটি বিশ্ববিদ্যালয়ে',
#  'যুক্তরাজ্যের কোনো একটি বিশ্ববিদ্যালয়ে ভর্তির',
#  'কোনো একটি বিশ্ববিদ্যালয়ে ভর্তির আনকন্ডিশনাল',
#  'একটি বিশ্ববিদ্যালয়ে ভর্তির আনকন্ডিশনাল অফার',
#  'বিশ্ববিদ্যালয়ে ভর্তির আনকন্ডিশনাল অফার লেটার',
#  'ভর্তির আনকন্ডিশনাল অফার লেটার ।',
#  'আনকন্ডিশনাল অফার লেটার । গুগল',
#  'অফার লেটার । গুগল করলেই',
#  'লেটার । গুগল করলেই লিস্ট',
#  '। গুগল করলেই লিস্ট পাবেন',
#  'গুগল করলেই লিস্ট পাবেন ব্রিটেনের',
#  'করলেই লিস্ট পাবেন ব্রিটেনের কোন',
#  'লিস্ট পাবেন ব্রিটেনের কোন কোন',
#  'পাবেন ব্রিটেনের কোন কোন বিশ্ববিদ্যালয়',
#  'ব্রিটেনের কোন কোন বিশ্ববিদ্যালয় কমনওয়েলথের',
#  'কোন কোন বিশ্ববিদ্যালয় কমনওয়েলথের আওতায়',
#  'কোন বিশ্ববিদ্যালয় কমনওয়েলথের আওতায় আছে',
#  'বিশ্ববিদ্যালয় কমনওয়েলথের আওতায় আছে ।',
#  'কমনওয়েলথের আওতায় আছে । তারমানে',
#  'আওতায় আছে । তারমানে আপনার',
#  'আছে । তারমানে আপনার আগে',
#  '। তারমানে আপনার আগে বিশ্ববিদ্যালয়ে',
#  'তারমানে আপনার আগে বিশ্ববিদ্যালয়ে ওদের',
#  'আপনার আগে বিশ্ববিদ্যালয়ে ওদের নিজস্ব',
#  'আগে বিশ্ববিদ্যালয়ে ওদের নিজস্ব সিস্টেমে',
#  'বিশ্ববিদ্যালয়ে ওদের নিজস্ব সিস্টেমে এপ্লাই',
#  'ওদের নিজস্ব সিস্টেমে এপ্লাই করতে',
#  'নিজস্ব সিস্টেমে এপ্লাই করতে হবে',
#  'সিস্টেমে এপ্লাই করতে হবে আর',
#  'এপ্লাই করতে হবে আর অফার',
#  'করতে হবে আর অফার লেটার',
#  'হবে আর অফার লেটার পেলেই',
#  'আর অফার লেটার পেলেই আপনি',
#  'অফার লেটার পেলেই আপনি কমনওয়েলথের',
#  'লেটার পেলেই আপনি কমনওয়েলথের জন্য',
#  'পেলেই আপনি কমনওয়েলথের জন্য এপ্লাই',
#  'আপনি কমনওয়েলথের জন্য এপ্লাই করতে',
#  'কমনওয়েলথের জন্য এপ্লাই করতে পারবেন',
#  'জন্য এপ্লাই করতে পারবেন ।',
#  'এপ্লাই করতে পারবেন । দুটোর',
#  'করতে পারবেন । দুটোর ক্ষেত্রেই',
#  'পারবেন । দুটোর ক্ষেত্রেই এপ্লিকেশন',
#  '। দুটোর ক্ষেত্রেই এপ্লিকেশন প্রোসেস',
#  'দুটোর ক্ষেত্রেই এপ্লিকেশন প্রোসেস ভিন্ন',
#  'ক্ষেত্রেই এপ্লিকেশন প্রোসেস ভিন্ন ।',
#  'এপ্লিকেশন প্রোসেস ভিন্ন । এছাড়া',
#  'প্রোসেস ভিন্ন । এছাড়া স্কলারশিপের',
#  'ভিন্ন । এছাড়া স্কলারশিপের ক্ষেত্রেও',
#  '। এছাড়া স্কলারশিপের ক্ষেত্রেও আইল্টসের',
#  'এছাড়া স্কলারশিপের ক্ষেত্রেও আইল্টসের স্কোর',
#  'স্কলারশিপের ক্ষেত্রেও আইল্টসের স্কোর আপনার',
#  'ক্ষেত্রেও আইল্টসের স্কোর আপনার জন্য',
#  'আইল্টসের স্কোর আপনার জন্য একটা',
#  'স্কোর আপনার জন্য একটা ফ্যাক্টর',
#  'আপনার জন্য একটা ফ্যাক্টর হবে',
#  'জন্য একটা ফ্যাক্টর হবে ।',
#  'একটা ফ্যাক্টর হবে । কমনওয়েলথ',
#  'ফ্যাক্টর হবে । কমনওয়েলথ সাধারণত',
#  'হবে । কমনওয়েলথ সাধারণত ওপেন',
#  '। কমনওয়েলথ সাধারণত ওপেন হয়',
#  'কমনওয়েলথ সাধারণত ওপেন হয় নভেম্বরের',
#  'সাধারণত ওপেন হয় নভেম্বরের দিকে',
#  'ওপেন হয় নভেম্বরের দিকে ।',
#  'হয় নভেম্বরের দিকে । সময়',
#  'নভেম্বরের দিকে । সময় থাকে',
#  'দিকে । সময় থাকে ২',
#  '। সময় থাকে ২ মাসের',
#  'সময় থাকে ২ মাসের মতো',
#  'থাকে ২ মাসের মতো ।',
#  '২ মাসের মতো । এটাও',
#  'মাসের মতো । এটাও কমনওয়েলথের',
#  'মতো । এটাও কমনওয়েলথের মতই',
#  '। এটাও কমনওয়েলথের মতই কিন্তু',
#  'এটাও কমনওয়েলথের মতই কিন্তু এটার',
#  'কমনওয়েলথের মতই কিন্তু এটার ফাণ্ডিং',
#  'মতই কিন্তু এটার ফাণ্ডিং অর্ধেক',
#  'কিন্তু এটার ফাণ্ডিং অর্ধেক যেই',
#  'এটার ফাণ্ডিং অর্ধেক যেই বিশ্ববিদ্যালয়',
#  'ফাণ্ডিং অর্ধেক যেই বিশ্ববিদ্যালয় এফিলিয়েটেড',
#  'অর্ধেক যেই বিশ্ববিদ্যালয় এফিলিয়েটেড সেটা',
#  'যেই বিশ্ববিদ্যালয় এফিলিয়েটেড সেটা দিবে',
#  'বিশ্ববিদ্যালয় এফিলিয়েটেড সেটা দিবে আর',
#  'এফিলিয়েটেড সেটা দিবে আর বাকি',
#  'সেটা দিবে আর বাকি অর্ধেক',
#  'দিবে আর বাকি অর্ধেক দিবে',
#  'আর বাকি অর্ধেক দিবে কমনওয়েলথ',
#  'বাকি অর্ধেক দিবে কমনওয়েলথ স্কলারশিপ',
#  'অর্ধেক দিবে কমনওয়েলথ স্কলারশিপ কমিটি',
#  'দিবে কমনওয়েলথ স্কলারশিপ কমিটি ।',
#  'কমনওয়েলথ স্কলারশিপ কমিটি । বাকিসব',
#  'স্কলারশিপ কমিটি । বাকিসব ক্রাইটেরিয়া',
#  'কমিটি । বাকিসব ক্রাইটেরিয়া একই',
#  '। বাকিসব ক্রাইটেরিয়া একই ।',
#  'বাকিসব ক্রাইটেরিয়া একই । তবে',
#  'ক্রাইটেরিয়া একই । তবে বিশ্ববিদ্যালয়ের',
#  'একই । তবে বিশ্ববিদ্যালয়ের একটা',
#  '। তবে বিশ্ববিদ্যালয়ের একটা তালিকা',
#  'তবে বিশ্ববিদ্যালয়ের একটা তালিকা থাকে',
#  'বিশ্ববিদ্যালয়ের একটা তালিকা থাকে যে',
#  'একটা তালিকা থাকে যে কোন',
#  'তালিকা থাকে যে কোন কোন',
#  'থাকে যে কোন কোন বিশ্ববিদ্যালয়',
#  'যে কোন কোন বিশ্ববিদ্যালয় এই',
#  'কোন কোন বিশ্ববিদ্যালয় এই শেয়ারড',
#  'কোন বিশ্ববিদ্যালয় এই শেয়ারড প্রোগ্রামের',
#  'বিশ্ববিদ্যালয় এই শেয়ারড প্রোগ্রামের আওতায়',
#  'এই শেয়ারড প্রোগ্রামের আওতায় ।',
#  'শেয়ারড প্রোগ্রামের আওতায় । যুক্তরাজ্যে',
#  'প্রোগ্রামের আওতায় । যুক্তরাজ্যে পড়তে',
#  'আওতায় । যুক্তরাজ্যে পড়তে যাওয়ার',
#  '। যুক্তরাজ্যে পড়তে যাওয়ার জন্য',
#  'যুক্তরাজ্যে পড়তে যাওয়ার জন্য ব্রিটিশ',
#  'পড়তে যাওয়ার জন্য ব্রিটিশ সরকারের',
#  'যাওয়ার জন্য ব্রিটিশ সরকারের বৃত্তি',
#  'জন্য ব্রিটিশ সরকারের বৃত্তি ।',
#  'ব্রিটিশ সরকারের বৃত্তি । সাধারণত',
#  'সরকারের বৃত্তি । সাধারণত এনজিও',
#  'বৃত্তি । সাধারণত এনজিও কর্মী',
#  '। সাধারণত এনজিও কর্মী সরকারী',
#  'সাধারণত এনজিও কর্মী সরকারী চাকুরে',
#  'এনজিও কর্মী সরকারী চাকুরে বাংলাদেশ',
#  'কর্মী সরকারী চাকুরে বাংলাদেশ ব্যাংকের',
#  'সরকারী চাকুরে বাংলাদেশ ব্যাংকের কর্মকর্তা',
#  'চাকুরে বাংলাদেশ ব্যাংকের কর্মকর্তা উদ্যোক্তা',
#  'বাংলাদেশ ব্যাংকের কর্মকর্তা উদ্যোক্তা এদের',
#  'ব্যাংকের কর্মকর্তা উদ্যোক্তা এদের জন্য',
#  'কর্মকর্তা উদ্যোক্তা এদের জন্য এই',
#  'উদ্যোক্তা এদের জন্য এই বৃত্তি',
#  'এদের জন্য এই বৃত্তি ।',
#  'জন্য এই বৃত্তি । আপনার',
#  'এই বৃত্তি । আপনার চাকরি',
#  'বৃত্তি । আপনার চাকরি যদি',
#  '। আপনার চাকরি যদি দুই',
#  'আপনার চাকরি যদি দুই বছর',
#  'চাকরি যদি দুই বছর হয়',
#  'যদি দুই বছর হয় তাহলে',
#  'দুই বছর হয় তাহলে এটার',
#  'বছর হয় তাহলে এটার জন্য',
#  'হয় তাহলে এটার জন্য এপ্লাই',
#  'তাহলে এটার জন্য এপ্লাই করতে',
#  'এটার জন্য এপ্লাই করতে পারবেন',
#  'জন্য এপ্লাই করতে পারবেন ।',
#  'এপ্লাই করতে পারবেন । ক্রাইটেরিয়া',
#  'করতে পারবেন । ক্রাইটেরিয়া একই',
#  'পারবেন । ক্রাইটেরিয়া একই রকম',
#  '। ক্রাইটেরিয়া একই রকম ।',
#  'ক্রাইটেরিয়া একই রকম । আইল্টসে',
#  'একই রকম । আইল্টসে ভালো',
#  'রকম । আইল্টসে ভালো স্কোর',
#  '। আইল্টসে ভালো স্কোর আর',
#  'আইল্টসে ভালো স্কোর আর ইউকের',
#  'ভালো স্কোর আর ইউকের বিশ্ববিদ্যালয়',
#  'স্কোর আর ইউকের বিশ্ববিদ্যালয় থেকে',
#  'আর ইউকের বিশ্ববিদ্যালয় থেকে আনকন্ডিশনাল',
#  'ইউকের বিশ্ববিদ্যালয় থেকে আনকন্ডিশনাল অফার',
#  'বিশ্ববিদ্যালয় থেকে আনকন্ডিশনাল অফার লেটার',
#  'থেকে আনকন্ডিশনাল অফার লেটার লাগবে',
#  'আনকন্ডিশনাল অফার লেটার লাগবে ।',
#  'অফার লেটার লাগবে । মার্কিন',
#  'লেটার লাগবে । মার্কিন সরকারের',
#  'লাগবে । মার্কিন সরকারের বৃত্তি',
#  '। মার্কিন সরকারের বৃত্তি ।',
#  'মার্কিন সরকারের বৃত্তি । দারুণ',
#  'সরকারের বৃত্তি । দারুণ প্রেস্টিজিয়াস',
#  'বৃত্তি । দারুণ প্রেস্টিজিয়াস এবং',
#  '। দারুণ প্রেস্টিজিয়াস এবং আর্থিক',
#  'দারুণ প্রেস্টিজিয়াস এবং আর্থিক দিক',
#  'প্রেস্টিজিয়াস এবং আর্থিক দিক থেকেও',
#  'এবং আর্থিক দিক থেকেও বেশ',
#  'আর্থিক দিক থেকেও বেশ লাভজনক',
#  'দিক থেকেও বেশ লাভজনক ।',
#  'থেকেও বেশ লাভজনক । মূল',
#  'বেশ লাভজনক । মূল বৃত্তিটির',
#  'লাভজনক । মূল বৃত্তিটির নাম',
#  '। মূল বৃত্তিটির নাম হলো',
#  'মূল বৃত্তিটির নাম হলো ফুলব্রাইট',
#  'বৃত্তিটির নাম হলো ফুলব্রাইট ফরেন',
#  'নাম হলো ফুলব্রাইট ফরেন স্টুডেন্ট',
#  'হলো ফুলব্রাইট ফরেন স্টুডেন্ট প্রোগ্রাম',
#  'ফুলব্রাইট ফরেন স্টুডেন্ট প্রোগ্রাম ।',
#  'ফরেন স্টুডেন্ট প্রোগ্রাম । এটার',
#  'স্টুডেন্ট প্রোগ্রাম । এটার ক্ষেত্রে',
#  'প্রোগ্রাম । এটার ক্ষেত্রে আলাদাভাবে',
#  '। এটার ক্ষেত্রে আলাদাভাবে কোনো',
#  'এটার ক্ষেত্রে আলাদাভাবে কোনো বিশ্ববিদ্যালয়ে',
#  'ক্ষেত্রে আলাদাভাবে কোনো বিশ্ববিদ্যালয়ে এপ্লাই',
#  'আলাদাভাবে কোনো বিশ্ববিদ্যালয়ে এপ্লাই করতে',
#  'কোনো বিশ্ববিদ্যালয়ে এপ্লাই করতে হবেনা',
#  'বিশ্ববিদ্যালয়ে এপ্লাই করতে হবেনা ।',
#  'এপ্লাই করতে হবেনা । ফুলব্রাইটে',
#  'করতে হবেনা । ফুলব্রাইটে এপ্লাই',
#  'হবেনা । ফুলব্রাইটে এপ্লাই করলেই',
#  '। ফুলব্রাইটে এপ্লাই করলেই হবে',
#  'ফুলব্রাইটে এপ্লাই করলেই হবে ।',
#  'এপ্লাই করলেই হবে । যদি',
#  'করলেই হবে । যদি আপনি',
#  'হবে । যদি আপনি বৃত্তির',
#  '। যদি আপনি বৃত্তির জন্য',
#  'যদি আপনি বৃত্তির জন্য মনোনীত',
#  'আপনি বৃত্তির জন্য মনোনীত হোন',
#  'বৃত্তির জন্য মনোনীত হোন তাহলে',
#  'জন্য মনোনীত হোন তাহলে তারাই',
#  'মনোনীত হোন তাহলে তারাই আপনাকে',
#  'হোন তাহলে তারাই আপনাকে বিশ্ববিদ্যালয়',
#  'তাহলে তারাই আপনাকে বিশ্ববিদ্যালয় নির্ধারণ',
#  'তারাই আপনাকে বিশ্ববিদ্যালয় নির্ধারণ করে',
#  'আপনাকে বিশ্ববিদ্যালয় নির্ধারণ করে দিবে',
#  'বিশ্ববিদ্যালয় নির্ধারণ করে দিবে ।',
#  'নির্ধারণ করে দিবে । ইয়োরোপ',
#  'করে দিবে । ইয়োরোপ ঘুরে',
#  'দিবে । ইয়োরোপ ঘুরে বেড়ানোর',
#  '। ইয়োরোপ ঘুরে বেড়ানোর জন্য',
#  'ইয়োরোপ ঘুরে বেড়ানোর জন্য এর',
#  'ঘুরে বেড়ানোর জন্য এর চাইতে',
#  'বেড়ানোর জন্য এর চাইতে ভালো',
#  'জন্য এর চাইতে ভালো স্কলারশিপ',
#  'এর চাইতে ভালো স্কলারশিপ আর',
#  'চাইতে ভালো স্কলারশিপ আর হয়না',
#  'ভালো স্কলারশিপ আর হয়না ।',
#  'স্কলারশিপ আর হয়না । বিশেষ',
#  'আর হয়না । বিশেষ করে',
#  'হয়না । বিশেষ করে সায়েন্স',
#  '। বিশেষ করে সায়েন্স এন্ড',
#  'বিশেষ করে সায়েন্স এন্ড টেকনোলজিতে',
#  'করে সায়েন্স এন্ড টেকনোলজিতে যারা',
#  'সায়েন্স এন্ড টেকনোলজিতে যারা পড়ছেন',
#  'এন্ড টেকনোলজিতে যারা পড়ছেন তাদের',
#  'টেকনোলজিতে যারা পড়ছেন তাদের জন্য',
#  'যারা পড়ছেন তাদের জন্য এটা',
#  'পড়ছেন তাদের জন্য এটা বেশ',
#  'তাদের জন্য এটা বেশ লিউক্রেটিভ',
#  'জন্য এটা বেশ লিউক্রেটিভ ।',
#  'এটা বেশ লিউক্রেটিভ । সিজিপিএ',
#  'বেশ লিউক্রেটিভ । সিজিপিএ ভালো',
#  'লিউক্রেটিভ । সিজিপিএ ভালো থাকা',
#  '। সিজিপিএ ভালো থাকা লাগবে',
#  'সিজিপিএ ভালো থাকা লাগবে ।',
#  'ভালো থাকা লাগবে । এই',
#  'থাকা লাগবে । এই স্কলারশিপের',
#  'লাগবে । এই স্কলারশিপের মজা',
#  '। এই স্কলারশিপের মজা হলো',
#  'এই স্কলারশিপের মজা হলো ওরা',
#  'স্কলারশিপের মজা হলো ওরা আ',
#  'মজা হলো ওরা আ পনাকে',
#  'হলো ওরা আ পনাকে ইয়োরোপের',
#  'ওরা আ পনাকে ইয়োরোপের দুটো',
#  'আ পনাকে ইয়োরোপের দুটো দেশের',
#  'পনাকে ইয়োরোপের দুটো দেশের দুই',
#  'ইয়োরোপের দুটো দেশের দুই বিশ্ববিদ্যালয়ে',
#  'দুটো দেশের দুই বিশ্ববিদ্যালয়ে যৌথভাবে',
#  'দেশের দুই বিশ্ববিদ্যালয়ে যৌথভাবে দুই',
#  'দুই বিশ্ববিদ্যালয়ে যৌথভাবে দুই বছরের',
#  'বিশ্ববিদ্যালয়ে যৌথভাবে দুই বছরের মাস্টার্স',
#  'যৌথভাবে দুই বছরের মাস্টার্স ডিগ্রি',
#  'দুই বছরের মাস্টার্স ডিগ্রি করাবে',
#  'বছরের মাস্টার্স ডিগ্রি করাবে ।',
#  'মাস্টার্স ডিগ্রি করাবে । বৃত্তির',
#  'ডিগ্রি করাবে । বৃত্তির পরিমাণ',
#  'করাবে । বৃত্তির পরিমাণ বেশ',
#  '। বৃত্তির পরিমাণ বেশ ভালো',
#  'বৃত্তির পরিমাণ বেশ ভালো ।',
#  'পরিমাণ বেশ ভালো । কোনো',
#  'বেশ ভালো । কোনো চাকরির',
#  'ভালো । কোনো চাকরির অভিজ্ঞতা',
#  '। কোনো চাকরির অভিজ্ঞতা লাগবেনা',
#  'কোনো চাকরির অভিজ্ঞতা লাগবেনা ।',
#  'চাকরির অভিজ্ঞতা লাগবেনা । বিশ্বের',
#  'অভিজ্ঞতা লাগবেনা । বিশ্বের যেকোনো',
#  'লাগবেনা । বিশ্বের যেকোনো বিশ্ববিদ্যালয়',
#  '। বিশ্বের যেকোনো বিশ্ববিদ্যালয় থেকে',
#  'বিশ্বের যেকোনো বিশ্ববিদ্যালয় থেকে আপনি',
#  'যেকোনো বিশ্ববিদ্যালয় থেকে আপনি আনকন্ডিশনাল',
#  'বিশ্ববিদ্যালয় থেকে আপনি আনকন্ডিশনাল অফার',
#  'থেকে আপনি আনকন্ডিশনাল অফার লেটার',
#  'আপনি আনকন্ডিশনাল অফার লেটার পেলে',
#  'আনকন্ডিশনাল অফার লেটার পেলে আপনি',
#  'অফার লেটার পেলে আপনি এটায়',
#  'লেটার পেলে আপনি এটায় এপ্লাই',
#  'পেলে আপনি এটায় এপ্লাই করতে',
#  'আপনি এটায় এপ্লাই করতে পারবেন',
#  'এটায় এপ্লাই করতে পারবেন ।',
#  'এপ্লাই করতে পারবেন । আইল্টস',
#  'করতে পারবেন । আইল্টস দেওয়া',
#  'পারবেন । আইল্টস দেওয়া লাগবে',
#  '। আইল্টস দেওয়া লাগবে ।',
#  'আইল্টস দেওয়া লাগবে । বিশ্ববিদ্যালয়',
#  'দেওয়া লাগবে । বিশ্ববিদ্যালয় অফার',
#  'লাগবে । বিশ্ববিদ্যালয় অফার পাওয়ার',
#  '। বিশ্ববিদ্যালয় অফার পাওয়ার পর',
#  'বিশ্ববিদ্যালয় অফার পাওয়ার পর আলদাভাবে',
#  'অফার পাওয়ার পর আলদাভাবে এপ্লাই',
#  'পাওয়ার পর আলদাভাবে এপ্লাই করতে',
#  'পর আলদাভাবে এপ্লাই করতে হবে',
#  'আলদাভাবে এপ্লাই করতে হবে ।',
#  'এপ্লাই করতে হবে । সাধারণত',
#  'করতে হবে । সাধারণত জানুয়ারি',
#  'হবে । সাধারণত জানুয়ারি ফেব্রুয়ারিতে',
#  '। সাধারণত জানুয়ারি ফেব্রুয়ারিতে ওপেন',
#  'সাধারণত জানুয়ারি ফেব্রুয়ারিতে ওপেন হয়ে',
#  'জানুয়ারি ফেব্রুয়ারিতে ওপেন হয়ে এপ্রিল',
#  'ফেব্রুয়ারিতে ওপেন হয়ে এপ্রিল পর্যন্ত',
#  'ওপেন হয়ে এপ্রিল পর্যন্ত সময়',
#  'হয়ে এপ্রিল পর্যন্ত সময় থাকে',
#  'এপ্রিল পর্যন্ত সময় থাকে ।',
#  'পর্যন্ত সময় থাকে । বিশ্বের',
#  'সময় থাকে । বিশ্বের ভালো',
#  'থাকে । বিশ্বের ভালো র\u200d্যাংকের',
#  '। বিশ্বের ভালো র\u200d্যাংকের বিশ্ববিদ্যালয়ে',
#  'বিশ্বের ভালো র\u200d্যাংকের বিশ্ববিদ্যালয়ে ভর্তি',
#  'ভালো র\u200d্যাংকের বিশ্ববিদ্যালয়ে ভর্তি হয়ে',
#  'র\u200d্যাংকের বিশ্ববিদ্যালয়ে ভর্তি হয়ে অফার',
#  'বিশ্ববিদ্যালয়ে ভর্তি হয়ে অফার লেটার',
#  'ভর্তি হয়ে অফার লেটার নিয়ে',
#  'হয়ে অফার লেটার নিয়ে এই',
#  'অফার লেটার নিয়ে এই স্কলারশিপে',
#  'লেটার নিয়ে এই স্কলারশিপে এপ্লাই',
#  'নিয়ে এই স্কলারশিপে এপ্লাই করতে',
#  'এই স্কলারশিপে এপ্লাই করতে হয়',
#  'স্কলারশিপে এপ্লাই করতে হয় ।',
#  'এপ্লাই করতে হয় । সাধারণত',
#  'করতে হয় । সাধারণত উন্নয়ন',
#  'হয় । সাধারণত উন্নয়ন বিষয়ক',
#  '। সাধারণত উন্নয়ন বিষয়ক পড়ালেখার',
#  'সাধারণত উন্নয়ন বিষয়ক পড়ালেখার জন্য',
#  'উন্নয়ন বিষয়ক পড়ালেখার জন্য এই',
#  'বিষয়ক পড়ালেখার জন্য এই বৃত্তি',
#  'পড়ালেখার জন্য এই বৃত্তি দেওয়া',
#  'জন্য এই বৃত্তি দেওয়া হয়',
#  'এই বৃত্তি দেওয়া হয় ।',
#  'বৃত্তি দেওয়া হয় । দারুণ',
#  'দেওয়া হয় । দারুণ একটা',
#  'হয় । দারুণ একটা সিভি',
#  '। দারুণ একটা সিভি লাগবে',
#  'দারুণ একটা সিভি লাগবে ।',
#  'একটা সিভি লাগবে । ফরম্যাট',
#  'সিভি লাগবে । ফরম্যাট অনেকেই',
#  'লাগবে । ফরম্যাট অনেকেই দিয়ে',
#  '। ফরম্যাট অনেকেই দিয়ে দেয়',
#  'ফরম্যাট অনেকেই দিয়ে দেয় যেমন',
#  'অনেকেই দিয়ে দেয় যেমন ইরেসমাসে',
#  'দিয়ে দেয় যেমন ইরেসমাসে আপনাকে',
#  'দেয় যেমন ইরেসমাসে আপনাকে সিভি',
#  'যেমন ইরেসমাসে আপনাকে সিভি ফরম্যাট',
#  'ইরেসমাসে আপনাকে সিভি ফরম্যাট ওরাই',
#  'আপনাকে সিভি ফরম্যাট ওরাই দিয়ে',
#  'সিভি ফরম্যাট ওরাই দিয়ে দিবে',
#  'ফরম্যাট ওরাই দিয়ে দিবে ।',
#  'ওরাই দিয়ে দিবে । বাকিগুলোর',
#  'দিয়ে দিবে । বাকিগুলোর ক্ষেত্রে',
#  'দিবে । বাকিগুলোর ক্ষেত্রে সিভি',
#  '। বাকিগুলোর ক্ষেত্রে সিভি হবে',
#  'বাকিগুলোর ক্ষেত্রে সিভি হবে সিম্পল',
#  'ক্ষেত্রে সিভি হবে সিম্পল কিন্তু',
#  'সিভি হবে সিম্পল কিন্তু বেশ',
#  'হবে সিম্পল কিন্তু বেশ ঝকঝকে',
#  'সিম্পল কিন্তু বেশ ঝকঝকে ।',
#  'কিন্তু বেশ ঝকঝকে । মিথ্যা',
#  'বেশ ঝকঝকে । মিথ্যা কোনো',
#  'ঝকঝকে । মিথ্যা কোনো ইনফরমেশন',
#  '। মিথ্যা কোনো ইনফরমেশন দেওয়া',
#  'মিথ্যা কোনো ইনফরমেশন দেওয়া যাবেনা',
#  'কোনো ইনফরমেশন দেওয়া যাবেনা ।',
#  'ইনফরমেশন দেওয়া যাবেনা । আপনার',
#  'দেওয়া যাবেনা । আপনার বিশ্ববিদ্যালয়ের',
#  'যাবেনা । আপনার বিশ্ববিদ্যালয়ের থিসিস',
#  '। আপনার বিশ্ববিদ্যালয়ের থিসিস সুপারভাইজর',
#  'আপনার বিশ্ববিদ্যালয়ের থিসিস সুপারভাইজর বা',
#  'বিশ্ববিদ্যালয়ের থিসিস সুপারভাইজর বা শিক্ষক',
#  'থিসিস সুপারভাইজর বা শিক্ষক বা',
#  'সুপারভাইজর বা শিক্ষক বা আপনার',
#  'বা শিক্ষক বা আপনার কর্মক্ষেত্রের',
#  'শিক্ষক বা আপনার কর্মক্ষেত্রের বস',
#  'বা আপনার কর্মক্ষেত্রের বস থেকে',
#  'আপনার কর্মক্ষেত্রের বস থেকে আপনার',
#  'কর্মক্ষেত্রের বস থেকে আপনার দুটো',
#  'বস থেকে আপনার দুটো রেফারেন্স',
#  'থেকে আপনার দুটো রেফারেন্স লেটার',
#  'আপনার দুটো রেফারেন্স লেটার লাগবে',
#  'দুটো রেফারেন্স লেটার লাগবে ।',
#  'রেফারেন্স লেটার লাগবে । এ',
#  'লেটার লাগবে । এ ক্ষেত্রে',
#  'লাগবে । এ ক্ষেত্রে যে',
#  '। এ ক্ষেত্রে যে আপনাকে',
#  'এ ক্ষেত্রে যে আপনাকে রেফারেন্স',
#  'ক্ষেত্রে যে আপনাকে রেফারেন্স দিবে',
#  'যে আপনাকে রেফারেন্স দিবে অর্থাৎ',
#  'আপনাকে রেফারেন্স দিবে অর্থাৎ রেফারির',
#  'রেফারেন্স দিবে অর্থাৎ রেফারির যোগ্যতাও',
#  'দিবে অর্থাৎ রেফারির যোগ্যতাও সেই',
#  'অর্থাৎ রেফারির যোগ্যতাও সেই লেভেলের',
#  'রেফারির যোগ্যতাও সেই লেভেলের হতে',
#  'যোগ্যতাও সেই লেভেলের হতে হবে',
#  'সেই লেভেলের হতে হবে ।',
#  'লেভেলের হতে হবে । সে',
#  'হতে হবে । সে আপনার',
#  'হবে । সে আপনার যোগ্যতা',
#  '। সে আপনার যোগ্যতা দুর্বলতা',
#  'সে আপনার যোগ্যতা দুর্বলতা এবং',
#  'আপনার যোগ্যতা দুর্বলতা এবং পোটেনশিয়াল',
#  'যোগ্যতা দুর্বলতা এবং পোটেনশিয়াল সম্পর্কে',
#  'দুর্বলতা এবং পোটেনশিয়াল সম্পর্কে জানবে',
#  'এবং পোটেনশিয়াল সম্পর্কে জানবে ।',
#  'পোটেনশিয়াল সম্পর্কে জানবে । কাজেই',
#  'সম্পর্কে জানবে । কাজেই রেফারি',
#  'জানবে । কাজেই রেফারি নির্বাচনের',
#  '। কাজেই রেফারি নির্বাচনের ক্ষেত্রে',
#  'কাজেই রেফারি নির্বাচনের ক্ষেত্রে সতর্ক',
#  'রেফারি নির্বাচনের ক্ষেত্রে সতর্ক হোন',
#  'নির্বাচনের ক্ষেত্রে সতর্ক হোন এবং',
#  'ক্ষেত্রে সতর্ক হোন এবং আগে',
#  'সতর্ক হোন এবং আগে থেকেই',
#  'হোন এবং আগে থেকেই সুসম্পর্ক',
#  'এবং আগে থেকেই সুসম্পর্ক বজায়',
#  'আগে থেকেই সুসম্পর্ক বজায় রাখুন',
#  'থেকেই সুসম্পর্ক বজায় রাখুন ।',
#  'সুসম্পর্ক বজায় রাখুন । নিজের',
#  'বজায় রাখুন । নিজের যোগ্যতা',
#  'রাখুন । নিজের যোগ্যতা দিয়ে',
#  '। নিজের যোগ্যতা দিয়ে সুসম্পর্ক',
#  'নিজের যোগ্যতা দিয়ে সুসম্পর্ক বজায়',
#  'যোগ্যতা দিয়ে সুসম্পর্ক বজায় রাখবেন',
#  'দিয়ে সুসম্পর্ক বজায় রাখবেন ।',
#  'সুসম্পর্ক বজায় রাখবেন । মাথায়',
#  'বজায় রাখবেন । মাথায় রাখবেন',
#  'রাখবেন । মাথায় রাখবেন আপনাকে',
#  '। মাথায় রাখবেন আপনাকে কেউ',
#  'মাথায় রাখবেন আপনাকে কেউ কিছু',
#  'রাখবেন আপনাকে কেউ কিছু মুখে',
#  'আপনাকে কেউ কিছু মুখে তুলে',
#  'কেউ কিছু মুখে তুলে খাওয়াবে',
#  'কিছু মুখে তুলে খাওয়াবে না',
#  'মুখে তুলে খাওয়াবে না ।',
#  'তুলে খাওয়াবে না । কষ্ট',
#  'খাওয়াবে না । কষ্ট করতে',
#  'না । কষ্ট করতে হবে',
#  '। কষ্ট করতে হবে ।',
#  'কষ্ট করতে হবে । নিজের',
#  'করতে হবে । নিজের সাথে',
#  'হবে । নিজের সাথে প্রতিযোগিতা',
#  '। নিজের সাথে প্রতিযোগিতা করতে',
#  'নিজের সাথে প্রতিযোগিতা করতে হবে',
#  'সাথে প্রতিযোগিতা করতে হবে ।',
#  'প্রতিযোগিতা করতে হবে । জেলা',
#  'করতে হবে । জেলা প্রশাসনের',
#  'হবে । জেলা প্রশাসনের একজন',
#  '। জেলা প্রশাসনের একজন এক্সিকিউটিভ',
#  'জেলা প্রশাসনের একজন এক্সিকিউটিভ ম্যাজিস্ট্রেটকে',
#  'প্রশাসনের একজন এক্সিকিউটিভ ম্যাজিস্ট্রেটকে এই',
#  'একজন এক্সিকিউটিভ ম্যাজিস্ট্রেটকে এই দায়িত্ব',
#  'এক্সিকিউটিভ ম্যাজিস্ট্রেটকে এই দায়িত্ব দেওয়া',
#  'ম্যাজিস্ট্রেটকে এই দায়িত্ব দেওয়া হয়',
#  'এই দায়িত্ব দেওয়া হয় ।',
#  'দায়িত্ব দেওয়া হয় । এনডিসির',
#  'দেওয়া হয় । এনডিসির কাজ',
#  'হয় । এনডিসির কাজ হলো',
#  '। এনডিসির কাজ হলো মূলত',
#  'এনডিসির কাজ হলো মূলত জেলা',
#  'কাজ হলো মূলত জেলা প্রশাসন',
#  'হলো মূলত জেলা প্রশাসন এবং',
#  'মূলত জেলা প্রশাসন এবং জেলা',
#  'জেলা প্রশাসন এবং জেলা সংশ্লিষ্ট',
#  'প্রশাসন এবং জেলা সংশ্লিষ্ট সকল',
#  'এবং জেলা সংশ্লিষ্ট সকল সরকারি',
#  'জেলা সংশ্লিষ্ট সকল সরকারি বিষয়ে',
#  'সংশ্লিষ্ট সকল সরকারি বিষয়ে লজিস্টিকস',
#  'সকল সরকারি বিষয়ে লজিস্টিকস সাপোর্ট',
#  'সরকারি বিষয়ে লজিস্টিকস সাপোর্ট দেওয়া',
#  'বিষয়ে লজিস্টিকস সাপোর্ট দেওয়া ।',
#  'লজিস্টিকস সাপোর্ট দেওয়া । যেমন',
#  'সাপোর্ট দেওয়া । যেমন জেলায়',
#  'দেওয়া । যেমন জেলায় কোনো',
#  '। যেমন জেলায় কোনো ভিআইপি',
#  'যেমন জেলায় কোনো ভিআইপি আসলে',
#  'জেলায় কোনো ভিআইপি আসলে যথাযোগ্যভাবে',
#  'কোনো ভিআইপি আসলে যথাযোগ্যভাবে তার',
#  'ভিআইপি আসলে যথাযোগ্যভাবে তার আবাসন',
#  'আসলে যথাযোগ্যভাবে তার আবাসন ও',
#  'যথাযোগ্যভাবে তার আবাসন ও পরিবহন',
#  'তার আবাসন ও পরিবহন নিশ্চিত',
#  'আবাসন ও পরিবহন নিশ্চিত করা',
#  'ও পরিবহন নিশ্চিত করা ।',
#  'পরিবহন নিশ্চিত করা । তার',
#  'নিশ্চিত করা । তার সফরসঙ্গীদের',
#  'করা । তার সফরসঙ্গীদের আবাসন',
#  '। তার সফরসঙ্গীদের আবাসন আহার',
#  'তার সফরসঙ্গীদের আবাসন আহার ইত্যাদি',
#  'সফরসঙ্গীদের আবাসন আহার ইত্যাদি নিশ্চিত',
#  'আবাসন আহার ইত্যাদি নিশ্চিত করা',
#  'আহার ইত্যাদি নিশ্চিত করা এবং',
#  'ইত্যাদি নিশ্চিত করা এবং জেলার',
#  'নিশ্চিত করা এবং জেলার পরিবহন',
#  'করা এবং জেলার পরিবহন পুলের',
#  'এবং জেলার পরিবহন পুলের গাড়ি',
#  'জেলার পরিবহন পুলের গাড়ি সার্কিট',
#  'পরিবহন পুলের গাড়ি সার্কিট হাউজ',
#  'পুলের গাড়ি সার্কিট হাউজ ব্যবস্থাপনা',
#  'গাড়ি সার্কিট হাউজ ব্যবস্থাপনা শ্রদ্ধেয়',
#  'সার্কিট হাউজ ব্যবস্থাপনা শ্রদ্ধেয় ডিসি',
#  'হাউজ ব্যবস্থাপনা শ্রদ্ধেয় ডিসি স্যারের',
#  'ব্যবস্থাপনা শ্রদ্ধেয় ডিসি স্যারের বাংলোর',
#  'শ্রদ্ধেয় ডিসি স্যারের বাংলোর তদারকি',
#  'ডিসি স্যারের বাংলোর তদারকি অফিসের',
#  'স্যারের বাংলোর তদারকি অফিসের কার',
#  'বাংলোর তদারকি অফিসের কার কী',
#  'তদারকি অফিসের কার কী লাগবে',
#  'অফিসের কার কী লাগবে এক',
#  'কার কী লাগবে এক কথায়',
#  'কী লাগবে এক কথায় সবকিছু',
#  'লাগবে এক কথায় সবকিছু দেখভাল',
#  'এক কথায় সবকিছু দেখভাল করতে',
#  'কথায় সবকিছু দেখভাল করতে হয়',
#  'সবকিছু দেখভাল করতে হয় এই',
#  'দেখভাল করতে হয় এই এনডিসির',
#  'করতে হয় এই এনডিসির ।',
#  'হয় এই এনডিসির । এনডিসির',
#  'এই এনডিসির । এনডিসির যেই',
#  'এনডিসির । এনডিসির যেই অফিশিয়াল',
#  '। এনডিসির যেই অফিশিয়াল ফোন',
#  'এনডিসির যেই অফিশিয়াল ফোন আছে',
#  'যেই অফিশিয়াল ফোন আছে সেটা',
#  'অফিশিয়াল ফোন আছে সেটা কখনো',
#  'ফোন আছে সেটা কখনো বন্ধ',
#  'আছে সেটা কখনো বন্ধ হয়না',
#  'সেটা কখনো বন্ধ হয়না ।',
#  'কখনো বন্ধ হয়না । রোজ',
#  'বন্ধ হয়না । রোজ কেয়ামতের',
#  'হয়না । রোজ কেয়ামতের দিনেও',
#  '। রোজ কেয়ামতের দিনেও যদি',
#  'রোজ কেয়ামতের দিনেও যদি কেউ',
#  'কেয়ামতের দিনেও যদি কেউ ফোন',
#  'দিনেও যদি কেউ ফোন করে',
#  'যদি কেউ ফোন করে বলে',
#  'কেউ ফোন করে বলে স্যার',
#  'ফোন করে বলে স্যার গাড়ি',
#  'করে বলে স্যার গাড়ি লাগবে',
#  'বলে স্যার গাড়ি লাগবে ।',
#  'স্যার গাড়ি লাগবে । থাকা',
#  'গাড়ি লাগবে । থাকা লাগবে',
#  'লাগবে । থাকা লাগবে নরসিংদীতে',
#  '। থাকা লাগবে নরসিংদীতে ।',
#  'থাকা লাগবে নরসিংদীতে । স্যার',
#  'লাগবে নরসিংদীতে । স্যার এই',
#  'নরসিংদীতে । স্যার এই সমস্যা',
#  '। স্যার এই সমস্যা হয়েছে',
#  'স্যার এই সমস্যা হয়েছে ।',
#  'এই সমস্যা হয়েছে । সেটাও',
#  'সমস্যা হয়েছে । সেটাও এনডিসির',
#  'হয়েছে । সেটাও এনডিসির যেভাবেই',
#  '। সেটাও এনডিসির যেভাবেই হোক',
#  'সেটাও এনডিসির যেভাবেই হোক ম্যানেজ',
#  'এনডিসির যেভাবেই হোক ম্যানেজ করা',
#  'যেভাবেই হোক ম্যানেজ করা লাগবে',
#  'হোক ম্যানেজ করা লাগবে ।',
#  'ম্যানেজ করা লাগবে । এর',
#  'করা লাগবে । এর পাশাপাশি',
#  'লাগবে । এর পাশাপাশি দাপ্তরিক',
#  '। এর পাশাপাশি দাপ্তরিক কাজ',
#  'এর পাশাপাশি দাপ্তরিক কাজ এবং',
#  'পাশাপাশি দাপ্তরিক কাজ এবং বিচারিক',
#  'দাপ্তরিক কাজ এবং বিচারিক কাজ',
#  'কাজ এবং বিচারিক কাজ তো',
#  'এবং বিচারিক কাজ তো আছেই',
#  'বিচারিক কাজ তো আছেই ।',
#  'কাজ তো আছেই । আমি',
#  'তো আছেই । আমি তখনো',
#  'আছেই । আমি তখনো বুঝিনি',
#  '। আমি তখনো বুঝিনি কী',
#  'আমি তখনো বুঝিনি কী এক',
#  'তখনো বুঝিনি কী এক কর্মযজ্ঞ',
#  'বুঝিনি কী এক কর্মযজ্ঞ আমার',
#  'কী এক কর্মযজ্ঞ আমার জন্য',
#  'এক কর্মযজ্ঞ আমার জন্য অপেক্ষা',
#  'কর্মযজ্ঞ আমার জন্য অপেক্ষা করছিলো',
#  'আমার জন্য অপেক্ষা করছিলো ।',
#  'জন্য অপেক্ষা করছিলো । আমি',
#  'অপেক্ষা করছিলো । আমি মাননীয়',
#  'করছিলো । আমি মাননীয় প্রধানমন্ত্রীর',
#  '। আমি মাননীয় প্রধানমন্ত্রীর কার্যালয়ের',
#  'আমি মাননীয় প্রধানমন্ত্রীর কার্যালয়ের এটুআই',
#  'মাননীয় প্রধানমন্ত্রীর কার্যালয়ের এটুআই থেকে',
#  'প্রধানমন্ত্রীর কার্যালয়ের এটুআই থেকে মেইল',
#  'কার্যালয়ের এটুআই থেকে মেইল ফোন',
#  'এটুআই থেকে মেইল ফোন কল',
#  'থেকে মেইল ফোন কল পেতে',
#  'মেইল ফোন কল পেতে থাকলাম',
#  'ফোন কল পেতে থাকলাম ।',
#  'কল পেতে থাকলাম । সময়',
#  'পেতে থাকলাম । সময় গড়ায়',
#  'থাকলাম । সময় গড়ায় আর',
#  '। সময় গড়ায় আর মেইল',
#  'সময় গড়ায় আর মেইল ফোন',
#  'গড়ায় আর মেইল ফোন কলের',
#  'আর মেইল ফোন কলের গতি',
#  'মেইল ফোন কলের গতি বাড়ে',
#  'ফোন কলের গতি বাড়ে ।',
#  'কলের গতি বাড়ে । তাদের',
#  'গতি বাড়ে । তাদের কাজ',
#  'বাড়ে । তাদের কাজ ছিলো',
#  '। তাদের কাজ ছিলো নরসিংদীর',
#  'তাদের কাজ ছিলো নরসিংদীর পুরো',
#  'কাজ ছিলো নরসিংদীর পুরো জেলার',
#  'ছিলো নরসিংদীর পুরো জেলার সিক্যিউরিটি',
#  'নরসিংদীর পুরো জেলার সিক্যিউরিটি এনশিউর',
#  'পুরো জেলার সিক্যিউরিটি এনশিউর করা',
#  'জেলার সিক্যিউরিটি এনশিউর করা ।',
#  'সিক্যিউরিটি এনশিউর করা । তাদের',
#  'এনশিউর করা । তাদের আবাসন',
#  'করা । তাদের আবাসন গাড়িসহ',
#  '। তাদের আবাসন গাড়িসহ সকল',
#  'তাদের আবাসন গাড়িসহ সকল ধরণের',
#  'আবাসন গাড়িসহ সকল ধরণের রিকোয়ারমেন্টের',
#  'গাড়িসহ সকল ধরণের রিকোয়ারমেন্টের দায়িত্ব',
#  'সকল ধরণের রিকোয়ারমেন্টের দায়িত্ব যথারীতি',
#  'ধরণের রিকোয়ারমেন্টের দায়িত্ব যথারীতি পড়লো',
#  'রিকোয়ারমেন্টের দায়িত্ব যথারীতি পড়লো আমার',
#  'দায়িত্ব যথারীতি পড়লো আমার কাঁধে',
#  'যথারীতি পড়লো আমার কাঁধে ।',
#  'পড়লো আমার কাঁধে । নিরাপত্তা',
#  'আমার কাঁধে । নিরাপত্তা ইস্যু',
#  'কাঁধে । নিরাপত্তা ইস্যু হিসেবে',
#  '। নিরাপত্তা ইস্যু হিসেবে তারিখের',
#  'নিরাপত্তা ইস্যু হিসেবে তারিখের প্রোগ্রামে',
#  'ইস্যু হিসেবে তারিখের প্রোগ্রামে কারা',
#  'হিসেবে তারিখের প্রোগ্রামে কারা কারা',
#  'তারিখের প্রোগ্রামে কারা কারা থাকবে',
#  'প্রোগ্রামে কারা কারা থাকবে তাদের',
#  'কারা কারা থাকবে তাদের সিক্যিউরিটি',
#  'কারা থাকবে তাদের সিক্যিউরিটি ক্লিয়ারেন্সের',
#  'থাকবে তাদের সিক্যিউরিটি ক্লিয়ারেন্সের জন্য',
#  'তাদের সিক্যিউরিটি ক্লিয়ারেন্সের জন্য ডিএসবি',
#  'সিক্যিউরিটি ক্লিয়ারেন্সের জন্য ডিএসবি পাস',
#  'ক্লিয়ারেন্সের জন্য ডিএসবি পাস করানো',
#  'জন্য ডিএসবি পাস করানো থেকে',
#  'ডিএসবি পাস করানো থেকে শুরু',
#  'পাস করানো থেকে শুরু করে',
#  'করানো থেকে শুরু করে সবকিছু',
#  'থেকে শুরু করে সবকিছু খেয়াল',
#  'শুরু করে সবকিছু খেয়াল রাখতে',
#  'করে সবকিছু খেয়াল রাখতে হলো',
#  'সবকিছু খেয়াল রাখতে হলো ।',
#  'খেয়াল রাখতে হলো । তারিখ',
#  'রাখতে হলো । তারিখ আসলো',
#  'হলো । তারিখ আসলো সেনাবাহিনীর',
#  '। তারিখ আসলো সেনাবাহিনীর ডগ',
#  'তারিখ আসলো সেনাবাহিনীর ডগ ।',
#  'আসলো সেনাবাহিনীর ডগ । স্কোয়াড',
#  'সেনাবাহিনীর ডগ । স্কোয়াড ।',
#  'ডগ । স্কোয়াড । ফোন',
#  '। স্কোয়াড । ফোন দিয়ে',
#  'স্কোয়াড । ফোন দিয়ে বললো',
#  '। ফোন দিয়ে বললো স্যার',
#  'ফোন দিয়ে বললো স্যার আমরা',
#  'দিয়ে বললো স্যার আমরা মেম্বার',
#  'বললো স্যার আমরা মেম্বার আর',
#  'স্যার আমরা মেম্বার আর ছয়টা',
#  'আমরা মেম্বার আর ছয়টা কুকুর',
#  'মেম্বার আর ছয়টা কুকুর থাকার',
#  'আর ছয়টা কুকুর থাকার ব্যবস্থা',
#  'ছয়টা কুকুর থাকার ব্যবস্থা করেন',
#  'কুকুর থাকার ব্যবস্থা করেন ।',
#  'থাকার ব্যবস্থা করেন । আমার',
#  'ব্যবস্থা করেন । আমার তখন',
#  'করেন । আমার তখন অলরেডি',
#  '। আমার তখন অলরেডি সার্কিট',
#  'আমার তখন অলরেডি সার্কিট হাউজ',
#  'তখন অলরেডি সার্কিট হাউজ ফুল',
#  'অলরেডি সার্কিট হাউজ ফুল ।',
#  'সার্কিট হাউজ ফুল । ম্যানেজ',
#  'হাউজ ফুল । ম্যানেজ করলাম',
#  'ফুল । ম্যানেজ করলাম ।',
#  '। ম্যানেজ করলাম । নেভির',
#  'ম্যানেজ করলাম । নেভির ডাইভার',
#  'করলাম । নেভির ডাইভার দল',
#  '। নেভির ডাইভার দল ফোন',
#  'নেভির ডাইভার দল ফোন দিয়ে',
#  'ডাইভার দল ফোন দিয়ে বললো',
#  'দল ফোন দিয়ে বললো স্যার',
#  'ফোন দিয়ে বললো স্যার আমরা',
#  'দিয়ে বললো স্যার আমরা আসতেছি',
#  'বললো স্যার আমরা আসতেছি ।',
#  'স্যার আমরা আসতেছি । থাকবো',
#  'আমরা আসতেছি । থাকবো ম্যানেজ',
#  'আসতেছি । থাকবো ম্যানেজ করেন',
#  '। থাকবো ম্যানেজ করেন ।',
#  'থাকবো ম্যানেজ করেন । সেনাবাহিনীর',
#  'ম্যানেজ করেন । সেনাবাহিনীর সিক্যিউরিটি',
#  'করেন । সেনাবাহিনীর সিক্যিউরিটি সুইপিং',
#  '। সেনাবাহিনীর সিক্যিউরিটি সুইপিং টিম',
#  'সেনাবাহিনীর সিক্যিউরিটি সুইপিং টিম আসলো',
#  'সিক্যিউরিটি সুইপিং টিম আসলো একটা',
#  'সুইপিং টিম আসলো একটা আবাসনের',
#  'টিম আসলো একটা আবাসনের ব্যবস্থা',
#  'আসলো একটা আবাসনের ব্যবস্থা করলাম',
#  'একটা আবাসনের ব্যবস্থা করলাম তাদেরও',
#  'আবাসনের ব্যবস্থা করলাম তাদেরও ।',
#  'ব্যবস্থা করলাম তাদেরও । রাণী',
#  'করলাম তাদেরও । রাণী আসার',
#  'তাদেরও । রাণী আসার কথা',
#  '। রাণী আসার কথা সড়ক',
#  'রাণী আসার কথা সড়ক পথে',
#  'আসার কথা সড়ক পথে কিন্তু',
#  'কথা সড়ক পথে কিন্তু হেলিপ্যাড',
#  'সড়ক পথে কিন্তু হেলিপ্যাড রেডি',
#  'পথে কিন্তু হেলিপ্যাড রেডি করতে',
#  'কিন্তু হেলিপ্যাড রেডি করতে হবে',
#  'হেলিপ্যাড রেডি করতে হবে ।',
#  'রেডি করতে হবে । গণপূর্তের',
#  'করতে হবে । গণপূর্তের নির্বাহী',
#  'হবে । গণপূর্তের নির্বাহী প্রকৌশলী',
#  '। গণপূর্তের নির্বাহী প্রকৌশলী মহোদয়কে',
#  'গণপূর্তের নির্বাহী প্রকৌশলী মহোদয়কে বললাম',
#  'নির্বাহী প্রকৌশলী মহোদয়কে বললাম স্টেডিয়ামে',
#  'প্রকৌশলী মহোদয়কে বললাম স্টেডিয়ামে হেলিপ্যাড',
#  'মহোদয়কে বললাম স্টেডিয়ামে হেলিপ্যাড বানান',
#  'বললাম স্টেডিয়ামে হেলিপ্যাড বানান ।',
#  'স্টেডিয়ামে হেলিপ্যাড বানান । বানানো',
#  'হেলিপ্যাড বানান । বানানো হলো',
#  'বানান । বানানো হলো ।',
#  '। বানানো হলো । মোটরকেড',
#  'বানানো হলো । মোটরকেড এবং',
#  'হলো । মোটরকেড এবং নিরাপত্তার',
#  '। মোটরকেড এবং নিরাপত্তার দায়িত্বে',
#  'মোটরকেড এবং নিরাপত্তার দায়িত্বে থাকা',
#  'এবং নিরাপত্তার দায়িত্বে থাকা অফিসারের',
#  'নিরাপত্তার দায়িত্বে থাকা অফিসারের জন্য',
#  'দায়িত্বে থাকা অফিসারের জন্য প্রচুর',
#  'থাকা অফিসারের জন্য প্রচুর গাড়ি',
#  'অফিসারের জন্য প্রচুর গাড়ি লাগবে',
#  'জন্য প্রচুর গাড়ি লাগবে ।',
#  'প্রচুর গাড়ি লাগবে । করলাম',
#  'গাড়ি লাগবে । করলাম ম্যানেজ',
#  'লাগবে । করলাম ম্যানেজ ।',
#  '। করলাম ম্যানেজ । এর',
#  'করলাম ম্যানেজ । এর মাঝে',
#  'ম্যানেজ । এর মাঝে হঠাত',
#  '। এর মাঝে হঠাত বলা',
#  'এর মাঝে হঠাত বলা হলো',
#  'মাঝে হঠাত বলা হলো রাণী',
#  'হঠাত বলা হলো রাণী যদি',
#  'বলা হলো রাণী যদি লাঞ্চ',
#  'হলো রাণী যদি লাঞ্চ করতে',
#  'রাণী যদি লাঞ্চ করতে চায়',
#  'যদি লাঞ্চ করতে চায় তাহলে',
#  'লাঞ্চ করতে চায় তাহলে মেন্যু',
#  'করতে চায় তাহলে মেন্যু কী',
#  'চায় তাহলে মেন্যু কী হবে',
#  'তাহলে মেন্যু কী হবে ।',
#  'মেন্যু কী হবে । নেট',
#  'কী হবে । নেট ঘেঁটে',
#  'হবে । নেট ঘেঁটে ডাচদের',
#  '। নেট ঘেঁটে ডাচদের খাবারের',
#  'নেট ঘেঁটে ডাচদের খাবারের আইডিয়া',
#  'ঘেঁটে ডাচদের খাবারের আইডিয়া নিলাম',
#  'ডাচদের খাবারের আইডিয়া নিলাম ।',
#  'খাবারের আইডিয়া নিলাম । আমার',
#  'আইডিয়া নিলাম । আমার বউকেও',
#  'নিলাম । আমার বউকেও বললাম',
#  '। আমার বউকেও বললাম হেল্প',
#  'আমার বউকেও বললাম হেল্প করতে',
#  'বউকেও বললাম হেল্প করতে ।',
#  'বললাম হেল্প করতে । যদিও',
#  'হেল্প করতে । যদিও ওটা',
#  'করতে । যদিও ওটা পরে',
#  '। যদিও ওটা পরে আর',
#  'যদিও ওটা পরে আর প্রয়োজন',
#  'ওটা পরে আর প্রয়োজন হয়নি',
#  'পরে আর প্রয়োজন হয়নি ।',
#  'আর প্রয়োজন হয়নি । রাণীর',
#  'প্রয়োজন হয়নি । রাণীর জন্য',
#  'হয়নি । রাণীর জন্য মেডিকেল',
#  '। রাণীর জন্য মেডিকেল টিম',
#  'রাণীর জন্য মেডিকেল টিম ফায়ার',
#  'জন্য মেডিকেল টিম ফায়ার সার্ভিস',
#  'মেডিকেল টিম ফায়ার সার্ভিস ফুড',
#  'টিম ফায়ার সার্ভিস ফুড এক্সামিনার',
#  'ফায়ার সার্ভিস ফুড এক্সামিনার সহ',
#  'সার্ভিস ফুড এক্সামিনার সহ সকল',
#  'ফুড এক্সামিনার সহ সকল কিছু',
#  'এক্সামিনার সহ সকল কিছু রেডি',
#  'সহ সকল কিছু রেডি রাখলাম',
#  'সকল কিছু রেডি রাখলাম ।',
#  'কিছু রেডি রাখলাম । রাণীকে',
#  'রেডি রাখলাম । রাণীকে আমাদের',
#  'রাখলাম । রাণীকে আমাদের জেলা',
#  '। রাণীকে আমাদের জেলা প্রশাসক',
#  'রাণীকে আমাদের জেলা প্রশাসক স্যার',
#  'আমাদের জেলা প্রশাসক স্যার নরসিংদী',
#  'জেলা প্রশাসক স্যার নরসিংদী জেলার',
#  'প্রশাসক স্যার নরসিংদী জেলার একটা',
#  'স্যার নরসিংদী জেলার একটা টোকেন',
#  'নরসিংদী জেলার একটা টোকেন গিফট',
#  'জেলার একটা টোকেন গিফট দিবে',
#  'একটা টোকেন গিফট দিবে ।',
#  'টোকেন গিফট দিবে । সেটাও',
#  'গিফট দিবে । সেটাও রেডি',
#  'দিবে । সেটাও রেডি করলাম',
#  '। সেটাও রেডি করলাম ।',
#  'সেটাও রেডি করলাম । আমি',
#  ...]

# %%
# save sequences to file
out_filename = r'C:\Users\OFR\Desktop\Thesis work\version four\updated_data_4_1.txt'
save_doc(sequences, out_filename)
