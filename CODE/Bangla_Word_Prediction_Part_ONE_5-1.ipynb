# %%
import string
import io
import codecs
import os
import re

# %%
# load doc into memory
def load_doc(filename):
    with io.open(filename, 'r', encoding='utf8') as f:
        text = f.read()
    return text

# %%
# turn a doc into clean tokens
def clean_doc(doc):
    # replace '--' with a space ' '
    doc = doc.replace('?', ' ? ')
    doc = doc.replace('।', ' । ')
    doc = doc.replace(',', ' । ')
    doc = doc.replace('-', ' । ')
    doc = doc.replace('(', ' । ')
    doc = doc.replace(')', ' । ')
    doc = doc.replace('{', ' । ')
    doc = doc.replace('}', ' । ')
    doc = doc.replace('[', ' । ')
    doc = doc.replace(']', ' । ')
    doc = doc.replace('*', ' ')
    doc = doc.replace('^', ' ')
    doc = doc.replace('#', ' ')
    doc = doc.replace('~', ' ')
    doc = doc.replace('`', ' ')
    doc = doc.replace('/', ' ')
    doc = doc.replace('_', ' ')
    doc = doc.replace('’', ' ')
    doc = doc.replace('‘', ' ')
    doc = doc.replace('.',' । ')
    
    
    # split into tokens by white space
    tokens = doc.split()
    # remove punctuation from each token
    #table = str.maketrans('', '', string.punctuation)
    #tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    #tokens = [word for word in tokens if word.isalpha()]
    # make lower case
    tokens = [word.lower() for word in tokens]
    return tokens

# %%
# save tokens to file, one dialog per line
def save_doc(lines, filename):
	data = '\n'.join(lines)
	file = open(filename, 'w', encoding='utf8')
	file.write(data)
	file.close()

# %%
# load document
in_filename = r'C:\Users\OFR\Desktop\Thesis work\version four\Main Dataset.txt'
doc = load_doc(in_filename)
print(doc[:200])
# Out:
# ﻿কর্পোরেশনের দোষ তো আছে । কিন্তু আমরা যে সুযোগ বুঝে হাজার হাজার কোটি টাকার ট্যাক্স ফাকি দিয়ে আসছি সেটাও আমরা জানি । এই ভয়ে সবাই স্যু করার সাহস পাবেনা । কারণ উলটা স্যু সে নিজে খেয়ে যাবে । আপনি স্যু করে

# %%
# clean document

tokens = clean_doc(doc)
#tokens = doc
print(tokens[:200])
print('Total Tokens: %d' % len(tokens))
print('Unique Tokens: %d' % len(set(tokens)))
# Out:
# ['\ufeffকর্পোরেশনের', 'দোষ', 'তো', 'আছে', '।', 'কিন্তু', 'আমরা', 'যে', 'সুযোগ', 'বুঝে', 'হাজার', 'হাজার', 'কোটি', 'টাকার', 'ট্যাক্স', 'ফাকি', 'দিয়ে', 'আসছি', 'সেটাও', 'আমরা', 'জানি', '।', 'এই', 'ভয়ে', 'সবাই', 'স্যু', 'করার', 'সাহস', 'পাবেনা', '।', 'কারণ', 'উলটা', 'স্যু', 'সে', 'নিজে', 'খেয়ে', 'যাবে', '।', 'আপনি', 'স্যু', 'করে', 'দৃষ্টান্ত', 'শুরু', 'করে', 'দিলেই', 'পারেন', '।', 'অন্যরাও', 'ধীরে', 'ধীরে', 'উৎসাহিত', 'হবে', '।', 'পরিবর্তন', 'আসবে', '।', 'আমাদের', 'সবার', 'মনেই', 'বিদেশে', 'পড়তে', 'যাওয়ার', 'সুপ্ত', 'কিন্তু', 'তীব্র', 'আকাঙ্ক্ষা', 'কাজ', 'করে', '।', 'বিদেশে', 'পড়ার', 'ক্ষেত্রে', 'খরচের', 'ব্যাপারটা', 'মাথায়', 'আসে', 'বলেই', 'আমরা', 'অনেকেই', 'চাই', 'বৃত্তি', 'বা', 'স্কলারশিপ', 'এর', 'ব্যাপারে', 'খোঁজ', 'নিতে', '।', 'পুরো', 'প্রক্রিয়াটি', 'অনেক', 'বিশদ', 'হওয়ায়', 'আমার', 'ক্ষুদ্র', 'অভিজ্ঞতা', 'থেকে', 'আমি', 'চেষ্টা', 'করবো', 'আমার', 'শিক্ষার্থীদের', 'কিছুটা', 'জানানোর', '।', 'আমার', 'লেখাটা', 'টি', 'পর্বে', 'থাকবে', '।', 'আজ', 'প্রথম', 'পর্ব', '।', 'আজকে', 'আমি', 'আলোচনা', 'করবো', 'বাংলাদেশি', 'শিক্ষার্থীদের', 'জন্য', 'বিদেশে', 'পড়তে', 'যাওয়ার', 'স্কলারশিপ', 'নিয়ে', '।', 'পরবর্তীতে', 'বিভিন্ন', 'দেশে', 'এপ্লাই', 'করার', 'প্রক্রিয়া', 'ক্রেডিট', 'ট্রান্সফার', 'বিশ্ববিদ্যালয়ের', 'ইন', 'হাউস', 'স্কলারশিপ', 'ইত্যাদি', 'বিষয়ে', 'আলোচনা', 'করবো', '।', 'যুক্তরাজ্যে', 'পড়তে', 'যাওয়ার', 'জন্য', 'ব্রিটিশ', 'সরকারের', 'বৃত্তি', 'এটি', '।', 'অত্যন্ত', 'সম্মানজনক', 'এবং', 'সেইসাথে', 'খুবই', 'প্রতিযোগিতামূলক', '।', 'সাধারণত', 'যারা', 'শিক্ষকতা', 'পেশায়', 'নিয়োজিত', 'থাকেন', 'তারা', 'এটা', 'পেয়ে', 'থাকেন', 'তবে', 'শিক্ষকই', 'হতে', 'হবে', 'এমন', 'কোনো', 'বাধ্যবাধকতা', 'নেই', '।', 'আপনার', 'বয়স', 'কম', 'হলে', 'এবং', 'আপনার', 'ব্যাচেলর', 'ডিগ্রিতে', 'নম্বর', 'থাকলেই', 'আপনি', 'এই', 'স্কলারশিপের', 'জন্য', 'এপ্লাই', 'করতে', 'পারবেন', '।', 'এক্ষেত্রে', 'যেটা']
# Total Tokens: 60239
# Unique Tokens: 10426

# %%
# organize into sequences of tokens
length = 5 + 1
sequences = list()
for i in range(length, len(tokens)):
	# select sequence of tokens
	seq = tokens[i-length:i]
	# convert into a line
	line = ' '.join(seq)
	# store
	sequences.append(line)
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 60233

# %%
sequences
# Out:
# ['\ufeffকর্পোরেশনের দোষ তো আছে । কিন্তু',
#  'দোষ তো আছে । কিন্তু আমরা',
#  'তো আছে । কিন্তু আমরা যে',
#  'আছে । কিন্তু আমরা যে সুযোগ',
#  '। কিন্তু আমরা যে সুযোগ বুঝে',
#  'কিন্তু আমরা যে সুযোগ বুঝে হাজার',
#  'আমরা যে সুযোগ বুঝে হাজার হাজার',
#  'যে সুযোগ বুঝে হাজার হাজার কোটি',
#  'সুযোগ বুঝে হাজার হাজার কোটি টাকার',
#  'বুঝে হাজার হাজার কোটি টাকার ট্যাক্স',
#  'হাজার হাজার কোটি টাকার ট্যাক্স ফাকি',
#  'হাজার কোটি টাকার ট্যাক্স ফাকি দিয়ে',
#  'কোটি টাকার ট্যাক্স ফাকি দিয়ে আসছি',
#  'টাকার ট্যাক্স ফাকি দিয়ে আসছি সেটাও',
#  'ট্যাক্স ফাকি দিয়ে আসছি সেটাও আমরা',
#  'ফাকি দিয়ে আসছি সেটাও আমরা জানি',
#  'দিয়ে আসছি সেটাও আমরা জানি ।',
#  'আসছি সেটাও আমরা জানি । এই',
#  'সেটাও আমরা জানি । এই ভয়ে',
#  'আমরা জানি । এই ভয়ে সবাই',
#  'জানি । এই ভয়ে সবাই স্যু',
#  '। এই ভয়ে সবাই স্যু করার',
#  'এই ভয়ে সবাই স্যু করার সাহস',
#  'ভয়ে সবাই স্যু করার সাহস পাবেনা',
#  'সবাই স্যু করার সাহস পাবেনা ।',
#  'স্যু করার সাহস পাবেনা । কারণ',
#  'করার সাহস পাবেনা । কারণ উলটা',
#  'সাহস পাবেনা । কারণ উলটা স্যু',
#  'পাবেনা । কারণ উলটা স্যু সে',
#  '। কারণ উলটা স্যু সে নিজে',
#  'কারণ উলটা স্যু সে নিজে খেয়ে',
#  'উলটা স্যু সে নিজে খেয়ে যাবে',
#  'স্যু সে নিজে খেয়ে যাবে ।',
#  'সে নিজে খেয়ে যাবে । আপনি',
#  'নিজে খেয়ে যাবে । আপনি স্যু',
#  'খেয়ে যাবে । আপনি স্যু করে',
#  'যাবে । আপনি স্যু করে দৃষ্টান্ত',
#  '। আপনি স্যু করে দৃষ্টান্ত শুরু',
#  'আপনি স্যু করে দৃষ্টান্ত শুরু করে',
#  'স্যু করে দৃষ্টান্ত শুরু করে দিলেই',
#  'করে দৃষ্টান্ত শুরু করে দিলেই পারেন',
#  'দৃষ্টান্ত শুরু করে দিলেই পারেন ।',
#  'শুরু করে দিলেই পারেন । অন্যরাও',
#  'করে দিলেই পারেন । অন্যরাও ধীরে',
#  'দিলেই পারেন । অন্যরাও ধীরে ধীরে',
#  'পারেন । অন্যরাও ধীরে ধীরে উৎসাহিত',
#  '। অন্যরাও ধীরে ধীরে উৎসাহিত হবে',
#  'অন্যরাও ধীরে ধীরে উৎসাহিত হবে ।',
#  'ধীরে ধীরে উৎসাহিত হবে । পরিবর্তন',
#  'ধীরে উৎসাহিত হবে । পরিবর্তন আসবে',
#  'উৎসাহিত হবে । পরিবর্তন আসবে ।',
#  'হবে । পরিবর্তন আসবে । আমাদের',
#  '। পরিবর্তন আসবে । আমাদের সবার',
#  'পরিবর্তন আসবে । আমাদের সবার মনেই',
#  'আসবে । আমাদের সবার মনেই বিদেশে',
#  '। আমাদের সবার মনেই বিদেশে পড়তে',
#  'আমাদের সবার মনেই বিদেশে পড়তে যাওয়ার',
#  'সবার মনেই বিদেশে পড়তে যাওয়ার সুপ্ত',
#  'মনেই বিদেশে পড়তে যাওয়ার সুপ্ত কিন্তু',
#  'বিদেশে পড়তে যাওয়ার সুপ্ত কিন্তু তীব্র',
#  'পড়তে যাওয়ার সুপ্ত কিন্তু তীব্র আকাঙ্ক্ষা',
#  'যাওয়ার সুপ্ত কিন্তু তীব্র আকাঙ্ক্ষা কাজ',
#  'সুপ্ত কিন্তু তীব্র আকাঙ্ক্ষা কাজ করে',
#  'কিন্তু তীব্র আকাঙ্ক্ষা কাজ করে ।',
#  'তীব্র আকাঙ্ক্ষা কাজ করে । বিদেশে',
#  'আকাঙ্ক্ষা কাজ করে । বিদেশে পড়ার',
#  'কাজ করে । বিদেশে পড়ার ক্ষেত্রে',
#  'করে । বিদেশে পড়ার ক্ষেত্রে খরচের',
#  '। বিদেশে পড়ার ক্ষেত্রে খরচের ব্যাপারটা',
#  'বিদেশে পড়ার ক্ষেত্রে খরচের ব্যাপারটা মাথায়',
#  'পড়ার ক্ষেত্রে খরচের ব্যাপারটা মাথায় আসে',
#  'ক্ষেত্রে খরচের ব্যাপারটা মাথায় আসে বলেই',
#  'খরচের ব্যাপারটা মাথায় আসে বলেই আমরা',
#  'ব্যাপারটা মাথায় আসে বলেই আমরা অনেকেই',
#  'মাথায় আসে বলেই আমরা অনেকেই চাই',
#  'আসে বলেই আমরা অনেকেই চাই বৃত্তি',
#  'বলেই আমরা অনেকেই চাই বৃত্তি বা',
#  'আমরা অনেকেই চাই বৃত্তি বা স্কলারশিপ',
#  'অনেকেই চাই বৃত্তি বা স্কলারশিপ এর',
#  'চাই বৃত্তি বা স্কলারশিপ এর ব্যাপারে',
#  'বৃত্তি বা স্কলারশিপ এর ব্যাপারে খোঁজ',
#  'বা স্কলারশিপ এর ব্যাপারে খোঁজ নিতে',
#  'স্কলারশিপ এর ব্যাপারে খোঁজ নিতে ।',
#  'এর ব্যাপারে খোঁজ নিতে । পুরো',
#  'ব্যাপারে খোঁজ নিতে । পুরো প্রক্রিয়াটি',
#  'খোঁজ নিতে । পুরো প্রক্রিয়াটি অনেক',
#  'নিতে । পুরো প্রক্রিয়াটি অনেক বিশদ',
#  '। পুরো প্রক্রিয়াটি অনেক বিশদ হওয়ায়',
#  'পুরো প্রক্রিয়াটি অনেক বিশদ হওয়ায় আমার',
#  'প্রক্রিয়াটি অনেক বিশদ হওয়ায় আমার ক্ষুদ্র',
#  'অনেক বিশদ হওয়ায় আমার ক্ষুদ্র অভিজ্ঞতা',
#  'বিশদ হওয়ায় আমার ক্ষুদ্র অভিজ্ঞতা থেকে',
#  'হওয়ায় আমার ক্ষুদ্র অভিজ্ঞতা থেকে আমি',
#  'আমার ক্ষুদ্র অভিজ্ঞতা থেকে আমি চেষ্টা',
#  'ক্ষুদ্র অভিজ্ঞতা থেকে আমি চেষ্টা করবো',
#  'অভিজ্ঞতা থেকে আমি চেষ্টা করবো আমার',
#  'থেকে আমি চেষ্টা করবো আমার শিক্ষার্থীদের',
#  'আমি চেষ্টা করবো আমার শিক্ষার্থীদের কিছুটা',
#  'চেষ্টা করবো আমার শিক্ষার্থীদের কিছুটা জানানোর',
#  'করবো আমার শিক্ষার্থীদের কিছুটা জানানোর ।',
#  'আমার শিক্ষার্থীদের কিছুটা জানানোর । আমার',
#  'শিক্ষার্থীদের কিছুটা জানানোর । আমার লেখাটা',
#  'কিছুটা জানানোর । আমার লেখাটা টি',
#  'জানানোর । আমার লেখাটা টি পর্বে',
#  '। আমার লেখাটা টি পর্বে থাকবে',
#  'আমার লেখাটা টি পর্বে থাকবে ।',
#  'লেখাটা টি পর্বে থাকবে । আজ',
#  'টি পর্বে থাকবে । আজ প্রথম',
#  'পর্বে থাকবে । আজ প্রথম পর্ব',
#  'থাকবে । আজ প্রথম পর্ব ।',
#  '। আজ প্রথম পর্ব । আজকে',
#  'আজ প্রথম পর্ব । আজকে আমি',
#  'প্রথম পর্ব । আজকে আমি আলোচনা',
#  'পর্ব । আজকে আমি আলোচনা করবো',
#  '। আজকে আমি আলোচনা করবো বাংলাদেশি',
#  'আজকে আমি আলোচনা করবো বাংলাদেশি শিক্ষার্থীদের',
#  'আমি আলোচনা করবো বাংলাদেশি শিক্ষার্থীদের জন্য',
#  'আলোচনা করবো বাংলাদেশি শিক্ষার্থীদের জন্য বিদেশে',
#  'করবো বাংলাদেশি শিক্ষার্থীদের জন্য বিদেশে পড়তে',
#  'বাংলাদেশি শিক্ষার্থীদের জন্য বিদেশে পড়তে যাওয়ার',
#  'শিক্ষার্থীদের জন্য বিদেশে পড়তে যাওয়ার স্কলারশিপ',
#  'জন্য বিদেশে পড়তে যাওয়ার স্কলারশিপ নিয়ে',
#  'বিদেশে পড়তে যাওয়ার স্কলারশিপ নিয়ে ।',
#  'পড়তে যাওয়ার স্কলারশিপ নিয়ে । পরবর্তীতে',
#  'যাওয়ার স্কলারশিপ নিয়ে । পরবর্তীতে বিভিন্ন',
#  'স্কলারশিপ নিয়ে । পরবর্তীতে বিভিন্ন দেশে',
#  'নিয়ে । পরবর্তীতে বিভিন্ন দেশে এপ্লাই',
#  '। পরবর্তীতে বিভিন্ন দেশে এপ্লাই করার',
#  'পরবর্তীতে বিভিন্ন দেশে এপ্লাই করার প্রক্রিয়া',
#  'বিভিন্ন দেশে এপ্লাই করার প্রক্রিয়া ক্রেডিট',
#  'দেশে এপ্লাই করার প্রক্রিয়া ক্রেডিট ট্রান্সফার',
#  'এপ্লাই করার প্রক্রিয়া ক্রেডিট ট্রান্সফার বিশ্ববিদ্যালয়ের',
#  'করার প্রক্রিয়া ক্রেডিট ট্রান্সফার বিশ্ববিদ্যালয়ের ইন',
#  'প্রক্রিয়া ক্রেডিট ট্রান্সফার বিশ্ববিদ্যালয়ের ইন হাউস',
#  'ক্রেডিট ট্রান্সফার বিশ্ববিদ্যালয়ের ইন হাউস স্কলারশিপ',
#  'ট্রান্সফার বিশ্ববিদ্যালয়ের ইন হাউস স্কলারশিপ ইত্যাদি',
#  'বিশ্ববিদ্যালয়ের ইন হাউস স্কলারশিপ ইত্যাদি বিষয়ে',
#  'ইন হাউস স্কলারশিপ ইত্যাদি বিষয়ে আলোচনা',
#  'হাউস স্কলারশিপ ইত্যাদি বিষয়ে আলোচনা করবো',
#  'স্কলারশিপ ইত্যাদি বিষয়ে আলোচনা করবো ।',
#  'ইত্যাদি বিষয়ে আলোচনা করবো । যুক্তরাজ্যে',
#  'বিষয়ে আলোচনা করবো । যুক্তরাজ্যে পড়তে',
#  'আলোচনা করবো । যুক্তরাজ্যে পড়তে যাওয়ার',
#  'করবো । যুক্তরাজ্যে পড়তে যাওয়ার জন্য',
#  '। যুক্তরাজ্যে পড়তে যাওয়ার জন্য ব্রিটিশ',
#  'যুক্তরাজ্যে পড়তে যাওয়ার জন্য ব্রিটিশ সরকারের',
#  'পড়তে যাওয়ার জন্য ব্রিটিশ সরকারের বৃত্তি',
#  'যাওয়ার জন্য ব্রিটিশ সরকারের বৃত্তি এটি',
#  'জন্য ব্রিটিশ সরকারের বৃত্তি এটি ।',
#  'ব্রিটিশ সরকারের বৃত্তি এটি । অত্যন্ত',
#  'সরকারের বৃত্তি এটি । অত্যন্ত সম্মানজনক',
#  'বৃত্তি এটি । অত্যন্ত সম্মানজনক এবং',
#  'এটি । অত্যন্ত সম্মানজনক এবং সেইসাথে',
#  '। অত্যন্ত সম্মানজনক এবং সেইসাথে খুবই',
#  'অত্যন্ত সম্মানজনক এবং সেইসাথে খুবই প্রতিযোগিতামূলক',
#  'সম্মানজনক এবং সেইসাথে খুবই প্রতিযোগিতামূলক ।',
#  'এবং সেইসাথে খুবই প্রতিযোগিতামূলক । সাধারণত',
#  'সেইসাথে খুবই প্রতিযোগিতামূলক । সাধারণত যারা',
#  'খুবই প্রতিযোগিতামূলক । সাধারণত যারা শিক্ষকতা',
#  'প্রতিযোগিতামূলক । সাধারণত যারা শিক্ষকতা পেশায়',
#  '। সাধারণত যারা শিক্ষকতা পেশায় নিয়োজিত',
#  'সাধারণত যারা শিক্ষকতা পেশায় নিয়োজিত থাকেন',
#  'যারা শিক্ষকতা পেশায় নিয়োজিত থাকেন তারা',
#  'শিক্ষকতা পেশায় নিয়োজিত থাকেন তারা এটা',
#  'পেশায় নিয়োজিত থাকেন তারা এটা পেয়ে',
#  'নিয়োজিত থাকেন তারা এটা পেয়ে থাকেন',
#  'থাকেন তারা এটা পেয়ে থাকেন তবে',
#  'তারা এটা পেয়ে থাকেন তবে শিক্ষকই',
#  'এটা পেয়ে থাকেন তবে শিক্ষকই হতে',
#  'পেয়ে থাকেন তবে শিক্ষকই হতে হবে',
#  'থাকেন তবে শিক্ষকই হতে হবে এমন',
#  'তবে শিক্ষকই হতে হবে এমন কোনো',
#  'শিক্ষকই হতে হবে এমন কোনো বাধ্যবাধকতা',
#  'হতে হবে এমন কোনো বাধ্যবাধকতা নেই',
#  'হবে এমন কোনো বাধ্যবাধকতা নেই ।',
#  'এমন কোনো বাধ্যবাধকতা নেই । আপনার',
#  'কোনো বাধ্যবাধকতা নেই । আপনার বয়স',
#  'বাধ্যবাধকতা নেই । আপনার বয়স কম',
#  'নেই । আপনার বয়স কম হলে',
#  '। আপনার বয়স কম হলে এবং',
#  'আপনার বয়স কম হলে এবং আপনার',
#  'বয়স কম হলে এবং আপনার ব্যাচেলর',
#  'কম হলে এবং আপনার ব্যাচেলর ডিগ্রিতে',
#  'হলে এবং আপনার ব্যাচেলর ডিগ্রিতে নম্বর',
#  'এবং আপনার ব্যাচেলর ডিগ্রিতে নম্বর থাকলেই',
#  'আপনার ব্যাচেলর ডিগ্রিতে নম্বর থাকলেই আপনি',
#  'ব্যাচেলর ডিগ্রিতে নম্বর থাকলেই আপনি এই',
#  'ডিগ্রিতে নম্বর থাকলেই আপনি এই স্কলারশিপের',
#  'নম্বর থাকলেই আপনি এই স্কলারশিপের জন্য',
#  'থাকলেই আপনি এই স্কলারশিপের জন্য এপ্লাই',
#  'আপনি এই স্কলারশিপের জন্য এপ্লাই করতে',
#  'এই স্কলারশিপের জন্য এপ্লাই করতে পারবেন',
#  'স্কলারশিপের জন্য এপ্লাই করতে পারবেন ।',
#  'জন্য এপ্লাই করতে পারবেন । এক্ষেত্রে',
#  'এপ্লাই করতে পারবেন । এক্ষেত্রে যেটা',
#  'করতে পারবেন । এক্ষেত্রে যেটা লাগবে',
#  'পারবেন । এক্ষেত্রে যেটা লাগবে সেটা',
#  '। এক্ষেত্রে যেটা লাগবে সেটা হলো',
#  'এক্ষেত্রে যেটা লাগবে সেটা হলো যুক্তরাজ্যের',
#  'যেটা লাগবে সেটা হলো যুক্তরাজ্যের কোনো',
#  'লাগবে সেটা হলো যুক্তরাজ্যের কোনো একটি',
#  'সেটা হলো যুক্তরাজ্যের কোনো একটি বিশ্ববিদ্যালয়ে',
#  'হলো যুক্তরাজ্যের কোনো একটি বিশ্ববিদ্যালয়ে ভর্তির',
#  'যুক্তরাজ্যের কোনো একটি বিশ্ববিদ্যালয়ে ভর্তির আনকন্ডিশনাল',
#  'কোনো একটি বিশ্ববিদ্যালয়ে ভর্তির আনকন্ডিশনাল অফার',
#  'একটি বিশ্ববিদ্যালয়ে ভর্তির আনকন্ডিশনাল অফার লেটার',
#  'বিশ্ববিদ্যালয়ে ভর্তির আনকন্ডিশনাল অফার লেটার ।',
#  'ভর্তির আনকন্ডিশনাল অফার লেটার । গুগল',
#  'আনকন্ডিশনাল অফার লেটার । গুগল করলেই',
#  'অফার লেটার । গুগল করলেই লিস্ট',
#  'লেটার । গুগল করলেই লিস্ট পাবেন',
#  '। গুগল করলেই লিস্ট পাবেন ব্রিটেনের',
#  'গুগল করলেই লিস্ট পাবেন ব্রিটেনের কোন',
#  'করলেই লিস্ট পাবেন ব্রিটেনের কোন কোন',
#  'লিস্ট পাবেন ব্রিটেনের কোন কোন বিশ্ববিদ্যালয়',
#  'পাবেন ব্রিটেনের কোন কোন বিশ্ববিদ্যালয় কমনওয়েলথের',
#  'ব্রিটেনের কোন কোন বিশ্ববিদ্যালয় কমনওয়েলথের আওতায়',
#  'কোন কোন বিশ্ববিদ্যালয় কমনওয়েলথের আওতায় আছে',
#  'কোন বিশ্ববিদ্যালয় কমনওয়েলথের আওতায় আছে ।',
#  'বিশ্ববিদ্যালয় কমনওয়েলথের আওতায় আছে । তারমানে',
#  'কমনওয়েলথের আওতায় আছে । তারমানে আপনার',
#  'আওতায় আছে । তারমানে আপনার আগে',
#  'আছে । তারমানে আপনার আগে বিশ্ববিদ্যালয়ে',
#  '। তারমানে আপনার আগে বিশ্ববিদ্যালয়ে ওদের',
#  'তারমানে আপনার আগে বিশ্ববিদ্যালয়ে ওদের নিজস্ব',
#  'আপনার আগে বিশ্ববিদ্যালয়ে ওদের নিজস্ব সিস্টেমে',
#  'আগে বিশ্ববিদ্যালয়ে ওদের নিজস্ব সিস্টেমে এপ্লাই',
#  'বিশ্ববিদ্যালয়ে ওদের নিজস্ব সিস্টেমে এপ্লাই করতে',
#  'ওদের নিজস্ব সিস্টেমে এপ্লাই করতে হবে',
#  'নিজস্ব সিস্টেমে এপ্লাই করতে হবে আর',
#  'সিস্টেমে এপ্লাই করতে হবে আর অফার',
#  'এপ্লাই করতে হবে আর অফার লেটার',
#  'করতে হবে আর অফার লেটার পেলেই',
#  'হবে আর অফার লেটার পেলেই আপনি',
#  'আর অফার লেটার পেলেই আপনি কমনওয়েলথের',
#  'অফার লেটার পেলেই আপনি কমনওয়েলথের জন্য',
#  'লেটার পেলেই আপনি কমনওয়েলথের জন্য এপ্লাই',
#  'পেলেই আপনি কমনওয়েলথের জন্য এপ্লাই করতে',
#  'আপনি কমনওয়েলথের জন্য এপ্লাই করতে পারবেন',
#  'কমনওয়েলথের জন্য এপ্লাই করতে পারবেন ।',
#  'জন্য এপ্লাই করতে পারবেন । দুটোর',
#  'এপ্লাই করতে পারবেন । দুটোর ক্ষেত্রেই',
#  'করতে পারবেন । দুটোর ক্ষেত্রেই এপ্লিকেশন',
#  'পারবেন । দুটোর ক্ষেত্রেই এপ্লিকেশন প্রোসেস',
#  '। দুটোর ক্ষেত্রেই এপ্লিকেশন প্রোসেস ভিন্ন',
#  'দুটোর ক্ষেত্রেই এপ্লিকেশন প্রোসেস ভিন্ন ।',
#  'ক্ষেত্রেই এপ্লিকেশন প্রোসেস ভিন্ন । এছাড়া',
#  'এপ্লিকেশন প্রোসেস ভিন্ন । এছাড়া স্কলারশিপের',
#  'প্রোসেস ভিন্ন । এছাড়া স্কলারশিপের ক্ষেত্রেও',
#  'ভিন্ন । এছাড়া স্কলারশিপের ক্ষেত্রেও আইল্টসের',
#  '। এছাড়া স্কলারশিপের ক্ষেত্রেও আইল্টসের স্কোর',
#  'এছাড়া স্কলারশিপের ক্ষেত্রেও আইল্টসের স্কোর আপনার',
#  'স্কলারশিপের ক্ষেত্রেও আইল্টসের স্কোর আপনার জন্য',
#  'ক্ষেত্রেও আইল্টসের স্কোর আপনার জন্য একটা',
#  'আইল্টসের স্কোর আপনার জন্য একটা ফ্যাক্টর',
#  'স্কোর আপনার জন্য একটা ফ্যাক্টর হবে',
#  'আপনার জন্য একটা ফ্যাক্টর হবে ।',
#  'জন্য একটা ফ্যাক্টর হবে । কমনওয়েলথ',
#  'একটা ফ্যাক্টর হবে । কমনওয়েলথ সাধারণত',
#  'ফ্যাক্টর হবে । কমনওয়েলথ সাধারণত ওপেন',
#  'হবে । কমনওয়েলথ সাধারণত ওপেন হয়',
#  '। কমনওয়েলথ সাধারণত ওপেন হয় নভেম্বরের',
#  'কমনওয়েলথ সাধারণত ওপেন হয় নভেম্বরের দিকে',
#  'সাধারণত ওপেন হয় নভেম্বরের দিকে ।',
#  'ওপেন হয় নভেম্বরের দিকে । সময়',
#  'হয় নভেম্বরের দিকে । সময় থাকে',
#  'নভেম্বরের দিকে । সময় থাকে ২',
#  'দিকে । সময় থাকে ২ মাসের',
#  '। সময় থাকে ২ মাসের মতো',
#  'সময় থাকে ২ মাসের মতো ।',
#  'থাকে ২ মাসের মতো । এটাও',
#  '২ মাসের মতো । এটাও কমনওয়েলথের',
#  'মাসের মতো । এটাও কমনওয়েলথের মতই',
#  'মতো । এটাও কমনওয়েলথের মতই কিন্তু',
#  '। এটাও কমনওয়েলথের মতই কিন্তু এটার',
#  'এটাও কমনওয়েলথের মতই কিন্তু এটার ফাণ্ডিং',
#  'কমনওয়েলথের মতই কিন্তু এটার ফাণ্ডিং অর্ধেক',
#  'মতই কিন্তু এটার ফাণ্ডিং অর্ধেক যেই',
#  'কিন্তু এটার ফাণ্ডিং অর্ধেক যেই বিশ্ববিদ্যালয়',
#  'এটার ফাণ্ডিং অর্ধেক যেই বিশ্ববিদ্যালয় এফিলিয়েটেড',
#  'ফাণ্ডিং অর্ধেক যেই বিশ্ববিদ্যালয় এফিলিয়েটেড সেটা',
#  'অর্ধেক যেই বিশ্ববিদ্যালয় এফিলিয়েটেড সেটা দিবে',
#  'যেই বিশ্ববিদ্যালয় এফিলিয়েটেড সেটা দিবে আর',
#  'বিশ্ববিদ্যালয় এফিলিয়েটেড সেটা দিবে আর বাকি',
#  'এফিলিয়েটেড সেটা দিবে আর বাকি অর্ধেক',
#  'সেটা দিবে আর বাকি অর্ধেক দিবে',
#  'দিবে আর বাকি অর্ধেক দিবে কমনওয়েলথ',
#  'আর বাকি অর্ধেক দিবে কমনওয়েলথ স্কলারশিপ',
#  'বাকি অর্ধেক দিবে কমনওয়েলথ স্কলারশিপ কমিটি',
#  'অর্ধেক দিবে কমনওয়েলথ স্কলারশিপ কমিটি ।',
#  'দিবে কমনওয়েলথ স্কলারশিপ কমিটি । বাকিসব',
#  'কমনওয়েলথ স্কলারশিপ কমিটি । বাকিসব ক্রাইটেরিয়া',
#  'স্কলারশিপ কমিটি । বাকিসব ক্রাইটেরিয়া একই',
#  'কমিটি । বাকিসব ক্রাইটেরিয়া একই ।',
#  '। বাকিসব ক্রাইটেরিয়া একই । তবে',
#  'বাকিসব ক্রাইটেরিয়া একই । তবে বিশ্ববিদ্যালয়ের',
#  'ক্রাইটেরিয়া একই । তবে বিশ্ববিদ্যালয়ের একটা',
#  'একই । তবে বিশ্ববিদ্যালয়ের একটা তালিকা',
#  '। তবে বিশ্ববিদ্যালয়ের একটা তালিকা থাকে',
#  'তবে বিশ্ববিদ্যালয়ের একটা তালিকা থাকে যে',
#  'বিশ্ববিদ্যালয়ের একটা তালিকা থাকে যে কোন',
#  'একটা তালিকা থাকে যে কোন কোন',
#  'তালিকা থাকে যে কোন কোন বিশ্ববিদ্যালয়',
#  'থাকে যে কোন কোন বিশ্ববিদ্যালয় এই',
#  'যে কোন কোন বিশ্ববিদ্যালয় এই শেয়ারড',
#  'কোন কোন বিশ্ববিদ্যালয় এই শেয়ারড প্রোগ্রামের',
#  'কোন বিশ্ববিদ্যালয় এই শেয়ারড প্রোগ্রামের আওতায়',
#  'বিশ্ববিদ্যালয় এই শেয়ারড প্রোগ্রামের আওতায় ।',
#  'এই শেয়ারড প্রোগ্রামের আওতায় । যুক্তরাজ্যে',
#  'শেয়ারড প্রোগ্রামের আওতায় । যুক্তরাজ্যে পড়তে',
#  'প্রোগ্রামের আওতায় । যুক্তরাজ্যে পড়তে যাওয়ার',
#  'আওতায় । যুক্তরাজ্যে পড়তে যাওয়ার জন্য',
#  '। যুক্তরাজ্যে পড়তে যাওয়ার জন্য ব্রিটিশ',
#  'যুক্তরাজ্যে পড়তে যাওয়ার জন্য ব্রিটিশ সরকারের',
#  'পড়তে যাওয়ার জন্য ব্রিটিশ সরকারের বৃত্তি',
#  'যাওয়ার জন্য ব্রিটিশ সরকারের বৃত্তি ।',
#  'জন্য ব্রিটিশ সরকারের বৃত্তি । সাধারণত',
#  'ব্রিটিশ সরকারের বৃত্তি । সাধারণত এনজিও',
#  'সরকারের বৃত্তি । সাধারণত এনজিও কর্মী',
#  'বৃত্তি । সাধারণত এনজিও কর্মী সরকারী',
#  '। সাধারণত এনজিও কর্মী সরকারী চাকুরে',
#  'সাধারণত এনজিও কর্মী সরকারী চাকুরে বাংলাদেশ',
#  'এনজিও কর্মী সরকারী চাকুরে বাংলাদেশ ব্যাংকের',
#  'কর্মী সরকারী চাকুরে বাংলাদেশ ব্যাংকের কর্মকর্তা',
#  'সরকারী চাকুরে বাংলাদেশ ব্যাংকের কর্মকর্তা উদ্যোক্তা',
#  'চাকুরে বাংলাদেশ ব্যাংকের কর্মকর্তা উদ্যোক্তা এদের',
#  'বাংলাদেশ ব্যাংকের কর্মকর্তা উদ্যোক্তা এদের জন্য',
#  'ব্যাংকের কর্মকর্তা উদ্যোক্তা এদের জন্য এই',
#  'কর্মকর্তা উদ্যোক্তা এদের জন্য এই বৃত্তি',
#  'উদ্যোক্তা এদের জন্য এই বৃত্তি ।',
#  'এদের জন্য এই বৃত্তি । আপনার',
#  'জন্য এই বৃত্তি । আপনার চাকরি',
#  'এই বৃত্তি । আপনার চাকরি যদি',
#  'বৃত্তি । আপনার চাকরি যদি দুই',
#  '। আপনার চাকরি যদি দুই বছর',
#  'আপনার চাকরি যদি দুই বছর হয়',
#  'চাকরি যদি দুই বছর হয় তাহলে',
#  'যদি দুই বছর হয় তাহলে এটার',
#  'দুই বছর হয় তাহলে এটার জন্য',
#  'বছর হয় তাহলে এটার জন্য এপ্লাই',
#  'হয় তাহলে এটার জন্য এপ্লাই করতে',
#  'তাহলে এটার জন্য এপ্লাই করতে পারবেন',
#  'এটার জন্য এপ্লাই করতে পারবেন ।',
#  'জন্য এপ্লাই করতে পারবেন । ক্রাইটেরিয়া',
#  'এপ্লাই করতে পারবেন । ক্রাইটেরিয়া একই',
#  'করতে পারবেন । ক্রাইটেরিয়া একই রকম',
#  'পারবেন । ক্রাইটেরিয়া একই রকম ।',
#  '। ক্রাইটেরিয়া একই রকম । আইল্টসে',
#  'ক্রাইটেরিয়া একই রকম । আইল্টসে ভালো',
#  'একই রকম । আইল্টসে ভালো স্কোর',
#  'রকম । আইল্টসে ভালো স্কোর আর',
#  '। আইল্টসে ভালো স্কোর আর ইউকের',
#  'আইল্টসে ভালো স্কোর আর ইউকের বিশ্ববিদ্যালয়',
#  'ভালো স্কোর আর ইউকের বিশ্ববিদ্যালয় থেকে',
#  'স্কোর আর ইউকের বিশ্ববিদ্যালয় থেকে আনকন্ডিশনাল',
#  'আর ইউকের বিশ্ববিদ্যালয় থেকে আনকন্ডিশনাল অফার',
#  'ইউকের বিশ্ববিদ্যালয় থেকে আনকন্ডিশনাল অফার লেটার',
#  'বিশ্ববিদ্যালয় থেকে আনকন্ডিশনাল অফার লেটার লাগবে',
#  'থেকে আনকন্ডিশনাল অফার লেটার লাগবে ।',
#  'আনকন্ডিশনাল অফার লেটার লাগবে । মার্কিন',
#  'অফার লেটার লাগবে । মার্কিন সরকারের',
#  'লেটার লাগবে । মার্কিন সরকারের বৃত্তি',
#  'লাগবে । মার্কিন সরকারের বৃত্তি ।',
#  '। মার্কিন সরকারের বৃত্তি । দারুণ',
#  'মার্কিন সরকারের বৃত্তি । দারুণ প্রেস্টিজিয়াস',
#  'সরকারের বৃত্তি । দারুণ প্রেস্টিজিয়াস এবং',
#  'বৃত্তি । দারুণ প্রেস্টিজিয়াস এবং আর্থিক',
#  '। দারুণ প্রেস্টিজিয়াস এবং আর্থিক দিক',
#  'দারুণ প্রেস্টিজিয়াস এবং আর্থিক দিক থেকেও',
#  'প্রেস্টিজিয়াস এবং আর্থিক দিক থেকেও বেশ',
#  'এবং আর্থিক দিক থেকেও বেশ লাভজনক',
#  'আর্থিক দিক থেকেও বেশ লাভজনক ।',
#  'দিক থেকেও বেশ লাভজনক । মূল',
#  'থেকেও বেশ লাভজনক । মূল বৃত্তিটির',
#  'বেশ লাভজনক । মূল বৃত্তিটির নাম',
#  'লাভজনক । মূল বৃত্তিটির নাম হলো',
#  '। মূল বৃত্তিটির নাম হলো ফুলব্রাইট',
#  'মূল বৃত্তিটির নাম হলো ফুলব্রাইট ফরেন',
#  'বৃত্তিটির নাম হলো ফুলব্রাইট ফরেন স্টুডেন্ট',
#  'নাম হলো ফুলব্রাইট ফরেন স্টুডেন্ট প্রোগ্রাম',
#  'হলো ফুলব্রাইট ফরেন স্টুডেন্ট প্রোগ্রাম ।',
#  'ফুলব্রাইট ফরেন স্টুডেন্ট প্রোগ্রাম । এটার',
#  'ফরেন স্টুডেন্ট প্রোগ্রাম । এটার ক্ষেত্রে',
#  'স্টুডেন্ট প্রোগ্রাম । এটার ক্ষেত্রে আলাদাভাবে',
#  'প্রোগ্রাম । এটার ক্ষেত্রে আলাদাভাবে কোনো',
#  '। এটার ক্ষেত্রে আলাদাভাবে কোনো বিশ্ববিদ্যালয়ে',
#  'এটার ক্ষেত্রে আলাদাভাবে কোনো বিশ্ববিদ্যালয়ে এপ্লাই',
#  'ক্ষেত্রে আলাদাভাবে কোনো বিশ্ববিদ্যালয়ে এপ্লাই করতে',
#  'আলাদাভাবে কোনো বিশ্ববিদ্যালয়ে এপ্লাই করতে হবেনা',
#  'কোনো বিশ্ববিদ্যালয়ে এপ্লাই করতে হবেনা ।',
#  'বিশ্ববিদ্যালয়ে এপ্লাই করতে হবেনা । ফুলব্রাইটে',
#  'এপ্লাই করতে হবেনা । ফুলব্রাইটে এপ্লাই',
#  'করতে হবেনা । ফুলব্রাইটে এপ্লাই করলেই',
#  'হবেনা । ফুলব্রাইটে এপ্লাই করলেই হবে',
#  '। ফুলব্রাইটে এপ্লাই করলেই হবে ।',
#  'ফুলব্রাইটে এপ্লাই করলেই হবে । যদি',
#  'এপ্লাই করলেই হবে । যদি আপনি',
#  'করলেই হবে । যদি আপনি বৃত্তির',
#  'হবে । যদি আপনি বৃত্তির জন্য',
#  '। যদি আপনি বৃত্তির জন্য মনোনীত',
#  'যদি আপনি বৃত্তির জন্য মনোনীত হোন',
#  'আপনি বৃত্তির জন্য মনোনীত হোন তাহলে',
#  'বৃত্তির জন্য মনোনীত হোন তাহলে তারাই',
#  'জন্য মনোনীত হোন তাহলে তারাই আপনাকে',
#  'মনোনীত হোন তাহলে তারাই আপনাকে বিশ্ববিদ্যালয়',
#  'হোন তাহলে তারাই আপনাকে বিশ্ববিদ্যালয় নির্ধারণ',
#  'তাহলে তারাই আপনাকে বিশ্ববিদ্যালয় নির্ধারণ করে',
#  'তারাই আপনাকে বিশ্ববিদ্যালয় নির্ধারণ করে দিবে',
#  'আপনাকে বিশ্ববিদ্যালয় নির্ধারণ করে দিবে ।',
#  'বিশ্ববিদ্যালয় নির্ধারণ করে দিবে । ইয়োরোপ',
#  'নির্ধারণ করে দিবে । ইয়োরোপ ঘুরে',
#  'করে দিবে । ইয়োরোপ ঘুরে বেড়ানোর',
#  'দিবে । ইয়োরোপ ঘুরে বেড়ানোর জন্য',
#  '। ইয়োরোপ ঘুরে বেড়ানোর জন্য এর',
#  'ইয়োরোপ ঘুরে বেড়ানোর জন্য এর চাইতে',
#  'ঘুরে বেড়ানোর জন্য এর চাইতে ভালো',
#  'বেড়ানোর জন্য এর চাইতে ভালো স্কলারশিপ',
#  'জন্য এর চাইতে ভালো স্কলারশিপ আর',
#  'এর চাইতে ভালো স্কলারশিপ আর হয়না',
#  'চাইতে ভালো স্কলারশিপ আর হয়না ।',
#  'ভালো স্কলারশিপ আর হয়না । বিশেষ',
#  'স্কলারশিপ আর হয়না । বিশেষ করে',
#  'আর হয়না । বিশেষ করে সায়েন্স',
#  'হয়না । বিশেষ করে সায়েন্স এন্ড',
#  '। বিশেষ করে সায়েন্স এন্ড টেকনোলজিতে',
#  'বিশেষ করে সায়েন্স এন্ড টেকনোলজিতে যারা',
#  'করে সায়েন্স এন্ড টেকনোলজিতে যারা পড়ছেন',
#  'সায়েন্স এন্ড টেকনোলজিতে যারা পড়ছেন তাদের',
#  'এন্ড টেকনোলজিতে যারা পড়ছেন তাদের জন্য',
#  'টেকনোলজিতে যারা পড়ছেন তাদের জন্য এটা',
#  'যারা পড়ছেন তাদের জন্য এটা বেশ',
#  'পড়ছেন তাদের জন্য এটা বেশ লিউক্রেটিভ',
#  'তাদের জন্য এটা বেশ লিউক্রেটিভ ।',
#  'জন্য এটা বেশ লিউক্রেটিভ । সিজিপিএ',
#  'এটা বেশ লিউক্রেটিভ । সিজিপিএ ভালো',
#  'বেশ লিউক্রেটিভ । সিজিপিএ ভালো থাকা',
#  'লিউক্রেটিভ । সিজিপিএ ভালো থাকা লাগবে',
#  '। সিজিপিএ ভালো থাকা লাগবে ।',
#  'সিজিপিএ ভালো থাকা লাগবে । এই',
#  'ভালো থাকা লাগবে । এই স্কলারশিপের',
#  'থাকা লাগবে । এই স্কলারশিপের মজা',
#  'লাগবে । এই স্কলারশিপের মজা হলো',
#  '। এই স্কলারশিপের মজা হলো ওরা',
#  'এই স্কলারশিপের মজা হলো ওরা আ',
#  'স্কলারশিপের মজা হলো ওরা আ পনাকে',
#  'মজা হলো ওরা আ পনাকে ইয়োরোপের',
#  'হলো ওরা আ পনাকে ইয়োরোপের দুটো',
#  'ওরা আ পনাকে ইয়োরোপের দুটো দেশের',
#  'আ পনাকে ইয়োরোপের দুটো দেশের দুই',
#  'পনাকে ইয়োরোপের দুটো দেশের দুই বিশ্ববিদ্যালয়ে',
#  'ইয়োরোপের দুটো দেশের দুই বিশ্ববিদ্যালয়ে যৌথভাবে',
#  'দুটো দেশের দুই বিশ্ববিদ্যালয়ে যৌথভাবে দুই',
#  'দেশের দুই বিশ্ববিদ্যালয়ে যৌথভাবে দুই বছরের',
#  'দুই বিশ্ববিদ্যালয়ে যৌথভাবে দুই বছরের মাস্টার্স',
#  'বিশ্ববিদ্যালয়ে যৌথভাবে দুই বছরের মাস্টার্স ডিগ্রি',
#  'যৌথভাবে দুই বছরের মাস্টার্স ডিগ্রি করাবে',
#  'দুই বছরের মাস্টার্স ডিগ্রি করাবে ।',
#  'বছরের মাস্টার্স ডিগ্রি করাবে । বৃত্তির',
#  'মাস্টার্স ডিগ্রি করাবে । বৃত্তির পরিমাণ',
#  'ডিগ্রি করাবে । বৃত্তির পরিমাণ বেশ',
#  'করাবে । বৃত্তির পরিমাণ বেশ ভালো',
#  '। বৃত্তির পরিমাণ বেশ ভালো ।',
#  'বৃত্তির পরিমাণ বেশ ভালো । কোনো',
#  'পরিমাণ বেশ ভালো । কোনো চাকরির',
#  'বেশ ভালো । কোনো চাকরির অভিজ্ঞতা',
#  'ভালো । কোনো চাকরির অভিজ্ঞতা লাগবেনা',
#  '। কোনো চাকরির অভিজ্ঞতা লাগবেনা ।',
#  'কোনো চাকরির অভিজ্ঞতা লাগবেনা । বিশ্বের',
#  'চাকরির অভিজ্ঞতা লাগবেনা । বিশ্বের যেকোনো',
#  'অভিজ্ঞতা লাগবেনা । বিশ্বের যেকোনো বিশ্ববিদ্যালয়',
#  'লাগবেনা । বিশ্বের যেকোনো বিশ্ববিদ্যালয় থেকে',
#  '। বিশ্বের যেকোনো বিশ্ববিদ্যালয় থেকে আপনি',
#  'বিশ্বের যেকোনো বিশ্ববিদ্যালয় থেকে আপনি আনকন্ডিশনাল',
#  'যেকোনো বিশ্ববিদ্যালয় থেকে আপনি আনকন্ডিশনাল অফার',
#  'বিশ্ববিদ্যালয় থেকে আপনি আনকন্ডিশনাল অফার লেটার',
#  'থেকে আপনি আনকন্ডিশনাল অফার লেটার পেলে',
#  'আপনি আনকন্ডিশনাল অফার লেটার পেলে আপনি',
#  'আনকন্ডিশনাল অফার লেটার পেলে আপনি এটায়',
#  'অফার লেটার পেলে আপনি এটায় এপ্লাই',
#  'লেটার পেলে আপনি এটায় এপ্লাই করতে',
#  'পেলে আপনি এটায় এপ্লাই করতে পারবেন',
#  'আপনি এটায় এপ্লাই করতে পারবেন ।',
#  'এটায় এপ্লাই করতে পারবেন । আইল্টস',
#  'এপ্লাই করতে পারবেন । আইল্টস দেওয়া',
#  'করতে পারবেন । আইল্টস দেওয়া লাগবে',
#  'পারবেন । আইল্টস দেওয়া লাগবে ।',
#  '। আইল্টস দেওয়া লাগবে । বিশ্ববিদ্যালয়',
#  'আইল্টস দেওয়া লাগবে । বিশ্ববিদ্যালয় অফার',
#  'দেওয়া লাগবে । বিশ্ববিদ্যালয় অফার পাওয়ার',
#  'লাগবে । বিশ্ববিদ্যালয় অফার পাওয়ার পর',
#  '। বিশ্ববিদ্যালয় অফার পাওয়ার পর আলদাভাবে',
#  'বিশ্ববিদ্যালয় অফার পাওয়ার পর আলদাভাবে এপ্লাই',
#  'অফার পাওয়ার পর আলদাভাবে এপ্লাই করতে',
#  'পাওয়ার পর আলদাভাবে এপ্লাই করতে হবে',
#  'পর আলদাভাবে এপ্লাই করতে হবে ।',
#  'আলদাভাবে এপ্লাই করতে হবে । সাধারণত',
#  'এপ্লাই করতে হবে । সাধারণত জানুয়ারি',
#  'করতে হবে । সাধারণত জানুয়ারি ফেব্রুয়ারিতে',
#  'হবে । সাধারণত জানুয়ারি ফেব্রুয়ারিতে ওপেন',
#  '। সাধারণত জানুয়ারি ফেব্রুয়ারিতে ওপেন হয়ে',
#  'সাধারণত জানুয়ারি ফেব্রুয়ারিতে ওপেন হয়ে এপ্রিল',
#  'জানুয়ারি ফেব্রুয়ারিতে ওপেন হয়ে এপ্রিল পর্যন্ত',
#  'ফেব্রুয়ারিতে ওপেন হয়ে এপ্রিল পর্যন্ত সময়',
#  'ওপেন হয়ে এপ্রিল পর্যন্ত সময় থাকে',
#  'হয়ে এপ্রিল পর্যন্ত সময় থাকে ।',
#  'এপ্রিল পর্যন্ত সময় থাকে । বিশ্বের',
#  'পর্যন্ত সময় থাকে । বিশ্বের ভালো',
#  'সময় থাকে । বিশ্বের ভালো র\u200d্যাংকের',
#  'থাকে । বিশ্বের ভালো র\u200d্যাংকের বিশ্ববিদ্যালয়ে',
#  '। বিশ্বের ভালো র\u200d্যাংকের বিশ্ববিদ্যালয়ে ভর্তি',
#  'বিশ্বের ভালো র\u200d্যাংকের বিশ্ববিদ্যালয়ে ভর্তি হয়ে',
#  'ভালো র\u200d্যাংকের বিশ্ববিদ্যালয়ে ভর্তি হয়ে অফার',
#  'র\u200d্যাংকের বিশ্ববিদ্যালয়ে ভর্তি হয়ে অফার লেটার',
#  'বিশ্ববিদ্যালয়ে ভর্তি হয়ে অফার লেটার নিয়ে',
#  'ভর্তি হয়ে অফার লেটার নিয়ে এই',
#  'হয়ে অফার লেটার নিয়ে এই স্কলারশিপে',
#  'অফার লেটার নিয়ে এই স্কলারশিপে এপ্লাই',
#  'লেটার নিয়ে এই স্কলারশিপে এপ্লাই করতে',
#  'নিয়ে এই স্কলারশিপে এপ্লাই করতে হয়',
#  'এই স্কলারশিপে এপ্লাই করতে হয় ।',
#  'স্কলারশিপে এপ্লাই করতে হয় । সাধারণত',
#  'এপ্লাই করতে হয় । সাধারণত উন্নয়ন',
#  'করতে হয় । সাধারণত উন্নয়ন বিষয়ক',
#  'হয় । সাধারণত উন্নয়ন বিষয়ক পড়ালেখার',
#  '। সাধারণত উন্নয়ন বিষয়ক পড়ালেখার জন্য',
#  'সাধারণত উন্নয়ন বিষয়ক পড়ালেখার জন্য এই',
#  'উন্নয়ন বিষয়ক পড়ালেখার জন্য এই বৃত্তি',
#  'বিষয়ক পড়ালেখার জন্য এই বৃত্তি দেওয়া',
#  'পড়ালেখার জন্য এই বৃত্তি দেওয়া হয়',
#  'জন্য এই বৃত্তি দেওয়া হয় ।',
#  'এই বৃত্তি দেওয়া হয় । দারুণ',
#  'বৃত্তি দেওয়া হয় । দারুণ একটা',
#  'দেওয়া হয় । দারুণ একটা সিভি',
#  'হয় । দারুণ একটা সিভি লাগবে',
#  '। দারুণ একটা সিভি লাগবে ।',
#  'দারুণ একটা সিভি লাগবে । ফরম্যাট',
#  'একটা সিভি লাগবে । ফরম্যাট অনেকেই',
#  'সিভি লাগবে । ফরম্যাট অনেকেই দিয়ে',
#  'লাগবে । ফরম্যাট অনেকেই দিয়ে দেয়',
#  '। ফরম্যাট অনেকেই দিয়ে দেয় যেমন',
#  'ফরম্যাট অনেকেই দিয়ে দেয় যেমন ইরেসমাসে',
#  'অনেকেই দিয়ে দেয় যেমন ইরেসমাসে আপনাকে',
#  'দিয়ে দেয় যেমন ইরেসমাসে আপনাকে সিভি',
#  'দেয় যেমন ইরেসমাসে আপনাকে সিভি ফরম্যাট',
#  'যেমন ইরেসমাসে আপনাকে সিভি ফরম্যাট ওরাই',
#  'ইরেসমাসে আপনাকে সিভি ফরম্যাট ওরাই দিয়ে',
#  'আপনাকে সিভি ফরম্যাট ওরাই দিয়ে দিবে',
#  'সিভি ফরম্যাট ওরাই দিয়ে দিবে ।',
#  'ফরম্যাট ওরাই দিয়ে দিবে । বাকিগুলোর',
#  'ওরাই দিয়ে দিবে । বাকিগুলোর ক্ষেত্রে',
#  'দিয়ে দিবে । বাকিগুলোর ক্ষেত্রে সিভি',
#  'দিবে । বাকিগুলোর ক্ষেত্রে সিভি হবে',
#  '। বাকিগুলোর ক্ষেত্রে সিভি হবে সিম্পল',
#  'বাকিগুলোর ক্ষেত্রে সিভি হবে সিম্পল কিন্তু',
#  'ক্ষেত্রে সিভি হবে সিম্পল কিন্তু বেশ',
#  'সিভি হবে সিম্পল কিন্তু বেশ ঝকঝকে',
#  'হবে সিম্পল কিন্তু বেশ ঝকঝকে ।',
#  'সিম্পল কিন্তু বেশ ঝকঝকে । মিথ্যা',
#  'কিন্তু বেশ ঝকঝকে । মিথ্যা কোনো',
#  'বেশ ঝকঝকে । মিথ্যা কোনো ইনফরমেশন',
#  'ঝকঝকে । মিথ্যা কোনো ইনফরমেশন দেওয়া',
#  '। মিথ্যা কোনো ইনফরমেশন দেওয়া যাবেনা',
#  'মিথ্যা কোনো ইনফরমেশন দেওয়া যাবেনা ।',
#  'কোনো ইনফরমেশন দেওয়া যাবেনা । আপনার',
#  'ইনফরমেশন দেওয়া যাবেনা । আপনার বিশ্ববিদ্যালয়ের',
#  'দেওয়া যাবেনা । আপনার বিশ্ববিদ্যালয়ের থিসিস',
#  'যাবেনা । আপনার বিশ্ববিদ্যালয়ের থিসিস সুপারভাইজর',
#  '। আপনার বিশ্ববিদ্যালয়ের থিসিস সুপারভাইজর বা',
#  'আপনার বিশ্ববিদ্যালয়ের থিসিস সুপারভাইজর বা শিক্ষক',
#  'বিশ্ববিদ্যালয়ের থিসিস সুপারভাইজর বা শিক্ষক বা',
#  'থিসিস সুপারভাইজর বা শিক্ষক বা আপনার',
#  'সুপারভাইজর বা শিক্ষক বা আপনার কর্মক্ষেত্রের',
#  'বা শিক্ষক বা আপনার কর্মক্ষেত্রের বস',
#  'শিক্ষক বা আপনার কর্মক্ষেত্রের বস থেকে',
#  'বা আপনার কর্মক্ষেত্রের বস থেকে আপনার',
#  'আপনার কর্মক্ষেত্রের বস থেকে আপনার দুটো',
#  'কর্মক্ষেত্রের বস থেকে আপনার দুটো রেফারেন্স',
#  'বস থেকে আপনার দুটো রেফারেন্স লেটার',
#  'থেকে আপনার দুটো রেফারেন্স লেটার লাগবে',
#  'আপনার দুটো রেফারেন্স লেটার লাগবে ।',
#  'দুটো রেফারেন্স লেটার লাগবে । এ',
#  'রেফারেন্স লেটার লাগবে । এ ক্ষেত্রে',
#  'লেটার লাগবে । এ ক্ষেত্রে যে',
#  'লাগবে । এ ক্ষেত্রে যে আপনাকে',
#  '। এ ক্ষেত্রে যে আপনাকে রেফারেন্স',
#  'এ ক্ষেত্রে যে আপনাকে রেফারেন্স দিবে',
#  'ক্ষেত্রে যে আপনাকে রেফারেন্স দিবে অর্থাৎ',
#  'যে আপনাকে রেফারেন্স দিবে অর্থাৎ রেফারির',
#  'আপনাকে রেফারেন্স দিবে অর্থাৎ রেফারির যোগ্যতাও',
#  'রেফারেন্স দিবে অর্থাৎ রেফারির যোগ্যতাও সেই',
#  'দিবে অর্থাৎ রেফারির যোগ্যতাও সেই লেভেলের',
#  'অর্থাৎ রেফারির যোগ্যতাও সেই লেভেলের হতে',
#  'রেফারির যোগ্যতাও সেই লেভেলের হতে হবে',
#  'যোগ্যতাও সেই লেভেলের হতে হবে ।',
#  'সেই লেভেলের হতে হবে । সে',
#  'লেভেলের হতে হবে । সে আপনার',
#  'হতে হবে । সে আপনার যোগ্যতা',
#  'হবে । সে আপনার যোগ্যতা দুর্বলতা',
#  '। সে আপনার যোগ্যতা দুর্বলতা এবং',
#  'সে আপনার যোগ্যতা দুর্বলতা এবং পোটেনশিয়াল',
#  'আপনার যোগ্যতা দুর্বলতা এবং পোটেনশিয়াল সম্পর্কে',
#  'যোগ্যতা দুর্বলতা এবং পোটেনশিয়াল সম্পর্কে জানবে',
#  'দুর্বলতা এবং পোটেনশিয়াল সম্পর্কে জানবে ।',
#  'এবং পোটেনশিয়াল সম্পর্কে জানবে । কাজেই',
#  'পোটেনশিয়াল সম্পর্কে জানবে । কাজেই রেফারি',
#  'সম্পর্কে জানবে । কাজেই রেফারি নির্বাচনের',
#  'জানবে । কাজেই রেফারি নির্বাচনের ক্ষেত্রে',
#  '। কাজেই রেফারি নির্বাচনের ক্ষেত্রে সতর্ক',
#  'কাজেই রেফারি নির্বাচনের ক্ষেত্রে সতর্ক হোন',
#  'রেফারি নির্বাচনের ক্ষেত্রে সতর্ক হোন এবং',
#  'নির্বাচনের ক্ষেত্রে সতর্ক হোন এবং আগে',
#  'ক্ষেত্রে সতর্ক হোন এবং আগে থেকেই',
#  'সতর্ক হোন এবং আগে থেকেই সুসম্পর্ক',
#  'হোন এবং আগে থেকেই সুসম্পর্ক বজায়',
#  'এবং আগে থেকেই সুসম্পর্ক বজায় রাখুন',
#  'আগে থেকেই সুসম্পর্ক বজায় রাখুন ।',
#  'থেকেই সুসম্পর্ক বজায় রাখুন । নিজের',
#  'সুসম্পর্ক বজায় রাখুন । নিজের যোগ্যতা',
#  'বজায় রাখুন । নিজের যোগ্যতা দিয়ে',
#  'রাখুন । নিজের যোগ্যতা দিয়ে সুসম্পর্ক',
#  '। নিজের যোগ্যতা দিয়ে সুসম্পর্ক বজায়',
#  'নিজের যোগ্যতা দিয়ে সুসম্পর্ক বজায় রাখবেন',
#  'যোগ্যতা দিয়ে সুসম্পর্ক বজায় রাখবেন ।',
#  'দিয়ে সুসম্পর্ক বজায় রাখবেন । মাথায়',
#  'সুসম্পর্ক বজায় রাখবেন । মাথায় রাখবেন',
#  'বজায় রাখবেন । মাথায় রাখবেন আপনাকে',
#  'রাখবেন । মাথায় রাখবেন আপনাকে কেউ',
#  '। মাথায় রাখবেন আপনাকে কেউ কিছু',
#  'মাথায় রাখবেন আপনাকে কেউ কিছু মুখে',
#  'রাখবেন আপনাকে কেউ কিছু মুখে তুলে',
#  'আপনাকে কেউ কিছু মুখে তুলে খাওয়াবে',
#  'কেউ কিছু মুখে তুলে খাওয়াবে না',
#  'কিছু মুখে তুলে খাওয়াবে না ।',
#  'মুখে তুলে খাওয়াবে না । কষ্ট',
#  'তুলে খাওয়াবে না । কষ্ট করতে',
#  'খাওয়াবে না । কষ্ট করতে হবে',
#  'না । কষ্ট করতে হবে ।',
#  '। কষ্ট করতে হবে । নিজের',
#  'কষ্ট করতে হবে । নিজের সাথে',
#  'করতে হবে । নিজের সাথে প্রতিযোগিতা',
#  'হবে । নিজের সাথে প্রতিযোগিতা করতে',
#  '। নিজের সাথে প্রতিযোগিতা করতে হবে',
#  'নিজের সাথে প্রতিযোগিতা করতে হবে ।',
#  'সাথে প্রতিযোগিতা করতে হবে । জেলা',
#  'প্রতিযোগিতা করতে হবে । জেলা প্রশাসনের',
#  'করতে হবে । জেলা প্রশাসনের একজন',
#  'হবে । জেলা প্রশাসনের একজন এক্সিকিউটিভ',
#  '। জেলা প্রশাসনের একজন এক্সিকিউটিভ ম্যাজিস্ট্রেটকে',
#  'জেলা প্রশাসনের একজন এক্সিকিউটিভ ম্যাজিস্ট্রেটকে এই',
#  'প্রশাসনের একজন এক্সিকিউটিভ ম্যাজিস্ট্রেটকে এই দায়িত্ব',
#  'একজন এক্সিকিউটিভ ম্যাজিস্ট্রেটকে এই দায়িত্ব দেওয়া',
#  'এক্সিকিউটিভ ম্যাজিস্ট্রেটকে এই দায়িত্ব দেওয়া হয়',
#  'ম্যাজিস্ট্রেটকে এই দায়িত্ব দেওয়া হয় ।',
#  'এই দায়িত্ব দেওয়া হয় । এনডিসির',
#  'দায়িত্ব দেওয়া হয় । এনডিসির কাজ',
#  'দেওয়া হয় । এনডিসির কাজ হলো',
#  'হয় । এনডিসির কাজ হলো মূলত',
#  '। এনডিসির কাজ হলো মূলত জেলা',
#  'এনডিসির কাজ হলো মূলত জেলা প্রশাসন',
#  'কাজ হলো মূলত জেলা প্রশাসন এবং',
#  'হলো মূলত জেলা প্রশাসন এবং জেলা',
#  'মূলত জেলা প্রশাসন এবং জেলা সংশ্লিষ্ট',
#  'জেলা প্রশাসন এবং জেলা সংশ্লিষ্ট সকল',
#  'প্রশাসন এবং জেলা সংশ্লিষ্ট সকল সরকারি',
#  'এবং জেলা সংশ্লিষ্ট সকল সরকারি বিষয়ে',
#  'জেলা সংশ্লিষ্ট সকল সরকারি বিষয়ে লজিস্টিকস',
#  'সংশ্লিষ্ট সকল সরকারি বিষয়ে লজিস্টিকস সাপোর্ট',
#  'সকল সরকারি বিষয়ে লজিস্টিকস সাপোর্ট দেওয়া',
#  'সরকারি বিষয়ে লজিস্টিকস সাপোর্ট দেওয়া ।',
#  'বিষয়ে লজিস্টিকস সাপোর্ট দেওয়া । যেমন',
#  'লজিস্টিকস সাপোর্ট দেওয়া । যেমন জেলায়',
#  'সাপোর্ট দেওয়া । যেমন জেলায় কোনো',
#  'দেওয়া । যেমন জেলায় কোনো ভিআইপি',
#  '। যেমন জেলায় কোনো ভিআইপি আসলে',
#  'যেমন জেলায় কোনো ভিআইপি আসলে যথাযোগ্যভাবে',
#  'জেলায় কোনো ভিআইপি আসলে যথাযোগ্যভাবে তার',
#  'কোনো ভিআইপি আসলে যথাযোগ্যভাবে তার আবাসন',
#  'ভিআইপি আসলে যথাযোগ্যভাবে তার আবাসন ও',
#  'আসলে যথাযোগ্যভাবে তার আবাসন ও পরিবহন',
#  'যথাযোগ্যভাবে তার আবাসন ও পরিবহন নিশ্চিত',
#  'তার আবাসন ও পরিবহন নিশ্চিত করা',
#  'আবাসন ও পরিবহন নিশ্চিত করা ।',
#  'ও পরিবহন নিশ্চিত করা । তার',
#  'পরিবহন নিশ্চিত করা । তার সফরসঙ্গীদের',
#  'নিশ্চিত করা । তার সফরসঙ্গীদের আবাসন',
#  'করা । তার সফরসঙ্গীদের আবাসন আহার',
#  '। তার সফরসঙ্গীদের আবাসন আহার ইত্যাদি',
#  'তার সফরসঙ্গীদের আবাসন আহার ইত্যাদি নিশ্চিত',
#  'সফরসঙ্গীদের আবাসন আহার ইত্যাদি নিশ্চিত করা',
#  'আবাসন আহার ইত্যাদি নিশ্চিত করা এবং',
#  'আহার ইত্যাদি নিশ্চিত করা এবং জেলার',
#  'ইত্যাদি নিশ্চিত করা এবং জেলার পরিবহন',
#  'নিশ্চিত করা এবং জেলার পরিবহন পুলের',
#  'করা এবং জেলার পরিবহন পুলের গাড়ি',
#  'এবং জেলার পরিবহন পুলের গাড়ি সার্কিট',
#  'জেলার পরিবহন পুলের গাড়ি সার্কিট হাউজ',
#  'পরিবহন পুলের গাড়ি সার্কিট হাউজ ব্যবস্থাপনা',
#  'পুলের গাড়ি সার্কিট হাউজ ব্যবস্থাপনা শ্রদ্ধেয়',
#  'গাড়ি সার্কিট হাউজ ব্যবস্থাপনা শ্রদ্ধেয় ডিসি',
#  'সার্কিট হাউজ ব্যবস্থাপনা শ্রদ্ধেয় ডিসি স্যারের',
#  'হাউজ ব্যবস্থাপনা শ্রদ্ধেয় ডিসি স্যারের বাংলোর',
#  'ব্যবস্থাপনা শ্রদ্ধেয় ডিসি স্যারের বাংলোর তদারকি',
#  'শ্রদ্ধেয় ডিসি স্যারের বাংলোর তদারকি অফিসের',
#  'ডিসি স্যারের বাংলোর তদারকি অফিসের কার',
#  'স্যারের বাংলোর তদারকি অফিসের কার কী',
#  'বাংলোর তদারকি অফিসের কার কী লাগবে',
#  'তদারকি অফিসের কার কী লাগবে এক',
#  'অফিসের কার কী লাগবে এক কথায়',
#  'কার কী লাগবে এক কথায় সবকিছু',
#  'কী লাগবে এক কথায় সবকিছু দেখভাল',
#  'লাগবে এক কথায় সবকিছু দেখভাল করতে',
#  'এক কথায় সবকিছু দেখভাল করতে হয়',
#  'কথায় সবকিছু দেখভাল করতে হয় এই',
#  'সবকিছু দেখভাল করতে হয় এই এনডিসির',
#  'দেখভাল করতে হয় এই এনডিসির ।',
#  'করতে হয় এই এনডিসির । এনডিসির',
#  'হয় এই এনডিসির । এনডিসির যেই',
#  'এই এনডিসির । এনডিসির যেই অফিশিয়াল',
#  'এনডিসির । এনডিসির যেই অফিশিয়াল ফোন',
#  '। এনডিসির যেই অফিশিয়াল ফোন আছে',
#  'এনডিসির যেই অফিশিয়াল ফোন আছে সেটা',
#  'যেই অফিশিয়াল ফোন আছে সেটা কখনো',
#  'অফিশিয়াল ফোন আছে সেটা কখনো বন্ধ',
#  'ফোন আছে সেটা কখনো বন্ধ হয়না',
#  'আছে সেটা কখনো বন্ধ হয়না ।',
#  'সেটা কখনো বন্ধ হয়না । রোজ',
#  'কখনো বন্ধ হয়না । রোজ কেয়ামতের',
#  'বন্ধ হয়না । রোজ কেয়ামতের দিনেও',
#  'হয়না । রোজ কেয়ামতের দিনেও যদি',
#  '। রোজ কেয়ামতের দিনেও যদি কেউ',
#  'রোজ কেয়ামতের দিনেও যদি কেউ ফোন',
#  'কেয়ামতের দিনেও যদি কেউ ফোন করে',
#  'দিনেও যদি কেউ ফোন করে বলে',
#  'যদি কেউ ফোন করে বলে স্যার',
#  'কেউ ফোন করে বলে স্যার গাড়ি',
#  'ফোন করে বলে স্যার গাড়ি লাগবে',
#  'করে বলে স্যার গাড়ি লাগবে ।',
#  'বলে স্যার গাড়ি লাগবে । থাকা',
#  'স্যার গাড়ি লাগবে । থাকা লাগবে',
#  'গাড়ি লাগবে । থাকা লাগবে নরসিংদীতে',
#  'লাগবে । থাকা লাগবে নরসিংদীতে ।',
#  '। থাকা লাগবে নরসিংদীতে । স্যার',
#  'থাকা লাগবে নরসিংদীতে । স্যার এই',
#  'লাগবে নরসিংদীতে । স্যার এই সমস্যা',
#  'নরসিংদীতে । স্যার এই সমস্যা হয়েছে',
#  '। স্যার এই সমস্যা হয়েছে ।',
#  'স্যার এই সমস্যা হয়েছে । সেটাও',
#  'এই সমস্যা হয়েছে । সেটাও এনডিসির',
#  'সমস্যা হয়েছে । সেটাও এনডিসির যেভাবেই',
#  'হয়েছে । সেটাও এনডিসির যেভাবেই হোক',
#  '। সেটাও এনডিসির যেভাবেই হোক ম্যানেজ',
#  'সেটাও এনডিসির যেভাবেই হোক ম্যানেজ করা',
#  'এনডিসির যেভাবেই হোক ম্যানেজ করা লাগবে',
#  'যেভাবেই হোক ম্যানেজ করা লাগবে ।',
#  'হোক ম্যানেজ করা লাগবে । এর',
#  'ম্যানেজ করা লাগবে । এর পাশাপাশি',
#  'করা লাগবে । এর পাশাপাশি দাপ্তরিক',
#  'লাগবে । এর পাশাপাশি দাপ্তরিক কাজ',
#  '। এর পাশাপাশি দাপ্তরিক কাজ এবং',
#  'এর পাশাপাশি দাপ্তরিক কাজ এবং বিচারিক',
#  'পাশাপাশি দাপ্তরিক কাজ এবং বিচারিক কাজ',
#  'দাপ্তরিক কাজ এবং বিচারিক কাজ তো',
#  'কাজ এবং বিচারিক কাজ তো আছেই',
#  'এবং বিচারিক কাজ তো আছেই ।',
#  'বিচারিক কাজ তো আছেই । আমি',
#  'কাজ তো আছেই । আমি তখনো',
#  'তো আছেই । আমি তখনো বুঝিনি',
#  'আছেই । আমি তখনো বুঝিনি কী',
#  '। আমি তখনো বুঝিনি কী এক',
#  'আমি তখনো বুঝিনি কী এক কর্মযজ্ঞ',
#  'তখনো বুঝিনি কী এক কর্মযজ্ঞ আমার',
#  'বুঝিনি কী এক কর্মযজ্ঞ আমার জন্য',
#  'কী এক কর্মযজ্ঞ আমার জন্য অপেক্ষা',
#  'এক কর্মযজ্ঞ আমার জন্য অপেক্ষা করছিলো',
#  'কর্মযজ্ঞ আমার জন্য অপেক্ষা করছিলো ।',
#  'আমার জন্য অপেক্ষা করছিলো । আমি',
#  'জন্য অপেক্ষা করছিলো । আমি মাননীয়',
#  'অপেক্ষা করছিলো । আমি মাননীয় প্রধানমন্ত্রীর',
#  'করছিলো । আমি মাননীয় প্রধানমন্ত্রীর কার্যালয়ের',
#  '। আমি মাননীয় প্রধানমন্ত্রীর কার্যালয়ের এটুআই',
#  'আমি মাননীয় প্রধানমন্ত্রীর কার্যালয়ের এটুআই থেকে',
#  'মাননীয় প্রধানমন্ত্রীর কার্যালয়ের এটুআই থেকে মেইল',
#  'প্রধানমন্ত্রীর কার্যালয়ের এটুআই থেকে মেইল ফোন',
#  'কার্যালয়ের এটুআই থেকে মেইল ফোন কল',
#  'এটুআই থেকে মেইল ফোন কল পেতে',
#  'থেকে মেইল ফোন কল পেতে থাকলাম',
#  'মেইল ফোন কল পেতে থাকলাম ।',
#  'ফোন কল পেতে থাকলাম । সময়',
#  'কল পেতে থাকলাম । সময় গড়ায়',
#  'পেতে থাকলাম । সময় গড়ায় আর',
#  'থাকলাম । সময় গড়ায় আর মেইল',
#  '। সময় গড়ায় আর মেইল ফোন',
#  'সময় গড়ায় আর মেইল ফোন কলের',
#  'গড়ায় আর মেইল ফোন কলের গতি',
#  'আর মেইল ফোন কলের গতি বাড়ে',
#  'মেইল ফোন কলের গতি বাড়ে ।',
#  'ফোন কলের গতি বাড়ে । তাদের',
#  'কলের গতি বাড়ে । তাদের কাজ',
#  'গতি বাড়ে । তাদের কাজ ছিলো',
#  'বাড়ে । তাদের কাজ ছিলো নরসিংদীর',
#  '। তাদের কাজ ছিলো নরসিংদীর পুরো',
#  'তাদের কাজ ছিলো নরসিংদীর পুরো জেলার',
#  'কাজ ছিলো নরসিংদীর পুরো জেলার সিক্যিউরিটি',
#  'ছিলো নরসিংদীর পুরো জেলার সিক্যিউরিটি এনশিউর',
#  'নরসিংদীর পুরো জেলার সিক্যিউরিটি এনশিউর করা',
#  'পুরো জেলার সিক্যিউরিটি এনশিউর করা ।',
#  'জেলার সিক্যিউরিটি এনশিউর করা । তাদের',
#  'সিক্যিউরিটি এনশিউর করা । তাদের আবাসন',
#  'এনশিউর করা । তাদের আবাসন গাড়িসহ',
#  'করা । তাদের আবাসন গাড়িসহ সকল',
#  '। তাদের আবাসন গাড়িসহ সকল ধরণের',
#  'তাদের আবাসন গাড়িসহ সকল ধরণের রিকোয়ারমেন্টের',
#  'আবাসন গাড়িসহ সকল ধরণের রিকোয়ারমেন্টের দায়িত্ব',
#  'গাড়িসহ সকল ধরণের রিকোয়ারমেন্টের দায়িত্ব যথারীতি',
#  'সকল ধরণের রিকোয়ারমেন্টের দায়িত্ব যথারীতি পড়লো',
#  'ধরণের রিকোয়ারমেন্টের দায়িত্ব যথারীতি পড়লো আমার',
#  'রিকোয়ারমেন্টের দায়িত্ব যথারীতি পড়লো আমার কাঁধে',
#  'দায়িত্ব যথারীতি পড়লো আমার কাঁধে ।',
#  'যথারীতি পড়লো আমার কাঁধে । নিরাপত্তা',
#  'পড়লো আমার কাঁধে । নিরাপত্তা ইস্যু',
#  'আমার কাঁধে । নিরাপত্তা ইস্যু হিসেবে',
#  'কাঁধে । নিরাপত্তা ইস্যু হিসেবে তারিখের',
#  '। নিরাপত্তা ইস্যু হিসেবে তারিখের প্রোগ্রামে',
#  'নিরাপত্তা ইস্যু হিসেবে তারিখের প্রোগ্রামে কারা',
#  'ইস্যু হিসেবে তারিখের প্রোগ্রামে কারা কারা',
#  'হিসেবে তারিখের প্রোগ্রামে কারা কারা থাকবে',
#  'তারিখের প্রোগ্রামে কারা কারা থাকবে তাদের',
#  'প্রোগ্রামে কারা কারা থাকবে তাদের সিক্যিউরিটি',
#  'কারা কারা থাকবে তাদের সিক্যিউরিটি ক্লিয়ারেন্সের',
#  'কারা থাকবে তাদের সিক্যিউরিটি ক্লিয়ারেন্সের জন্য',
#  'থাকবে তাদের সিক্যিউরিটি ক্লিয়ারেন্সের জন্য ডিএসবি',
#  'তাদের সিক্যিউরিটি ক্লিয়ারেন্সের জন্য ডিএসবি পাস',
#  'সিক্যিউরিটি ক্লিয়ারেন্সের জন্য ডিএসবি পাস করানো',
#  'ক্লিয়ারেন্সের জন্য ডিএসবি পাস করানো থেকে',
#  'জন্য ডিএসবি পাস করানো থেকে শুরু',
#  'ডিএসবি পাস করানো থেকে শুরু করে',
#  'পাস করানো থেকে শুরু করে সবকিছু',
#  'করানো থেকে শুরু করে সবকিছু খেয়াল',
#  'থেকে শুরু করে সবকিছু খেয়াল রাখতে',
#  'শুরু করে সবকিছু খেয়াল রাখতে হলো',
#  'করে সবকিছু খেয়াল রাখতে হলো ।',
#  'সবকিছু খেয়াল রাখতে হলো । তারিখ',
#  'খেয়াল রাখতে হলো । তারিখ আসলো',
#  'রাখতে হলো । তারিখ আসলো সেনাবাহিনীর',
#  'হলো । তারিখ আসলো সেনাবাহিনীর ডগ',
#  '। তারিখ আসলো সেনাবাহিনীর ডগ ।',
#  'তারিখ আসলো সেনাবাহিনীর ডগ । স্কোয়াড',
#  'আসলো সেনাবাহিনীর ডগ । স্কোয়াড ।',
#  'সেনাবাহিনীর ডগ । স্কোয়াড । ফোন',
#  'ডগ । স্কোয়াড । ফোন দিয়ে',
#  '। স্কোয়াড । ফোন দিয়ে বললো',
#  'স্কোয়াড । ফোন দিয়ে বললো স্যার',
#  '। ফোন দিয়ে বললো স্যার আমরা',
#  'ফোন দিয়ে বললো স্যার আমরা মেম্বার',
#  'দিয়ে বললো স্যার আমরা মেম্বার আর',
#  'বললো স্যার আমরা মেম্বার আর ছয়টা',
#  'স্যার আমরা মেম্বার আর ছয়টা কুকুর',
#  'আমরা মেম্বার আর ছয়টা কুকুর থাকার',
#  'মেম্বার আর ছয়টা কুকুর থাকার ব্যবস্থা',
#  'আর ছয়টা কুকুর থাকার ব্যবস্থা করেন',
#  'ছয়টা কুকুর থাকার ব্যবস্থা করেন ।',
#  'কুকুর থাকার ব্যবস্থা করেন । আমার',
#  'থাকার ব্যবস্থা করেন । আমার তখন',
#  'ব্যবস্থা করেন । আমার তখন অলরেডি',
#  'করেন । আমার তখন অলরেডি সার্কিট',
#  '। আমার তখন অলরেডি সার্কিট হাউজ',
#  'আমার তখন অলরেডি সার্কিট হাউজ ফুল',
#  'তখন অলরেডি সার্কিট হাউজ ফুল ।',
#  'অলরেডি সার্কিট হাউজ ফুল । ম্যানেজ',
#  'সার্কিট হাউজ ফুল । ম্যানেজ করলাম',
#  'হাউজ ফুল । ম্যানেজ করলাম ।',
#  'ফুল । ম্যানেজ করলাম । নেভির',
#  '। ম্যানেজ করলাম । নেভির ডাইভার',
#  'ম্যানেজ করলাম । নেভির ডাইভার দল',
#  'করলাম । নেভির ডাইভার দল ফোন',
#  '। নেভির ডাইভার দল ফোন দিয়ে',
#  'নেভির ডাইভার দল ফোন দিয়ে বললো',
#  'ডাইভার দল ফোন দিয়ে বললো স্যার',
#  'দল ফোন দিয়ে বললো স্যার আমরা',
#  'ফোন দিয়ে বললো স্যার আমরা আসতেছি',
#  'দিয়ে বললো স্যার আমরা আসতেছি ।',
#  'বললো স্যার আমরা আসতেছি । থাকবো',
#  'স্যার আমরা আসতেছি । থাকবো ম্যানেজ',
#  'আমরা আসতেছি । থাকবো ম্যানেজ করেন',
#  'আসতেছি । থাকবো ম্যানেজ করেন ।',
#  '। থাকবো ম্যানেজ করেন । সেনাবাহিনীর',
#  'থাকবো ম্যানেজ করেন । সেনাবাহিনীর সিক্যিউরিটি',
#  'ম্যানেজ করেন । সেনাবাহিনীর সিক্যিউরিটি সুইপিং',
#  'করেন । সেনাবাহিনীর সিক্যিউরিটি সুইপিং টিম',
#  '। সেনাবাহিনীর সিক্যিউরিটি সুইপিং টিম আসলো',
#  'সেনাবাহিনীর সিক্যিউরিটি সুইপিং টিম আসলো একটা',
#  'সিক্যিউরিটি সুইপিং টিম আসলো একটা আবাসনের',
#  'সুইপিং টিম আসলো একটা আবাসনের ব্যবস্থা',
#  'টিম আসলো একটা আবাসনের ব্যবস্থা করলাম',
#  'আসলো একটা আবাসনের ব্যবস্থা করলাম তাদেরও',
#  'একটা আবাসনের ব্যবস্থা করলাম তাদেরও ।',
#  'আবাসনের ব্যবস্থা করলাম তাদেরও । রাণী',
#  'ব্যবস্থা করলাম তাদেরও । রাণী আসার',
#  'করলাম তাদেরও । রাণী আসার কথা',
#  'তাদেরও । রাণী আসার কথা সড়ক',
#  '। রাণী আসার কথা সড়ক পথে',
#  'রাণী আসার কথা সড়ক পথে কিন্তু',
#  'আসার কথা সড়ক পথে কিন্তু হেলিপ্যাড',
#  'কথা সড়ক পথে কিন্তু হেলিপ্যাড রেডি',
#  'সড়ক পথে কিন্তু হেলিপ্যাড রেডি করতে',
#  'পথে কিন্তু হেলিপ্যাড রেডি করতে হবে',
#  'কিন্তু হেলিপ্যাড রেডি করতে হবে ।',
#  'হেলিপ্যাড রেডি করতে হবে । গণপূর্তের',
#  'রেডি করতে হবে । গণপূর্তের নির্বাহী',
#  'করতে হবে । গণপূর্তের নির্বাহী প্রকৌশলী',
#  'হবে । গণপূর্তের নির্বাহী প্রকৌশলী মহোদয়কে',
#  '। গণপূর্তের নির্বাহী প্রকৌশলী মহোদয়কে বললাম',
#  'গণপূর্তের নির্বাহী প্রকৌশলী মহোদয়কে বললাম স্টেডিয়ামে',
#  'নির্বাহী প্রকৌশলী মহোদয়কে বললাম স্টেডিয়ামে হেলিপ্যাড',
#  'প্রকৌশলী মহোদয়কে বললাম স্টেডিয়ামে হেলিপ্যাড বানান',
#  'মহোদয়কে বললাম স্টেডিয়ামে হেলিপ্যাড বানান ।',
#  'বললাম স্টেডিয়ামে হেলিপ্যাড বানান । বানানো',
#  'স্টেডিয়ামে হেলিপ্যাড বানান । বানানো হলো',
#  'হেলিপ্যাড বানান । বানানো হলো ।',
#  'বানান । বানানো হলো । মোটরকেড',
#  '। বানানো হলো । মোটরকেড এবং',
#  'বানানো হলো । মোটরকেড এবং নিরাপত্তার',
#  'হলো । মোটরকেড এবং নিরাপত্তার দায়িত্বে',
#  '। মোটরকেড এবং নিরাপত্তার দায়িত্বে থাকা',
#  'মোটরকেড এবং নিরাপত্তার দায়িত্বে থাকা অফিসারের',
#  'এবং নিরাপত্তার দায়িত্বে থাকা অফিসারের জন্য',
#  'নিরাপত্তার দায়িত্বে থাকা অফিসারের জন্য প্রচুর',
#  'দায়িত্বে থাকা অফিসারের জন্য প্রচুর গাড়ি',
#  'থাকা অফিসারের জন্য প্রচুর গাড়ি লাগবে',
#  'অফিসারের জন্য প্রচুর গাড়ি লাগবে ।',
#  'জন্য প্রচুর গাড়ি লাগবে । করলাম',
#  'প্রচুর গাড়ি লাগবে । করলাম ম্যানেজ',
#  'গাড়ি লাগবে । করলাম ম্যানেজ ।',
#  'লাগবে । করলাম ম্যানেজ । এর',
#  '। করলাম ম্যানেজ । এর মাঝে',
#  'করলাম ম্যানেজ । এর মাঝে হঠাত',
#  'ম্যানেজ । এর মাঝে হঠাত বলা',
#  '। এর মাঝে হঠাত বলা হলো',
#  'এর মাঝে হঠাত বলা হলো রাণী',
#  'মাঝে হঠাত বলা হলো রাণী যদি',
#  'হঠাত বলা হলো রাণী যদি লাঞ্চ',
#  'বলা হলো রাণী যদি লাঞ্চ করতে',
#  'হলো রাণী যদি লাঞ্চ করতে চায়',
#  'রাণী যদি লাঞ্চ করতে চায় তাহলে',
#  'যদি লাঞ্চ করতে চায় তাহলে মেন্যু',
#  'লাঞ্চ করতে চায় তাহলে মেন্যু কী',
#  'করতে চায় তাহলে মেন্যু কী হবে',
#  'চায় তাহলে মেন্যু কী হবে ।',
#  'তাহলে মেন্যু কী হবে । নেট',
#  'মেন্যু কী হবে । নেট ঘেঁটে',
#  'কী হবে । নেট ঘেঁটে ডাচদের',
#  'হবে । নেট ঘেঁটে ডাচদের খাবারের',
#  '। নেট ঘেঁটে ডাচদের খাবারের আইডিয়া',
#  'নেট ঘেঁটে ডাচদের খাবারের আইডিয়া নিলাম',
#  'ঘেঁটে ডাচদের খাবারের আইডিয়া নিলাম ।',
#  'ডাচদের খাবারের আইডিয়া নিলাম । আমার',
#  'খাবারের আইডিয়া নিলাম । আমার বউকেও',
#  'আইডিয়া নিলাম । আমার বউকেও বললাম',
#  'নিলাম । আমার বউকেও বললাম হেল্প',
#  '। আমার বউকেও বললাম হেল্প করতে',
#  'আমার বউকেও বললাম হেল্প করতে ।',
#  'বউকেও বললাম হেল্প করতে । যদিও',
#  'বললাম হেল্প করতে । যদিও ওটা',
#  'হেল্প করতে । যদিও ওটা পরে',
#  'করতে । যদিও ওটা পরে আর',
#  '। যদিও ওটা পরে আর প্রয়োজন',
#  'যদিও ওটা পরে আর প্রয়োজন হয়নি',
#  'ওটা পরে আর প্রয়োজন হয়নি ।',
#  'পরে আর প্রয়োজন হয়নি । রাণীর',
#  'আর প্রয়োজন হয়নি । রাণীর জন্য',
#  'প্রয়োজন হয়নি । রাণীর জন্য মেডিকেল',
#  'হয়নি । রাণীর জন্য মেডিকেল টিম',
#  '। রাণীর জন্য মেডিকেল টিম ফায়ার',
#  'রাণীর জন্য মেডিকেল টিম ফায়ার সার্ভিস',
#  'জন্য মেডিকেল টিম ফায়ার সার্ভিস ফুড',
#  'মেডিকেল টিম ফায়ার সার্ভিস ফুড এক্সামিনার',
#  'টিম ফায়ার সার্ভিস ফুড এক্সামিনার সহ',
#  'ফায়ার সার্ভিস ফুড এক্সামিনার সহ সকল',
#  'সার্ভিস ফুড এক্সামিনার সহ সকল কিছু',
#  'ফুড এক্সামিনার সহ সকল কিছু রেডি',
#  'এক্সামিনার সহ সকল কিছু রেডি রাখলাম',
#  'সহ সকল কিছু রেডি রাখলাম ।',
#  'সকল কিছু রেডি রাখলাম । রাণীকে',
#  'কিছু রেডি রাখলাম । রাণীকে আমাদের',
#  'রেডি রাখলাম । রাণীকে আমাদের জেলা',
#  'রাখলাম । রাণীকে আমাদের জেলা প্রশাসক',
#  '। রাণীকে আমাদের জেলা প্রশাসক স্যার',
#  'রাণীকে আমাদের জেলা প্রশাসক স্যার নরসিংদী',
#  'আমাদের জেলা প্রশাসক স্যার নরসিংদী জেলার',
#  'জেলা প্রশাসক স্যার নরসিংদী জেলার একটা',
#  'প্রশাসক স্যার নরসিংদী জেলার একটা টোকেন',
#  'স্যার নরসিংদী জেলার একটা টোকেন গিফট',
#  'নরসিংদী জেলার একটা টোকেন গিফট দিবে',
#  'জেলার একটা টোকেন গিফট দিবে ।',
#  'একটা টোকেন গিফট দিবে । সেটাও',
#  'টোকেন গিফট দিবে । সেটাও রেডি',
#  'গিফট দিবে । সেটাও রেডি করলাম',
#  'দিবে । সেটাও রেডি করলাম ।',
#  '। সেটাও রেডি করলাম । আমি',
#  'সেটাও রেডি করলাম । আমি ফোন',
#  ...]

# %%
# save sequences to file
out_filename = r'C:\Users\OFR\Desktop\Thesis work\version four\updated_data_5_1.txt'
save_doc(sequences, out_filename)
